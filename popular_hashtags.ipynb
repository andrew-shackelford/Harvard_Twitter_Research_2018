# %% [markdown]
# # Finding popular political hashtags from existing data

# %% [markdown]
# We want to find the most common hashtags that appear in the tweets we've gathered so far and add the politically relevant ones to our filter.

# %%
import numpy as np
import pandas as pd
import build_hashtag_count_dict as build
import pickle
import json
import os

# %% [markdown]
# ## Create dict for top hashtags in history

# %%
directory = 'hashtag2count_dicts'
file_names = []
for file_name in os.listdir(directory):
    file_names.append(file_name)

# %%
hashtag_counts_historical = {}
for file_name in file_names:
    with open('{}/{}'.format(directory, file_name), 'rb') as f:
        data = pickle.load(f)
        f.close()
    for hashtag in data.keys():
        if hashtag in hashtag_counts_historical.keys():
            hashtag_counts_historical[hashtag] += data[hashtag]
        else:
            hashtag_counts_historical[hashtag] = data[hashtag]

# %%
hashtag_counts_historical
# Out:
# {'Trump': 2338536,
#  'BLUE': 1158532,
#  '生きろ': 3296685,
#  'ゼロ一獲千金ゲーム': 1187468,
#  'NEWS': 4027583,
#  'OnlyYouぼくらのROMEOandJULIET': 14117,
#  'hacking': 1163,
#  'RussianHacking': 4366,
#  'TCMA': 138,
#  'vote': 115480,
#  'Cascade': 439173,
#  '夜よ踊れ': 523038,
#  'NEWSな2人': 30631,
#  'NowPlaying': 679647,
#  'nowplaying': 92408,
#  'Music': 21667,
#  'Konpa': 2235,
#  'Zouk': 2157,
#  'Haiti': 5561,
#  'USA': 1086804,
#  'FBR': 107656,
#  'Resistance': 289343,
#  'FBRParty': 163527,
#  'BlueWave': 290221,
#  'DemForce': 12730,
#  'news': 1346150,
#  'popular': 2592,
#  'MAGA': 4055406,
#  'tbs': 46568,
#  'tbs_news': 45630,
#  'japan': 51247,
#  'テンションMAXっす': 33,
#  '小山慶一郎': 384033,
#  '手越祐也': 402506,
#  '増田貴久': 367467,
#  '加藤シゲアキ': 563138,
#  'RepresentNEWSMix': 282,
#  'NEWSニッポン': 262849,
#  'StandUp': 194195,
#  'BuildtheWall': 10376,
#  'MAGA2018': 23093,
#  'Veterans': 174868,
#  'Veteran': 38610,
#  'QANON': 40053,
#  'SOMETHINGBIG': 57,
#  'Truth': 198827,
#  'TeamLead': 74,
#  'salary': 1061,
#  'ScrumMaster': 11,
#  'Houston': 15433,
#  'Texas': 303960,
#  'Dallas': 15548,
#  'FAKENEWS': 6196,
#  'DEEPSTATE': 2481,
#  'BuildTheWall': 231414,
#  'TrumpTrain': 229956,
#  'Dobbs': 43200,
#  'News': 697437,
#  '生きろ発売決定': 5100,
#  'Celeb': 2696,
#  'Hollywood': 25546,
#  'NEWS最高最強大好き': 3801,
#  'newsevery': 12655,
#  '楽天ブックス': 131,
#  '送料無料': 24,
#  'KAG': 498594,
#  'TrumpArmy': 7995,
#  'TrumpBase': 368,
#  'AmericaFirst': 321801,
#  'DraintheSwamp': 11066,
#  'SilentMajority': 374,
#  'Military': 84936,
#  'まっすー': 29783,
#  'DAPUMP': 120883,
#  'AppWorld': 25,
#  'ニュース': 31620,
#  'にゅーす': 6135,
#  '最新': 6010,
#  'GOP': 338408,
#  'libtards': 11332,
#  'Qarmy': 4304,
#  'KellyFile': 30,
#  'MAGA2KAG': 7088,
#  '生きろCD化希望お願いします': 19364,
#  'fußball': 49,
#  'capitalism': 13782,
#  'Colorado': 17256,
#  'POTUS': 1179791,
#  'BackfireTrump': 857634,
#  'ats': 59,
#  'resistance': 69987,
#  'resist': 61011,
#  'magaisformorons': 1520,
#  'shitholepresident': 989,
#  'Money': 14552,
#  'Power': 1684,
#  'Railway': 772,
#  'newpolicy': 6,
#  'promotion': 633,
#  'LosAngeles': 5724,
#  'RealEstate': 3151,
#  'PutinsPuppet': 16591,
#  'Hitler': 2231,
#  'TBWORLD2018': 51977,
#  'TomCruise': 1427,
#  'HOLLYWOOD': 3843,
#  'Obama': 344768,
#  'GwenIfill': 2101,
#  'honored': 6375,
#  'Sarah': 463,
#  'Acosta': 1519,
#  'FireAcosta': 309,
#  '希望yell': 75348,
#  'エンドレス・サマー': 795007,
#  'np': 319505,
#  'NEWSに恋して': 124059,
#  'PON': 46308,
#  'いのちのうたフェス': 26696,
#  'ゼロエピソードZERO': 44975,
#  'Kazakhstannews': 1831,
#  'Kazakhstan': 2055,
#  '2A': 244130,
#  'AR15': 4192,
#  'Resisters': 39623,
#  'FBRparty': 371077,
#  'Professional': 2413,
#  'business': 41377,
#  'logo': 8013,
#  'FirstLady': 1358,
#  'MelaniaTrump': 9515,
#  'CampusCarry': 748,
#  'safer': 734,
#  'Retweet': 41071,
#  'Like': 2625,
#  'CodeOfPatriots': 297,
#  'God': 34840,
#  'NEWSチケットの輪': 20411,
#  'NEWS求': 5049,
#  'Caligula': 54,
#  'IsolateTheRegime': 32,
#  'acting': 1131,
#  'America': 267256,
#  'lllinois': 25,
#  'Chicago': 40039,
#  'Yaeh': 1,
#  'Replay': 81,
#  'Sports': 7804,
#  'Radio': 2668,
#  'JohnLennon': 111,
#  'Dreams': 385,
#  'Nightmares': 27,
#  'Dreaming': 23,
#  'Mythology': 71,
#  'Dreamers': 845,
#  'Fairies': 9,
#  'Faith': 5450,
#  'Reality': 1408,
#  'Beatles': 196,
#  'Dragons': 326,
#  'TrumpSupporters': 8914,
#  'Libs': 3044,
#  'Bible': 8687,
#  'Pastor': 563,
#  'WakeUpAmerica': 58335,
#  'gaggiolisposiOUTLET': 3,
#  'TraitorTrump': 83952,
#  'Science': 11687,
#  'gender': 2581,
#  'Equality': 5368,
#  'studies': 1535,
#  'biology': 1634,
#  'sociology': 1783,
#  'NEWS15thAnniversaryLIVE2018Strawberry': 35171,
#  'NEWSKOOL': 308,
#  '慶ちゃん大好き': 47854,
#  '小山慶一郎大好き': 15683,
#  '小山慶一郎キャスター復帰待ち': 2591,
#  '慶ちゃん頑張れ': 18363,
#  'Health': 6594,
#  'PetAllama': 424,
#  'MiercolesSanto': 2,
#  'miercoles': 55,
#  'papafrancisco': 29,
#  'religion': 48658,
#  'catolico': 48,
#  'semanasanta': 14,
#  'WWE': 45137,
#  'Democrats': 150823,
#  'AMERICA': 22348,
#  'Zimbabwe': 1669,
#  'EmmersonMnangagwa': 56,
#  'WhiteHouse': 45584,
#  '小山ファイト': 1039,
#  'newsニッポンrepresentnewsmix': 1043,
#  'standuprepresentnewsmix': 648,
#  'Primaries': 712,
#  'BlueWave2018': 67360,
#  'Tennessee': 49564,
#  'Kansas': 22375,
#  'Michigan': 43436,
#  'Missouri': 54005,
#  'Washington': 25169,
#  'Hawaii': 8697,
#  'Connecticut': 10204,
#  'night': 2612,
#  'usa': 136104,
#  'landscape': 3154,
#  'travel': 45252,
#  'stars': 560,
#  'photo': 6169,
#  'oregon': 580,
#  'OH12': 38712,
#  'BLEU': 489,
#  'Thinkaboutthat': 677,
#  'FREEDOM': 18274,
#  'フリーダム天六': 59,
#  'VOTE': 97624,
#  'VoteBlueToSaveAmerica': 16939,
#  'VoteBlueNoMatterWho': 4426,
#  'BlackTwitter': 6387,
#  'BlackLivesMatter': 136264,
#  'DrainTheSwamp': 138937,
#  'midterms': 5130,
#  'novogratz': 1,
#  'cryptocurrency': 34617,
#  'bank': 1595,
#  'slippery': 24,
#  'start': 460,
#  'drops': 66,
#  'day': 2445,
#  'hodl': 622,
#  'cryptonews': 3130,
#  'Winning': 64039,
#  'art': 33817,
#  'StreisandEffect': 47,
#  'QAnon': 400646,
#  'crypto': 37720,
#  'bitcoin': 40747,
#  'ethereum': 11631,
#  'bitcoincash': 759,
#  'qtum': 24,
#  'xrp': 3669,
#  'gas': 1676,
#  'redwave': 7047,
#  'エピソードZERO山口カズヤ編': 1149,
#  'BARZ': 2,
#  'potus45': 561,
#  'NFL': 53980,
#  'HireBlackCoaches': 1493,
#  'CD化': 23,
#  'GodBlessOurPotus': 15,
#  'GodBlessOurFlotus': 6,
#  'GodBlessAmerica': 55343,
#  'podcast': 8997,
#  'politics': 127135,
#  'geek': 1619,
#  'humor': 7665,
#  'comedy': 5334,
#  'detroit': 1271,
#  'michigan': 1264,
#  'japanese': 892,
#  'judo': 377,
#  'kodokan': 310,
#  'martialarts': 713,
#  'martialartist': 350,
#  'budo': 306,
#  'mindset': 3183,
#  'peace': 15263,
#  'Oscillator': 19,
#  'Support': 2904,
#  'TheProfit': 125,
#  'новости': 40408,
#  'политика': 433,
#  'Путин': 590,
#  'Россия': 1175,
#  'Russia': 116498,
#  'Rouhani': 3377,
#  'Iran': 79348,
#  'ButHerEmails': 1028,
#  'Comey': 13796,
#  'Clinton': 26084,
#  'leadership': 13081,
#  'opinion': 2611,
#  'RSA': 165,
#  'Africa': 15013,
#  'democracy': 40299,
#  'PaulManafort': 11048,
#  'Mueller': 83382,
#  'trump': 245121,
#  'maga': 339447,
#  'PastorDarrellScott': 623,
#  'Spirituality': 2290,
#  'Spiritual': 592,
#  'Religion': 27187,
#  'Consciousness': 419,
#  'onpoli': 3940,
#  'election': 23546,
#  'rt': 14149,
#  'love': 68523,
#  'tech': 51597,
#  'Free': 9395,
#  'kindle': 5908,
#  'シンガポール': 101,
#  'nnaasia': 697,
#  'Nigeria': 9877,
#  'liberal': 20203,
#  'Democrat': 192448,
#  'StanAgainstEvil': 1,
#  '愛おしげあき': 462,
#  'エンドレスサマー': 59690,
#  'Community': 3008,
#  'PeruCoin': 1303,
#  'Bitcoin': 31483,
#  'Patriots': 283965,
#  'TrumpRussia': 67540,
#  'TrumpTapes': 9721,
#  'TrumpNation': 6245,
#  'TrumpUSA': 1793,
#  'WilkesBarre': 1327,
#  'Pennsylvania': 55712,
#  'PASen': 514,
#  'usmarine': 58,
#  'semperfidelis': 72,
#  'semperfi': 146,
#  'usmc': 1089,
#  'marine': 806,
#  'TrumpRally': 11743,
#  'TheOpen': 1187,
#  'Golf': 2045,
#  'gop': 26127,
#  '2a': 20065,
#  'rnc': 1640,
#  'MuellerTime': 6764,
#  'IvankaTrump': 2931,
#  'DonaldTrump': 192502,
#  'TheResistance': 114729,
#  'RESIST': 31463,
#  'DEMOCRATS': 5493,
#  'GreenParty': 4121,
#  'Groupthink': 18,
#  'Musafir': 6,
#  'conservative': 21268,
#  'liberals': 24629,
#  'FactCheck': 4219,
#  'DeportThemAll': 10771,
#  'TeamBossyGals': 5999,
#  'L': 6046,
#  '慶ちゃん応援隊': 24125,
#  'Np': 2116,
#  'qanda': 246,
#  '生きろCD化決定': 275,
#  'NEWS15thAnniversary': 153794,
#  'Respect': 184512,
#  'Soldiers': 6227,
#  'salute': 1678,
#  'IndianArmy': 1826,
#  'JaiHind': 796,
#  'goodmorning': 3042,
#  'Sir': 290,
#  'breakingnews': 35929,
#  'PedoGate': 20979,
#  'PedoGateNews': 6468,
#  '希望〜Yell〜': 236318,
#  'San': 2442,
#  'Diego': 694,
#  'CA': 19186,
#  'Job': 32771,
#  'US': 101758,
#  'Politics': 102889,
#  'Q': 67385,
#  'WWG1WGA': 343479,
#  'ImwithHer': 1398,
#  'Bernie': 16909,
#  'American': 175498,
#  'moonbats': 122,
#  'LionelNation': 2590,
#  'War': 7111,
#  'Economy': 8649,
#  'WorldWarII': 452,
#  'TreasonTribe': 8,
#  'BuckleUpButterCup': 63,
#  'Basta': 8679,
#  '小山慶一郎キャスター復帰希望': 4874,
#  '小山慶一郎さんを応援': 946,
#  '15th': 618,
#  'Patriot': 42349,
#  'WalkAway': 390493,
#  'USArmy': 49846,
#  'OnlyYou': 36719,
#  'robot': 1467,
#  'social': 6726,
#  'iot': 1581,
#  'java': 293,
#  'programming': 630,
#  'dev': 133,
#  'ai': 2642,
#  'internet': 2921,
#  'rpi': 89,
#  'Nowplaying': 85706,
#  'ABPNews': 124,
#  'TheGreatAwakening': 66467,
#  'potus': 45327,
#  'realDonaldTrump': 14509,
#  'patriots': 19225,
#  'nra': 11612,
#  'Revolution2018': 389,
#  'qanon': 66806,
#  'Qanon8chan': 11099,
#  'anon': 570,
#  'Congress': 42988,
#  'senate': 1270,
#  'China': 90511,
#  '中國': 29832,
#  '泛亚': 37731,
#  'ABC': 48205,
#  'BBC': 40865,
#  'CNN': 90160,
#  'Facebook': 34365,
#  'Google': 29524,
#  'FT': 15783,
#  'RedWave': 34733,
#  'Man': 1014,
#  'ソレダメ': 7060,
#  'CamilaCabello': 5277,
#  'fifthharmony': 2324,
#  'AbolishICE': 4995,
#  'DefundHate': 350,
#  'Prince': 1647,
#  'CTL': 2010,
#  'BLM': 16541,
#  'FUCKTRUMP': 9592,
#  'president': 39175,
#  'security': 7564,
#  'russia': 9672,
#  'national': 1587,
#  'officials': 277,
#  'campaign': 3427,
#  'country': 31246,
#  'police': 5293,
#  'rally': 1853,
#  'Trump2020': 106375,
#  'RedWaveRising': 53190,
#  'PresidentTrump': 44650,
#  'truth': 322066,
#  'realtalk': 2504,
#  'Indigenous': 543,
#  'Oregon': 5957,
#  'Election2018': 58049,
#  'OR02': 39,
#  'Video': 9905,
#  'Iowa': 9857,
#  'recommends': 1393,
#  'latesttech': 671,
#  'techvideo': 662,
#  'techie': 749,
#  'cascade': 57052,
#  'whoobid': 6,
#  'whoobidauctioneers': 1,
#  'k小山慶一郎キャ': 369,
#  'Opinion': 7974,
#  'Christians': 8735,
#  '1A': 29536,
#  'AFP': 23920,
#  'IMF': 2529,
#  'reuters': 12119,
#  'Comunidad': 503,
#  'Logic': 410,
#  'India': 26479,
#  'BREAKING': 117957,
#  'Qanon': 138197,
#  'QArmy': 80856,
#  'TRUTH': 41466,
#  'TRUMP2020': 18058,
#  'LiberalismIsAMentalDisorder': 26149,
#  'CNNisFakeNews': 1116,
#  'TaxationIsTheft': 1966,
#  'Libertarian': 17049,
#  'TrumpPence16': 747,
#  'Republicans': 48496,
#  'SCOTUS': 42529,
#  'Arizona': 40485,
#  'mcsally': 161,
#  'CharlesKoch': 42,
#  'weightloss': 1285,
#  'fatloss': 582,
#  'health': 13754,
#  'fitness': 9433,
#  'DataSvience': 2,
#  'MachineLearning': 1572,
#  'information': 4943,
#  'Patriotic': 8599,
#  'traitors': 1633,
#  'drumpf': 1069,
#  'impeach': 5413,
#  'ArianaGrande': 3480,
#  '15thAnniversaryLIVE2018': 6686,
#  'strawberry': 116790,
#  'NEWS最高': 508,
#  '生きろ発売決定おめでとう': 664,
#  'TheStorm': 24559,
#  'GreatAwakeningWorldwide': 2965,
#  'GreatAwakening': 93437,
#  'DeepStateInAPanic': 27,
#  'GATrumpTrain': 4735,
#  'patriot': 13020,
#  'KAG2018': 28661,
#  'KAG2020': 57103,
#  'Conte': 1648,
#  'sugardaddy': 2765,
#  'Dilley': 100,
#  'TinyLivesAtStake': 15447,
#  'CrookedHillary': 52854,
#  'ClintonStateDepartment': 307,
#  'threatening': 35,
#  'withhold': 3,
#  'SanctuaryCities': 2269,
#  'shame': 1099,
#  'patronage': 27,
#  'Environmental': 846,
#  'avoalre': 3,
#  'nightcity': 5,
#  'ootd': 1320,
#  'modelling': 192,
#  'tgif': 589,
#  'weekendmood': 8,
#  'like': 3124,
#  'follow': 11290,
#  'sunglasses': 476,
#  'SteamDrills': 104,
#  'ClimateChange': 4836,
#  '5Star': 170,
#  'Inspiration': 3572,
#  'тюмень': 2704,
#  'FirstWarn3': 576,
#  'temps': 73,
#  'temperature': 122,
#  '希望～Yell～': 461988,
#  'NEWS作詞楽曲': 21,
#  'Rosenstein': 16635,
#  'Wray': 2488,
#  'ENOUGH': 802,
#  'DoubleStandard': 1550,
#  '関ジャニ': 11169,
#  'ここに': 1038,
#  'CCOT': 17286,
#  'WeGotThis': 245,
#  'RingIn2018': 3,
#  'GA01': 49,
#  'GOPLies': 695,
#  'GOPComplicit': 5356,
#  'OrinHatch': 39,
#  'İbrahimÇelikkol': 252,
#  '2AğustosDünyaYakışıklılarGünü': 72422,
#  'takeourcountryback': 159,
#  'カモベビってんね': 3041,
#  '祝4000万回再生': 2,
#  'MAGAveteran': 31439,
#  'AssKickers': 223,
#  'VoterId': 99,
#  'VoteRED': 17246,
#  'RedWaveRising2018': 23627,
#  'CNNFakeNews': 3329,
#  '生きろＣＤ化決定': 34,
#  '15anniversary': 277,
#  'Seatbelts': 8,
#  'FucktRump': 298,
#  'JimAcosta': 2258,
#  'CNNSUCKS': 992,
#  'FakeNews': 172591,
#  'FakeNewsMedia': 25744,
#  'WalkAwayCampaign': 8147,
#  'WalkAwayMovement': 6795,
#  'wakeup': 2328,
#  '生きろCD化希望': 20549,
#  'MSNBC': 29012,
#  'PizzaGate': 4688,
#  'MKUltra': 1213,
#  'BitcoinCash': 732,
#  'ReleaseTheIGReport': 1210,
#  'WeThePeople': 108330,
#  'repost': 2649,
#  'twitter': 9568,
#  'WednesdayWisdom': 48981,
#  'Gratitude': 37298,
#  'HappyWeekend': 1051,
#  'Friends': 2706,
#  'ABP': 104,
#  '9月12日発売決定': 62,
#  'Middle': 497,
#  'Syria': 37118,
#  '発売決定': 131,
#  'Venezuela': 20069,
#  'SOSVenezuela': 321,
#  'PrayforVenezuela': 125,
#  'Photography': 11158,
#  'TickTock': 7002,
#  '生きろリリース決定': 25,
#  'ConfirmKavanaugh': 21484,
#  'SupremeCourt': 16627,
#  'Ireland': 4435,
#  'Nature': 24396,
#  'Travel': 47662,
#  'Photo': 15248,
#  'Country': 26169,
#  'Mountains': 2999,
#  'SideraPreSale': 1641,
#  'Mundo': 817,
#  'amazing': 9708,
#  'socialsteeze': 663,
#  'followme': 7394,
#  'Cibolero': 13,
#  'NewMexico': 8514,
#  'TeamFollowBack': 2099,
#  'Follow4Follow': 571,
#  'SigoATodos': 129,
#  'BancoDeSeguidores': 129,
#  'FollowSeguro': 129,
#  'takipedenitakipederim': 138,
#  'InstantFollow': 129,
#  'UnitingPatriotsTogether': 31210,
#  'Thetruenet': 161,
#  'LastFighterPilot': 13017,
#  'UPNews': 536,
#  'Mayawati': 72,
#  'BJP': 4373,
#  'ccot': 25588,
#  'SMAP': 4979,
#  'UC26qEPjOBfx05BeDsYvcGqg': 1,
#  'チラッと芸能たいむ': 1,
#  '中居正広': 903,
#  '音楽の日': 14005,
#  'PatsCamp': 5668,
#  'FastandFurious': 514,
#  'TUS': 982,
#  'WSSU': 370,
#  'QreamFest': 348,
#  'QreamfestPajamaJam': 347,
#  'MakeItRain': 1293,
#  'Snowflake': 1241,
#  'Telescope': 456,
#  'DodgeCity': 27,
#  'UnitedStates': 36557,
#  'TRUMP': 122427,
#  'SallyYates': 853,
#  'CBS': 13441,
#  'LeslieMoonves': 72,
#  'metoo': 7228,
#  'DrainTheDeepState': 33754,
#  'veterans': 52031,
#  '1010に1億回をめざして': 1,
#  '手越': 3583,
#  'NEWSで妄想': 29608,
#  'にゅーすで妄想': 7089,
#  'Flipthe3rd': 1277,
#  'peopleoverpolitics': 875,
#  'electlong': 672,
#  'realrepresentation': 176,
#  'waprimary': 403,
#  'bluewave': 30605,
#  '15周年': 6939,
#  'SmellGists': 10876,
#  'Gist': 9777,
#  'dapump': 11922,
#  'thealfee': 187,
#  'issa': 800,
#  '高見沢俊彦': 192,
#  'Takamiy': 190,
#  'nba': 1581,
#  'mavs': 34,
#  'mavericks': 33,
#  'basketball': 1343,
#  'free': 24096,
#  'agent': 239,
#  'sign': 484,
#  'signing': 42,
#  'LoyolaCollege': 28,
#  'shams': 29,
#  'freedom': 115624,
#  'listen': 1151,
#  'heart': 3284,
#  'introvertlife': 15,
#  'introverts': 7,
#  'honest': 1923,
#  'error': 889,
#  'EmoryUniversity': 1509,
#  'Atlanta': 8102,
#  'fraudulent': 792,
#  'researcher': 873,
#  'fabricator': 749,
#  'ザ少年俱楽部プレミアム': 5533,
#  'MSM': 79288,
#  'atheist': 11776,
#  'atheism': 11828,
#  'atheistrollcall': 8857,
#  'atheistpics': 8773,
#  'pray': 12107,
#  'faith': 21490,
#  'godlessmom': 2362,
#  'godless': 7465,
#  'goodwithoutgod': 4986,
#  'kids': 3229,
#  'deals': 16563,
#  'blackcharcoal': 1,
#  '小山キャスター復帰希望': 43009,
#  'modi': 620,
#  'ji': 5,
#  'ThursdayThoughts': 47718,
#  'FakeNewsCNN': 8927,
#  'общество': 10379,
#  'происшествие': 9825,
#  '1日1貴久': 341,
#  '1日1まっすー': 354,
#  '1日1増田': 334,
#  'おいでよ増田沼': 334,
#  '一度ハマると抜け出せない増田沼': 333,
#  '生きろのCD化希望': 340,
#  'Zombies': 836,
#  'Apocalypse': 642,
#  'KindleBooks': 384,
#  'bookreview': 512,
#  'blockcahin': 67,
#  'CryBaby': 362,
#  'Bait': 266,
#  'Lie': 798,
#  'Fascism': 16509,
#  'DeepState': 71757,
#  '味スタ': 27910,
#  'ShivSena': 335,
#  'demonetisation': 49,
#  'Freedom': 97915,
#  'Cortex': 1242,
#  'PPDAI': 516,
#  'PatriotsFight': 48280,
#  'NowComesThePain': 2149,
#  'CloakAndDagger': 322,
#  'Cuba': 10723,
#  '3Dprinter': 613,
#  '3DGuns': 1886,
#  'guns': 56412,
#  'NRA': 179237,
#  'guncontrol': 18102,
#  'Spotify': 4634,
#  'Viral': 967,
#  'UK': 55450,
#  'KochBrothers': 5626,
#  'TaxScam': 5305,
#  'Cyprus': 1654,
#  'KavanaughForSCOTUS': 10343,
#  '昼休みの癒し': 24,
#  'VoteRed2018': 48412,
#  'VoteTN': 178,
#  'MiracleTreatDay': 413,
#  'NationalIceCreamSandwichDay': 164,
#  'Astroworld': 188,
#  'TEXAS': 14833,
#  'Newsonepk': 5418,
#  'DrShahidMasood': 2033,
#  'LiveWithDrShahidMasood': 990,
#  'LWDSM': 464,
#  'LameStreamMedia': 126,
#  'USMC': 12506,
#  'job': 181750,
#  'Newark': 337,
#  'atheists': 868,
#  'WWI': 2575,
#  'military': 64514,
#  'CrookedDonald': 227,
#  'repealandreplacepotus45': 2,
#  'traitor': 6570,
#  'muellertime': 4073,
#  'feedly': 50089,
#  'today': 9754,
#  'people': 9560,
#  'friends': 10523,
#  'Vote': 272670,
#  'XiJinping': 7175,
#  'Taiwan': 3842,
#  'HOTNEWS重播': 2813,
#  'Reuters': 7340,
#  'RT': 47508,
#  'UN': 11899,
#  'law': 7650,
#  'students': 1903,
#  'CIA': 27513,
#  'VaughnBishop': 2,
#  'GinaHaspel': 126,
#  'YesWeCan': 23530,
#  'FlipItBlue': 17941,
#  'SaveTheChildren': 6128,
#  'Unredacted': 802,
#  'FBResistance': 5176,
#  'Resist': 227240,
#  '味スタ成功祈願': 3824,
#  'VoteBlue': 46261,
#  'Prolife': 8431,
#  'Biden2020': 371,
#  'German': 5245,
#  'UBonn': 1,
#  'PeterScholze': 1,
#  'cnn': 16267,
#  'msnbc': 6631,
#  'mueller': 4321,
#  'fakenews': 20496,
#  'dam': 2350,
#  '15thAnniversary': 14931,
#  'RedNationRising': 25471,
#  'Maga2Kag': 339,
#  'TNgov': 238,
#  'RNRTN': 591,
#  'Facepalm': 191,
#  'BanRedundancyBillNelson': 164,
#  'MolonLabe': 4341,
#  '4chan': 389,
#  '8chan': 2527,
#  'NP': 29616,
#  'alligator': 114,
#  'crocodile': 81,
#  'FunniestTweets': 681,
#  'Parliament': 1851,
#  'French': 2646,
#  'Government': 77926,
#  'illegal': 5960,
#  'restaurants': 333,
#  'unlimited': 81,
#  'binary': 1116,
#  'NowPIaying': 51095,
#  'español': 1054,
#  'FinRech': 1,
#  'قطر': 1234,
#  'WordsToLiveBy': 619,
#  'qotd': 1358,
#  'music': 32222,
#  '15thAnniversaryBox': 15893,
#  'MD': 1313,
#  'Liberals': 68934,
#  'NationalColoringBookDay': 381,
#  'WalkAwayFromDemocrats': 32494,
#  'Megayacht': 91,
#  'DyreAvenue': 1,
#  'BeerHall': 1,
#  'History': 14368,
#  'NYCHistory': 9,
#  'Beer': 855,
#  'TheBronx': 36,
#  'NewYorkCity': 3847,
#  'GovernmentOfPutin': 222,
#  'Collusion': 7240,
#  'FBI': 50350,
#  'DeathOfANation': 6148,
#  'FollowBackResistance': 196771,
#  'FF': 9799,
#  'FollowPatriots': 925,
#  'UseCasesVerticals': 424,
#  'HillaryForPrison': 6522,
#  'snowflake': 1482,
#  'Throw': 20,
#  '2Años': 265,
#  'Vips': 3,
#  'crimeseries': 117,
#  'ARTKNB': 168,
#  'MurderMystery': 195,
#  'CR4U': 124,
#  'ASMSG': 3597,
#  'IARTG': 3836,
#  '生きろCD化ありがとう': 1122,
#  'NXIVM': 6256,
#  'ClintonFoundation': 21871,
#  'ExtincióndeDominio': 187,
#  'Jesus': 18761,
#  'coupons': 342,
#  'freebies': 177,
#  'money': 22290,
#  'finance': 7756,
#  'fashion': 21379,
#  'cars': 2806,
#  'Microsoft': 3149,
#  'MicrosoftFlow': 19,
#  'JosepHKabila': 18,
#  'RDC': 805,
#  'Marketing': 12914,
#  'TrumpPA': 215,
#  'FuckTrump': 95393,
#  'DistractMeWith4Words': 77,
#  'InMyFeelings': 443,
#  'Уфа': 2352,
#  'ГородУфа': 1802,
#  'Башкортостан': 921,
#  'Башкирия': 405,
#  'saferoptions': 2,
#  'Nowplayng': 512,
#  '15thAnniversaryLIVE2018Strawberry': 17277,
#  'WINNING': 27488,
#  'TaxCuts': 3692,
#  'americantownscape': 414,
#  'california': 9123,
#  'america': 41525,
#  'hot': 6199,
#  'playboy': 269,
#  'pod': 55,
#  'ny': 1989,
#  'funny': 12952,
#  'dirty': 1189,
#  'fun': 8354,
#  'soundcloud': 1264,
#  'LiberalLogic': 26128,
#  'votedemout': 164,
#  'hiring': 71223,
#  '新宿ジャニーズ通信': 301,
#  'reinsurance': 1225,
#  'roevswade': 60,
#  'abortion': 8687,
#  'society': 2549,
#  'Attack': 2122,
#  'ObamaWorstPresidentEver': 1984,
#  'TryObama4Treason': 138,
#  'ImprisonObama': 96,
#  'House': 5614,
#  'moving': 247,
#  'MoveTheDate': 6,
#  'FAMU': 48,
#  'Jimin': 1363,
#  'Telugu': 183,
#  'ExtinciónDeDominio': 917,
#  'FamilySeparation': 1128,
#  'Ivanka': 4506,
#  'LilitaTeniaRazon': 830,
#  'DraintheSWAMP': 75,
#  'Hulu': 26697,
#  'NewQ': 1812,
#  'NeonRevolt': 606,
#  'fb': 2280,
#  'StrangerThings': 217,
#  'Privacy': 948,
#  'HumanRights': 13893,
#  'fucktrump': 34548,
#  'इंदौर': 117,
#  'TaleNTedIndia': 2362,
#  'Indore': 3759,
#  'IndoreNews': 1787,
#  'न्यूज़': 1527,
#  'इंदौरन्यूज़': 930,
#  'TaleNTed': 523,
#  'MadhyaPradesh': 688,
#  'eBay': 1515,
#  'Protest': 2722,
#  'racism': 10914,
#  'NYTimes': 14021,
#  'SarahJeong': 1831,
#  'SarahJeongEditorials': 148,
#  'doyourjob': 81,
#  'GoPats': 5225,
#  'Adecco': 6248,
#  'Andover': 160,
#  'Basingstoke': 123,
#  'HemelHempstead': 112,
#  'Stevenage': 123,
#  'WelwynGardenCity': 112,
#  'Ashford': 128,
#  'Dartford': 118,
#  'ChicagoRealEstate': 17,
#  'TimCook': 167,
#  'President': 81931,
#  'IndustryPartners': 129,
#  'wizkhalifa': 27,
#  'chicago': 9443,
#  'chilling': 225,
#  'WinBlue': 25250,
#  'AZ09': 568,
#  'donteatme': 13,
#  'designers': 1529,
#  'followmeJP': 1469,
#  'sougofollow': 3869,
#  'twiNAGOYA': 1466,
#  'nagoya': 1644,
#  'MAGAShadowBan': 3289,
#  'TampaTrumpRally': 952,
#  'Thug': 541,
#  'Bully': 614,
#  'MerrickGarland': 3693,
#  'S': 290,
#  'SaveDemocracy': 2840,
#  'VotingMatters': 657,
#  'EveryVoteCounts': 898,
#  'Progressives': 9519,
#  'DACAAmnesty': 362,
#  'CatchandRelease': 219,
#  'HR392': 6396,
#  'AndreaMitchell': 1034,
#  'Stalin': 1391,
#  '生きろ15thAnniversaryBox': 7165,
#  'StopTheBias': 9452,
#  'Twitter': 42608,
#  'FaceBook': 1543,
#  'Instagram': 5441,
#  'NBA': 3388,
#  'Bloomberg': 1119,
#  'CNBC': 8625,
#  'poverty': 1773,
#  'Poll': 11921,
#  'TheTruthCommunity': 4830,
#  ...}

# %% [markdown]
# ## Convert the dictionary to a list of tuples with (hashtag, count) format

# %%
def sort_dict_by_value_to_tuples(d, reverse=True):
    return [(k, d[k]) for k in sorted(d, key=d.get, reverse=reverse)]

# %%
hashtag_counts_historical_tuples = sort_dict_by_value_to_tuples(hashtag_counts_historical)
hashtag_counts_historical_tuples
# Out:
# [('MAGA', 4055406),
#  ('NEWS', 4027583),
#  ('生きろ', 3296685),
#  ('Trump', 2338536),
#  ('news', 1346150),
#  ('ゼロ一獲千金ゲーム', 1187468),
#  ('POTUS', 1179791),
#  ('BLUE', 1158532),
#  ('USA', 1086804),
#  ('LVE', 960586),
#  ('BackfireTrump', 857634),
#  ('Strawberry', 828151),
#  ('エンドレス・サマー', 795007),
#  ('News', 697437),
#  ('NowPlaying', 679647),
#  ('加藤シゲアキ', 563138),
#  ('夜よ踊れ', 523038),
#  ('KAG', 498594),
#  ('BringBacktheSummer', 477132),
#  ('希望～Yell～', 461988),
#  ('Cascade', 439173),
#  ('手越祐也', 402506),
#  ('QAnon', 400646),
#  ('WalkAway', 390493),
#  ('小山慶一郎', 384033),
#  ('FBRparty', 371077),
#  ('増田貴久', 367467),
#  ('Obama', 344768),
#  ('WWG1WGA', 343479),
#  ('maga', 339447),
#  ('GOP', 338408),
#  ('truth', 322066),
#  ('AmericaFirst', 321801),
#  ('np', 319505),
#  ('Texas', 303960),
#  ('BlueWave', 290221),
#  ('Resistance', 289343),
#  ('Patriots', 283965),
#  ('Vote', 272670),
#  ('America', 267256),
#  ('NEWSニッポン', 262849),
#  ('trump', 245121),
#  ('2A', 244130),
#  ('Bring', 242875),
#  ('希望〜Yell〜', 236318),
#  ('BuildTheWall', 231414),
#  ('TrumpTrain', 229956),
#  ('Resist', 227240),
#  ('Truth', 198827),
#  ('FollowBackResistance', 196771),
#  ('StandUp', 194195),
#  ('DonaldTrump', 192502),
#  ('Democrat', 192448),
#  ('Respect', 184512),
#  ('job', 181750),
#  ('NRA', 179237),
#  ('American', 175498),
#  ('Veterans', 174868),
#  ('FakeNews', 172591),
#  ('FBRParty', 163527),
#  ('NEWS15thAnniversary', 153794),
#  ('Democrats', 150823),
#  ('Putin', 141472),
#  ('DrainTheSwamp', 138937),
#  ('Qanon', 138197),
#  ('BTS', 136327),
#  ('BlackLivesMatter', 136264),
#  ('usa', 136104),
#  ('red', 133712),
#  ('politics', 127135),
#  ('respect', 126836),
#  ('NEWSに恋して', 124059),
#  ('tcot', 122929),
#  ('TRUMP', 122427),
#  ('DAPUMP', 120883),
#  ('BREAKING', 117957),
#  ('strawberry', 116790),
#  ('Russia', 116498),
#  ('freedom', 115624),
#  ('vote', 115480),
#  ('TheResistance', 114729),
#  ('Republican', 114547),
#  ('California', 108462),
#  ('WeThePeople', 108330),
#  ('FBR', 107656),
#  ('Trump2020', 106375),
#  ('Politics', 102889),
#  ('US', 101758),
#  ('CareerArc', 101528),
#  ('Freedom', 97915),
#  ('VOTE', 97624),
#  ('Hiring', 96104),
#  ('FuckTrump', 95393),
#  ('HillaryClinton', 94021),
#  ('GreatAwakening', 93437),
#  ('nowplaying', 92408),
#  ('China', 90511),
#  ('CNN', 90160),
#  ('KちゃんNEWS', 90122),
#  ('ImpeachTrump', 88588),
#  ('45sindespidos', 88227),
#  ('Kavanaugh', 87162),
#  ('Florida', 87155),
#  ('生きろを1位に', 86344),
#  ('Nowplaying', 85706),
#  ('Military', 84936),
#  ('TraitorTrump', 83952),
#  ('Mueller', 83382),
#  ('President', 81931),
#  ('PCAs', 80882),
#  ('QArmy', 80856),
#  ('Iran', 79348),
#  ('MSM', 79288),
#  ('Government', 77926),
#  ('daradaily', 77914),
#  ('Hillary', 76303),
#  ('希望yell', 75348),
#  ('2AğustosDünyaYakışıklılarGünü', 72422),
#  ('DeepState', 71757),
#  ('NeverTrump', 71564),
#  ('hiring', 71223),
#  ('resistance', 69987),
#  ('MakeAmericaGreatAgain', 69517),
#  ('Liberals', 68934),
#  ('love', 68523),
#  ('Maga', 67583),
#  ('TrumpRussia', 67540),
#  ('Q', 67385),
#  ('BlueWave2018', 67360),
#  ('qanon', 66806),
#  ('gratitude', 66724),
#  ('TheGreatAwakening', 66467),
#  ('Ohio', 65965),
#  ('生きろ9月12日発売', 65867),
#  ('ザ少年倶楽部プレミアム', 64847),
#  ('military', 64514),
#  ('FNSうたの夏まつり', 64482),
#  ('EndWitchHunt', 64461),
#  ('Winning', 64039),
#  ('resist', 61011),
#  ('ดาราเดลี่', 60764),
#  ('エンドレスサマー', 59690),
#  ('WakeUpAmerica', 58335),
#  ('Election2018', 58049),
#  ('KAG2020', 57103),
#  ('cascade', 57052),
#  ('guns', 56412),
#  ('TreasonSummit', 56146),
#  ('Pennsylvania', 55712),
#  ('UK', 55450),
#  ('GodBlessAmerica', 55343),
#  ('NorthCarolina', 54268),
#  ('Missouri', 54005),
#  ('NFL', 53980),
#  ('VoteRed', 53853),
#  ('Democracy', 53840),
#  ('Constitution', 53449),
#  ('RedWaveRising', 53190),
#  ('Mステ', 53186),
#  ('CrookedHillary', 52854),
#  ('MondayMotivation', 52227),
#  ('Illinois', 52212),
#  ('veterans', 52031),
#  ('TBWORLD2018', 51977),
#  ('Conservatives', 51858),
#  ('tech', 51597),
#  ('japan', 51247),
#  ('NowPIaying', 51095),
#  ('ProLife', 50985),
#  ('FBI', 50350),
#  ('feedly', 50089),
#  ('USArmy', 49846),
#  ('Tennessee', 49564),
#  ('FoxNews', 49307),
#  ('PatriotsUnited', 49173),
#  ('Crypto', 49075),
#  ('Right', 49002),
#  ('WednesdayWisdom', 48981),
#  ('religion', 48658),
#  ('Republicans', 48496),
#  ('VoteRed2018', 48412),
#  ('TuesdayThoughts', 48400),
#  ('PatriotsFight', 48280),
#  ('ABC', 48205),
#  ('慶ちゃん大好き', 47854),
#  ('ThursdayThoughts', 47718),
#  ('Travel', 47662),
#  ('RT', 47508),
#  ('QAlert', 47212),
#  ('ASTRO', 47159),
#  ('tbs', 46568),
#  ('blockchain', 46400),
#  ('PON', 46308),
#  ('VoteBlue', 46261),
#  ('아스트로', 46089),
#  ('Brexit', 46008),
#  ('tbs_news', 45630),
#  ('WhiteHouse', 45584),
#  ('potus', 45327),
#  ('FridayFeeling', 45270),
#  ('travel', 45252),
#  ('NEWS担と繋がりたい', 45208),
#  ('WWE', 45137),
#  ('ゼロエピソードZERO', 44975),
#  ('PresidentTrump', 44650),
#  ('texas', 44423),
#  ('Red', 44316),
#  ('Canada', 43926),
#  ('JohnMcCain', 43824),
#  ('少年倶楽部プレミアム', 43606),
#  ('Michigan', 43436),
#  ('Dobbs', 43200),
#  ('NiUnSuicidioMasEnFFCCSEyFAS', 43052),
#  ('小山キャスター復帰希望', 43009),
#  ('Congress', 42988),
#  ('Treason', 42871),
#  ('Twitter', 42608),
#  ('SCOTUS', 42529),
#  ('Israel', 42466),
#  ('Patriot', 42349),
#  ('DNC', 42256),
#  ('NewYork', 42130),
#  ('NeverForget', 41763),
#  ('Virginia', 41698),
#  ('america', 41525),
#  ('TRUTH', 41466),
#  ('business', 41377),
#  ('少プレ', 41249),
#  ('Retweet', 41071),
#  ('BBC', 40865),
#  ('bitcoin', 40747),
#  ('Arizona', 40485),
#  ('новости', 40408),
#  ('democracy', 40299),
#  ('QANON', 40053),
#  ('Chicago', 40039),
#  ('walkaway', 39884),
#  ('Resisters', 39623),
#  ('president', 39175),
#  ('Liberal', 38794),
#  ('OH12', 38712),
#  ('Veteran', 38610),
#  ('VoteThemOut', 37976),
#  ('TCOT', 37961),
#  ('Americans', 37833),
#  ('BT21', 37766),
#  ('泛亚', 37731),
#  ('crypto', 37720),
#  ('RJ', 37715),
#  ('Amount', 37671),
#  ('breaking', 37659),
#  ('Georgia', 37376),
#  ('SEVENTEEN', 37324),
#  ('Gratitude', 37298),
#  ('Syria', 37118),
#  ('OnlyYou', 36719),
#  ('UnitedStates', 36557),
#  ('SundayMorning', 36471),
#  ('BoozAllen', 36345),
#  ('MollieTibbetts', 36257),
#  ('RESPECT', 35983),
#  ('breakingnews', 35929),
#  ('ドリフェス', 35867),
#  ('Conservative', 35860),
#  ('life', 35180),
#  ('NEWS15thAnniversaryLIVE2018Strawberry', 35171),
#  ('kag', 35144),
#  ('DumpTrump', 34917),
#  ('ICO', 34900),
#  ('God', 34840),
#  ('RedWave', 34733),
#  ('Russian', 34641),
#  ('cryptocurrency', 34617),
#  ('iKON', 34549),
#  ('fucktrump', 34548),
#  ('Midterms2018', 34509),
#  ('VoteDemsOut', 34389),
#  ('Facebook', 34365),
#  ('art', 33817),
#  ('DrainTheDeepState', 33754),
#  ('Jobs', 33392),
#  ('Indiana', 33218),
#  ('WannaOne', 33163),
#  ('PresidentialElection', 33125),
#  ('government', 32820),
#  ('Job', 32771),
#  ('SouthCarolina', 32717),
#  ('NCT', 32691),
#  ('PJNET', 32688),
#  ('WalkAwayFromDemocrats', 32494),
#  ('honor', 32448),
#  ('Follow', 32447),
#  ('Business', 32408),
#  ('McCain', 32362),
#  ('music', 32222),
#  ('RESISTANCE', 32047),
#  ('New', 31779),
#  ('Manafort', 31701),
#  ('KPOP', 31686),
#  ('KeepAmericaGreat', 31673),
#  ('ニュース', 31620),
#  ('SaturdayMorning', 31573),
#  ('Bitcoin', 31483),
#  ('RESIST', 31463),
#  ('RedWave2018', 31452),
#  ('MAGAveteran', 31439),
#  ('Summer', 31341),
#  ('VoteRedToSaveAmerica', 31261),
#  ('country', 31246),
#  ('UnitingPatriotsTogether', 31210),
#  ('Love', 30657),
#  ('NEWSな2人', 30631),
#  ('Antifa', 30616),
#  ('bluewave', 30605),
#  ('tRump', 30592),
#  ('Pakistan', 30314),
#  ('world', 30007),
#  ('中國', 29832),
#  ('まっすー', 29783),
#  ('veteran', 29709),
#  ('EXO', 29674),
#  ('NP', 29616),
#  ('NEWSで妄想', 29608),
#  ('1A', 29536),
#  ('Google', 29524),
#  ('MSNBC', 29012),
#  ('LockHerUp', 28933),
#  ('prolife', 28718),
#  ('KAG2018', 28661),
#  ('BlueTsunami', 28498),
#  ('希望〜Yell～', 28314),
#  ('NowPlaying️', 28256),
#  ('QuoteOfTheDay', 28214),
#  ('SpyGate', 28121),
#  ('FISA', 28060),
#  ('Omarosa', 27948),
#  ('味スタ', 27910),
#  ('CIA', 27513),
#  ('WINNING', 27488),
#  ('Religion', 27187),
#  ('resisters', 27049),
#  ('希望〜yell', 27012),
#  ('Breaking', 26951),
#  ('希望～Yell〜', 26935),
#  ('technology', 26886),
#  ('Life', 26794),
#  ('Hulu', 26697),
#  ('いのちのうたフェス', 26696),
#  ('GOT7', 26638),
#  ('India', 26479),
#  ('Cohen', 26465),
#  ('イッテQ', 26451),
#  ('Justice', 26421),
#  ('EU', 26378),
#  ('1u', 26348),
#  ('Honor', 26325),
#  ('NEWS15周年おめでとう', 26237),
#  ('Country', 26169),
#  ('LiberalismIsAMentalDisorder', 26149),
#  ('LiberalLogic', 26128),
#  ('gop', 26127),
#  ('Clinton', 26084),
#  ('パーナさんと繋がりたい', 25960),
#  ('MikePence', 25897),
#  ('FakeNewsMedia', 25744),
#  ('ccot', 25588),
#  ('Hollywood', 25546),
#  ('VERNON', 25493),
#  ('RedNationRising', 25471),
#  ('WinBlue', 25250),
#  ('BreakingNews', 25233),
#  ('Washington', 25169),
#  ('TXSen', 25090),
#  ('MeToo', 25008),
#  ('Dems', 24945),
#  ('DOJ', 24920),
#  ('2ndAmendment', 24809),
#  ('Nike', 24763),
#  ('liberals', 24629),
#  ('USFA', 24605),
#  ('TheStorm', 24559),
#  ('donaldtrump', 24427),
#  ('Nature', 24396),
#  ('media', 24334),
#  ('慶ちゃん応援隊', 24125),
#  ('RED', 24109),
#  ('free', 24096),
#  ('NewJersey', 23980),
#  ('AFP', 23920),
#  ('RedWaveRising2018', 23627),
#  ('ICE', 23566),
#  ('election', 23546),
#  ('YesWeCan', 23530),
#  ('NEWSでお絵かき', 23456),
#  ('FreeSpeech', 23376),
#  ('Alabama', 23334),
#  ('日テレ', 23315),
#  ('WitchHunt', 23288),
#  ('GA', 23160),
#  ('MAGA2018', 23093),
#  ('MichaelCohen', 22771),
#  ('quote', 22685),
#  ('wwg1wga', 22655),
#  ('100MostHandsomeFaces2018', 22585),
#  ('Tech', 22563),
#  ('ファミマのエクレア', 22474),
#  ('IT', 22402),
#  ('LockThemAllUp', 22400),
#  ('Impeach45', 22397),
#  ('Kansas', 22375),
#  ('Wisconsin', 22354),
#  ('AMERICA', 22348),
#  ('慶ちゃん', 22327),
#  ('money', 22290),
#  ('TUR', 22184),
#  ('Invest', 22015),
#  ('JohnBrennan', 22008),
#  ('democrats', 21940),
#  ('ClintonFoundation', 21871),
#  ('100MostHandsomeFacesOf2018', 21859),
#  ('Christian', 21769),
#  ('HOT', 21732),
#  ('MAGA2020', 21703),
#  ('2ADefenders', 21683),
#  ('Music', 21667),
#  ('SOUTHKOREA', 21598),
#  ('Saudi', 21492),
#  ('faith', 21490),
#  ('ConfirmKavanaugh', 21484),
#  ('fashion', 21379),
#  ('NEWS15thAniniversary', 21272),
#  ('conservative', 21268),
#  ('Election', 21061),
#  ('NY', 21006),
#  ('PedoGate', 20979),
#  ('Midterms', 20905),
#  ('NotMyPresident', 20895),
#  ('TrumpPutinSummit', 20851),
#  ('ROHLL5', 20845),
#  ('Mexico', 20810),
#  ('Yemen', 20806),
#  ('gun', 20793),
#  ('Louisiana', 20746),
#  ('Maryland', 20716),
#  ('BigTimeRadio', 20653),
#  ('BigOlFamily', 20586),
#  ('すみません落ちます', 20572),
#  ('Turkey', 20564),
#  ('生きろCD化希望', 20549),
#  ('AMJoy', 20505),
#  ('fakenews', 20496),
#  ('Europe', 20451),
#  ('TheGroup', 20450),
#  ('Followback', 20442),
#  ('NEWSチケットの輪', 20411),
#  ('World', 20279),
#  ('TrumpDerangementSyndrome', 20208),
#  ('liberal', 20203),
#  ('Brennan', 20190),
#  ('Media', 20141),
#  ('Oklahoma', 20112),
#  ('Venezuela', 20069),
#  ('2a', 20065),
#  ('ObamaGate', 20044),
#  ('POTUS45', 19978),
#  ('winning', 19879),
#  ('obama', 19839),
#  ('France', 19641),
#  ('Cryptocurrency', 19595),
#  ('Liberty', 19569),
#  ('BrettKavanaugh', 19542),
#  ('希望～yell～', 19536),
#  ('拡散希望', 19505),
#  ('TrumpPutin', 19467),
#  ('生きろCD化希望お願いします', 19364),
#  ('NBC', 19349),
#  ('慶ちゃんのエクレア', 19320),
#  ('NosotrosLosSoldados', 19296),
#  ('GunControl', 19236),
#  ('patriots', 19225),
#  ('EPCOTIA', 19206),
#  ('Apollo11', 19194),
#  ('CA', 19186),
#  ('Browns', 19171),
#  ('テゴマスのらじお', 19154),
#  ('TakeAKnee', 19044),
#  ('間宮祥太朗', 18802),
#  ('Jesus', 18761),
#  ('proudtobeanAmerican', 18753),
#  ('MorningJoe', 18712),
#  ('JustDoIt', 18688),
#  ('onenation', 18651),
#  ('TrumpTreason', 18626),
#  ('July1969', 18585),
#  ('roadtoApollo50', 18542),
#  ('Japan', 18470),
#  ('Deplorables', 18431),
#  ('success', 18431),
#  ('慶ちゃん頑張れ', 18363),
#  ('giveaway', 18323),
#  ('women', 18275),
#  ('FREEDOM', 18274),
#  ('BlueWaveComing2018', 18216),
#  ('TX', 18177),
#  ('希望〜Yell', 18129),
#  ('guncontrol', 18102),
#  ('TRUMP2020', 18058),
#  ('Minnesota', 18001),
#  ('socialmedia', 17982),
#  ('newspaper', 17965),
#  ('Kentucky', 17959),
#  ('FlipItBlue', 17941),
#  ('followback', 17819),
#  ('nature', 17804),
#  ('photography', 17682),
#  ('Istandul', 17640),
#  ('Cody45', 17608),
#  ('AlexJones', 17597),
#  ('CCOT', 17286),
#  ('15thAnniversaryLIVE2018Strawberry', 17277),
#  ('Colorado', 17256),
#  ('VoteRED', 17246),
#  ('JAEHYUN', 17185),
#  ('trumptrain', 17167),
#  ('trending', 17102),
#  ('sagagist', 17069),
#  ('Libertarian', 17049),
#  ('AllLivesMatter', 17005),
#  ('ArethaFranklin', 16970),
#  ('Trending', 16947),
#  ('VoteBlueToSaveAmerica', 16939),
#  ('Bernie', 16909),
#  ('BuildTheDamnWall', 16802),
#  ('ゼロ一攫千金ゲーム', 16768),
#  ('ビビット', 16682),
#  ('ジャニーズ', 16638),
#  ('Rosenstein', 16635),
#  ('BernieSanders', 16629),
#  ('SupremeCourt', 16627),
#  ('Blockchain', 16614),
#  ('PutinsPuppet', 16591),
#  ('deals', 16563),
#  ('android', 16553),
#  ('BLM', 16541),
#  ('mentalhealth', 16540),
#  ('Fascism', 16509),
#  ('PrescientInfo', 16462),
#  ('Benghazi', 16451),
#  ('FX', 16375),
#  ('ข่าววันนี้', 16361),
#  ('嵐', 16357),
#  ('AI', 16341),
#  ('PuertoRico', 16332),
#  ('Labour', 16325),
#  ('HurricaneFlorence', 16282),
#  ('ゼロ', 16280),
#  ('cnn', 16267),
#  ('차은우', 16170),
#  ('p2', 16168),
#  ('내아이디는강남미인', 16153),
#  ('Jacksonville', 16080),
#  ('StopKavanaugh', 16065),
#  ('NEWS速報JAPAN', 16011),
#  ('生きろを１位に', 15962),
#  ('ResistTrump', 15961),
#  ('TeaParty', 15956),
#  ('GOBLUE', 15935),
#  ('Apple', 15926),
#  ('marketing', 15908),
#  ('15thAnniversaryBox', 15893),
#  ('Bluewave', 15832),
#  ('KangDaniel', 15813),
#  ('London', 15801),
#  ('FT', 15783),
#  ('TrustThePlan', 15772),
#  ('IllegalAliens', 15736),
#  ('Standup', 15721),
#  ('小山慶一郎大好き', 15683),
#  ('jobs', 15671),
#  ('Dallas', 15548),
#  ('TinyLivesAtStake', 15447),
#  ('Houston', 15433),
#  ('win', 15421),
#  ('TheSocialCelebrity', 15391),
#  ('TheRainMakers', 15338),
#  ('CoryBooker', 15334),
#  ('GoodTRUMPsEvil', 15325),
#  ('UAE', 15301),
#  ('LockHimUp', 15276),
#  ('peace', 15263),
#  ('SouthAfrica', 15253),
#  ('Photo', 15248),
#  ('Woozi', 15226),
#  ('BoycottNike', 15225),
#  ('blacklivesmatter', 15210),
#  ('EEUU', 15175),
#  ('science', 15154),
#  ('political', 15152),
#  ('Amazon', 15109),
#  ('城山小太郎', 15101),
#  ('Africa', 15013),
#  ('NYC', 15005),
#  ('小関裕太', 14998),
#  ('15thAnniversary', 14931),
#  ('BenGarrison', 14899),
#  ('conservatives', 14877),
#  ('TEXAS', 14833),
#  ('share', 14792),
#  ('DerogacionLey08_2006', 14754),
#  ('btc', 14660),
#  ('football', 14632),
#  ('Germany', 14598),
#  ('チャンカパーナ', 14574),
#  ('Healthcare', 14557),
#  ('SuperEliteMAGAshoutout', 14553),
#  ('Money', 14552),
#  ('FreePress', 14544),
#  ('1Voice', 14519),
#  ('Anime', 14516),
#  ('realDonaldTrump', 14509),
#  ('liberty', 14437),
#  ('FoxAndFriends', 14419),
#  ('History', 14368),
#  ('Helsinki', 14358),
#  ('MAGAbots', 14346),
#  ('SpaceForce', 14334),
#  ('Technology', 14279),
#  ('AAUSA', 14198),
#  ('cartoon', 14164),
#  ('rt', 14149),
#  ('motivation', 14148),
#  ('OnlyYouぼくらのROMEOandJULIET', 14117),
#  ('TDS', 14078),
#  ('Macron', 14051),
#  ('GUN', 14034),
#  ('NYTimes', 14021),
#  ('音楽の日', 14005),
#  ('history', 13957),
#  ('BLUEWAVE', 13936),
#  ('DemocratsHateAmerica', 13932),
#  ('HumanRights', 13893),
#  ('FISAGate', 13875),
#  ('KEIICHIRO', 13803),
#  ('MOG', 13799),
#  ('Comey', 13796),
#  ('官骗', 13792),
#  ('capitalism', 13782),
#  ('BlueWaveIsComing', 13755),
#  ('health', 13754),
#  ('ZIP', 13731),
#  ('TRUMPTRAIN', 13704),
#  ('Usa', 13700),
#  ('RETWEET', 13652),
#  ('retweet', 13622),
#  ('SouthKorea', 13561),
#  ('OHIO', 13551),
#  ('ChooseCruz', 13521),
#  ('杉野遥亮', 13516),
#  ('Australia', 13473),
#  ('CBS', 13441),
#  ('UraniumOne', 13406),
#  ('Socialism', 13393),
#  ('firearms', 13369),
#  ('Fashion', 13304),
#  ('NorthKorea', 13275),
#  ('TrumpKnew', 13272),
#  ('SexyZone', 13227),
#  ('Corruption', 13210),
#  ('Finance', 13193),
#  ('Austin', 13186),
#  ('activemeasures', 13175),
#  ('松島聡', 13154),
#  ('ExtremeMAGAShoutOut', 13151),
#  ('ElectionDay', 13151),
#  ('NEWS譲', 13118),
#  ('deal', 13098),
#  ('England', 13082),
#  ('leadership', 13081),
#  ('presidentpropecia', 13078),
#  ('Profits', 13053),
#  ('patriot', 13020),
#  ('LastFighterPilot', 13017),
#  ('BuildThatWall', 13012),
#  ('TrumpTrain2020', 12991),
#  ('funny', 12952),
#  ('SupportOurTroops', 12949),
#  ('CDTV', 12948),
#  ('Marketing', 12914),
#  ('TrumpCrimeFamily', 12904),
#  ('Maddow', 12901),
#  ('CloserNation', 12890),
#  ('RussianCollusion', 12862),
#  ('BarackObama', 12813),
#  ('海外から応援', 12806),
#  ('PATRIOTS', 12781),
#  ('online', 12773),
#  ('Potus', 12769),
#  ('LaborDay', 12750),
#  ('aboluowang', 12749),
#  ('ISSA', 12741),
#  ('KeepTexasRed', 12732),
#  ('DemForce', 12730),
#  ('2018Midterms', 12706),
#  ('newsevery', 12655),
#  ('video', 12644),
#  ('hiphop', 12628),
#  ('lol', 12587),
#  ('DeepStateCorruption', 12570),
#  ('NWO', 12556),
#  ('LiberalismIsAMentalDisease', 12549),
#  ('ColinKaepernick', 12547),
#  ('ISIS', 12528),
#  ('USMC', 12506),
#  ('ObamaDay', 12492),
#  ('TuesdayMotivation', 12489),
#  ('Left', 12488),
#  ('紅く燃ゆる太陽', 12482),
#  ('GDP', 12443),
#  ('BackTheBlue', 12434),
#  ('quotes', 12422),
#  ('Markets', 12343),
#  ('Islam', 12337),
#  ('NATO', 12292),
#  ('OPMAYFLOWER', 12278),
#  ('Melania', 12254),
#  ('right', 12228),
#  ('FAKEpresident', 12224),
#  ('Sessions', 12195),
#  ('FL', 12191),
#  ('フルスイング', 12176),
#  ('SaturdayMotivation', 12144),
#  ('ImWithHer', 12138),
#  ('DigitalSoldiers', 12122),
#  ('reuters', 12119),
#  ('ゼロ一獲千金ゲームエピソードZERO', 12116),
#  ('少クラP', 12113),
#  ('pray', 12107),
#  ('IoT', 12098),
#  ('NEWSありがとう大好き', 12080),
#  ('buildthewall', 12061),
#  ('deepstate', 12048),
#  ('sports', 12043),
#  ('KavanaughConfirmation', 12026),
#  ('Traitor', 12010),
#  ('VoterID', 11973),
#  ('Strzok', 11973),
#  ('LGBTQ', 11971),
#  ('HelsinkiSummit', 11946),
#  ('dapump', 11922),
#  ('Poll', 11921),
#  ('UN', 11899),
#  ('September11', 11866),
#  ('blue', 11844),
#  ('atheism', 11828),
#  ('VoteBlue2018', 11817),
#  ('JeffSessions', 11790),
#  ('atheist', 11776),
#  ('american', 11763),
#  ('YouTube', 11747),
#  ('Soros', 11747),
#  ('economy', 11746),
#  ('TrumpRally', 11743),
#  ('Gaming', 11718),
#  ('Science', 11687),
#  ('Palestine', 11656),
#  ('ethereum', 11631),
#  ('FollowTheWhiteRabbit', 11631),
#  ('nra', 11612),
#  ('earthquake', 11603),
#  ('加藤諒', 11591),
#  ('Florence', 11577),
#  ('NAFTA', 11576),
#  ('новини', 11575),
#  ('FLOTUS', 11568),
#  ('NHK', 11545),
#  ('Live', 11544),
#  ('Muslim', 11506),
#  ('岡山天音', 11440),
#  ('Flowers', 11438),
#  ('Peace', 11429),
#  ('NFLprotests', 11375),
#  ('libtards', 11332),
#  ('Massachusetts', 11321),
#  ('summer', 11318),
#  ('follow', 11290),
#  ('Army', 11181),
#  ('FUCKtrump', 11172),
#  ('関ジャニ', 11169),
#  ('Photography', 11158),
#  ('HeySayJUMP', 11154),
#  ('わーーーージャニオタさんと繋がるお時間がまいりましたいっぱい繋がりましょ', 11141),
#  ('TreasonousTrump', 11116),
#  ('ICYMI', 11105),
#  ('Qanon8chan', 11099),
#  ('war', 11078),
#  ('DraintheSwamp', 11066),
#  ('Bless', 11058),
#  ('GOPTraitors', 11052),
#  ('PaulManafort', 11048),
#  ('Startup', 11042),
#  ('MARK', 11015),
#  ('MAGAts', 11005),
#  ('Kラジ', 10995),
#  ('Hannity', 10984),
#  ('StandForTheFlag', 10924),
#  ('apple', 10915),
#  ('racism', 10914),
#  ('Sales', 10891),
#  ('火曜サプライズ', 10885),
#  ('SmellGists', 10876),
#  ('Anonymous', 10874),
#  ('Arkansas', 10865),
#  ('OBAMA', 10849),
#  ('Police', 10813),
#  ('Fiverr', 10772),
#  ('DeportThemAll', 10771),
#  ('auspol', 10764),
#  ('DianaMarySharpton', 10739),
#  ('REDFriday', 10726),
#  ('Cuba', 10723),
#  ('Immigration', 10721),
#  ('tlot', 10697),
#  ('ChooseLife', 10689),
#  ('Senate', 10687),
#  ('uk', 10669),
#  ('LDTPoll', 10655),
#  ('Walkaway', 10645),
#  ('BoycottNFL', 10644),
#  ('RNC', 10635),
#  ('blog', 10601),
#  ('MONSTA_X', 10597),
#  ('WhoIsQ', 10580),
#  ('newyork', 10576),
#  ('Catalonia', 10551),
#  ('Women', 10545),
#  ('friends', 10523),
#  ('TaylorSwift', 10504),
#  ('weather', 10491),
#  ('Former', 10471),
#  ('conspiracy', 10447),
#  ('Cruz', 10447),
#  ('希望〜yell〜', 10427),
#  ('Iranian', 10418),
#  ('общество', 10379),
#  ('Political', 10379),
#  ('BuildtheWall', 10376),
#  ('designer', 10367),
#  ('wisdom', 10347),
#  ('KavanaughForSCOTUS', 10343),
#  ('Tcot', 10340),
#  ('Censorship', 10330),
#  ('TheStormIsHere', 10329),
#  ('TrumpsArmy', 10328),
#  ('45SinDespidos', 10325),
#  ('Scotland', 10322),
#  ('JOOHEON', 10313),
#  ('CatsOfTwitter', 10299),
#  ('September11th', 10284),
#  ('putin', 10271),
#  ('VoteWard', 10245),
#  ('WalkAwayFromDemocrats2018', 10244),
#  ('forex', 10233),
#  ('Connecticut', 10204),
#  ('Repost', 10185),
#  ('dumptrump', 10165),
#  ('QPosts', 10095),
#  ('stocks', 10040),
#  ('TREASON', 10037),
#  ('FusionGPS', 10036),
#  ('Bedminster', 10029),
#  ('EXOL', 10017),
#  ('democrat', 10014),
#  ('ctl', 9997),
#  ('amazon', 9996),
#  ('Gossip', 9993),
#  ('mollietibbits', 9992),
#  ('family', 9982),
#  ('pjnet', 9981),
#  ('trump2020', 9978),
#  ('SundayFunday', 9965),
#  ('UniteBlue', 9965),
#  ('Video', 9905),
#  ('PeterStrzok', 9900),
#  ('SEO', 9886),
#  ('GOTV', 9884),
#  ('Nigeria', 9877),
#  ('Iowa', 9857),
#  ('происшествие', 9825),
#  ('FF', 9799),
#  ('books', 9799),
#  ('Gaza', 9793),
#  ('Gist', 9777),
#  ('today', 9754),
#  ('inspiration', 9747),
#  ('Infowars', 9743),
#  ('TrumpTapes', 9721),
#  ('Russians', 9715),
#  ('amazing', 9708),
#  ('Boston', 9694),
#  ('etsy', 9679),
#  ('russia', 9672),
#  ('문빈', 9649),
#  ('Education', 9624),
#  ('FUCKTRUMP', 9592),
#  ('テゴマス', 9591),
#  ('Ukraine', 9584),
#  ('censorship', 9578),
#  ('LockThemUp', 9571),
#  ('twitter', 9568),
#  ('中国', 9564),
#  ('people', 9560),
#  ('MuellerInvestigation', 9552),
#  ('マスヒツ', 9549),
#  ('Progressives', 9519),
#  ('MelaniaTrump', 9515),
#  ('Rise_Up', 9507),
#  ('terpopuler', 9478),
#  ('weeeek', 9467),
#  ('ots', 9454),
#  ('StopTheBias', 9452),
#  ('chicago', 9443),
#  ('fitness', 9433),
#  ('TedCruz', 9425),
#  ('vintage', 9410),
#  ('エピソードZERO', 9404),
#  ('FTrump', 9401),
#  ('Capitalism', 9399),
#  ('kpop', 9396),
#  ('Free', 9395),
#  ('education', 9387),
#  ('DAICHI', 9384),
#  ('trading', 9383),
#  ('Vets', 9382),
#  ('corruption', 9373),
#  ('AskTheQ', 9361),
#  ('MarkBam', 9359),
#  ('美的', 9353),
#  ('republican', 9349),
#  ('SocialMedia', 9338),
#  ('entrepreneur', 9333),
#  ('Erdogan', 9318),
#  ('realdonaldtrump', 9311),
#  ('FloridaPrimary', 9306),
#  ('cdnpoli', 9282),
#  ('china', 9276),
#  ('KRYSTAL', 9276),
#  ('youtube', 9265),
#  ('FridayMotivation', 9258),
#  ('Beto', 9243),
#  ('canada', 9238),
#  ('Asia', 9234),
#  ('nyc', 9233),
#  ('Weather', 9233),
#  ('USBiz', 9220),
#  ('beautiful', 9202),
#  ('TBT', 9187),
#  ('worldnews', 9126),
#  ('california', 9123),
#  ('foxnews', 9119),
#  ('SaudiArabia', 9092),
#  ('SecondAmendment', 9088),
#  ('Trader', 9088),
#  ('ウルトラFES', 9073),
#  ('PatriotsUnite', 9064),
#  ('Mississippi', 9021),
#  ('Pedogate', 9005),
#  ('podcast', 8997),
#  ('LiarInChief', 8959),
#  ('FakeNewsCNN', 8927),
#  ('ネタパレ', 8926),
#  ('ConstitutionDay', 8926),
#  ('DefundPP', 8915),
#  ('TrumpSupporters', 8914),
#  ('WALKAWAY', 8891),
#  ('Kerala', 8887),
#  ('atheistrollcall', 8857),
#  ('FNS', 8842),
#  ('Deplorable', 8833),
#  ('1W1Lツ', 8795),
#  ('Navy', 8784),
#  ('Art', 8784),
#  ('Bush', 8783),
#  ('BlueLivesMatter', 8776),
#  ('atheistpics', 8773),
#  ('MLB', 8749),
#  ('Christians', 8735),
#  ('Progressive', 8731),
#  ('FamiliesBelongTogether', 8723),
#  ('LockTrumpUp', 8720),
#  ('racist', 8716),
#  ('Hawaii', 8697),
#  ('MariaButina', 8697),
#  ('Guns', 8696),
#  ('Bible', 8687),
#  ('abortion', 8687),
#  ('Basta', 8679),
#  ('Merica', 8669),
#  ('ShareJourney', 8653),
#  ('GodBlessOurMilitary', 8652),
#  ('Economy', 8649),
#  ...]

# %% [markdown]
# ## Put the top 1000 hashtags that we aren't already filtering for in a file

# %%
def get_hashtags_not_in_lst(top_hashtags_and_counts):
    hashtag_lst = []
    with open('political_hashtags_2018.txt', 'r') as f:
        for line in f:
            hashtag_lst.append(line[1:-1].lower())
        f.close()
    hashtags_not_in_lst = []
    for hashtag,_ in top_hashtags_and_counts:
        if hashtag.lower() not in hashtag_lst:
            hashtags_not_in_lst.append(hashtag)
    return hashtags_not_in_lst

# %%
top_hashtags_not_in_lst = get_hashtags_not_in_lst(hashtag_counts_historical_tuples)

# %%
f = open('top_1000_hashtags_not_in_political_hashtags_historical.txt', 'w+')
for hashtag in top_hashtags_not_in_lst[:1000]:
    f.write(hashtag + '\n')
f.close()

# %% [markdown]
# # Work below here is only for single days

# %% [markdown]
# ## Examine top hashtags

# %% [markdown]
# Figure out which hashtags appear with the top hashtags but aren't on our list

# %%
def get_top_hashtags_and_counts_for_file(file_name):
    with open(file_name, 'rb') as f:
        data = pickle.load(f)
        f.close()
    sorted_counts = list(data.keys())
    sorted_counts.sort()
    top_hashtags_and_counts = []
    for count in sorted_counts[-1000:]:
        top_hashtags_and_counts.append((count, data[count]))
    return top_hashtags_and_counts

# %%
get_top_hashtags_and_counts_for_file('counts2hashtag_2018-09-19.pkl')
# Out:
# [(1,
#   ['TradeTarrifs',
#    'Replay',
#    'edlandscapes',
#    'itswhatsontheoutsidethatcounts',
#    'mudgee',
#    'abattoir',
#    'OvenStoveCleaners',
#    'MuéveteEnMéxico',
#    'militaryhalloffame',
#    'bcbravehearts',
#    'protector',
#    '150Billion',
#    'BankOfRussia',
#    'Blacklist',
#    'IMPEACHTRUMPNOW',
#    'IncompetentPOTUS',
#    'factoryfarming',
#    'BlogPost',
#    'NunesIsATraitor',
#    'NunesIsALeaker',
#    'VoteJanzforCongress',
#    'TheDocumentsAreComing',
#    'IGI',
#    'steeldossier',
#    'rEPUBLICAN',
#    'ironicmemes',
#    'UseYourHead',
#    'guargopaldas',
#    'goFast',
#    'Walkawayfromdemocrats2018',
#    'itsokwhenitsaconservative',
#    'DIDDLERSDOWN',
#    'MakeaDifference',
#    'STEPSocal',
#    'CrisisOfCharacter',
#    'Beto4Veterans',
#    'drugskill',
#    'SomeDrugsArentCool',
#    'NoSelfRespect',
#    'chevelle',
#    'liveatthenorva',
#    'Creepy',
#    'DemonratsAreSorosPaidPuppets',
#    'OTC',
#    'wusses',
#    'betamales',
#    'TearsDown',
#    'TRAMPTRAIN',
#    'TRUMPSTAIN',
#    'CaitlynJenner',
#    'VotoLatino',
#    'Nuthatch',
#    'species',
#    'AajKeSamachar',
#    'unethical',
#    'atlas',
#    'スチーム',
#    'valve',
#    'Kiina',
#    'Euroopan',
#    'Lumber',
#    'libby',
#    'triggerwarning',
#    'liberalbull',
#    'SteamingPileOfTrump',
#    'DonaldHump',
#    '袖ヶ浦公園',
#    '袖ヶ浦',
#    '季節のお花',
#    'lycoris',
#    'Chiba',
#    'sodegaura',
#    'partcolor',
#    'indvhk',
#    'votebank',
#    'RightToKnow',
#    'FacesOfRacism',
#    'apes',
#    'JesseWilliams',
#    'copslivesmatter',
#    'stopallracism',
#    'dontbearacist',
#    'enoughisenough',
#    'streetphotographicnyc',
#    'marcelopratesphotojournalist',
#    'houstantexans',
#    'OakPoint',
#    'VoteBlueToSaveAmericaDemocracy',
#    'BatshitCrazy',
#    'DrinkMe',
#    'footsteps',
#    'TheRojasFile',
#    'SaferJoburg',
#    'makeSAsafe',
#    'Ekse',
#    'BuyaMthetho',
#    'Spanking',
#    'DumDon',
#    'Blam',
#    'toffee',
#    'toffees',
#    'DavidAxelrod',
#    'Krauthammer',
#    'SepticTankCleaning',
#    'BoyBye',
#    'StopTheDemocraticDeception',
#    'WalkAwayMovementGrowing',
#    'byebyefelicia',
#    'fo_exchange',
#    'entropy',
#    'GopHatesDemocracy',
#    'FakePoll',
#    'ChildSafety',
#    'CrimePrevention',
#    'VisiblePolicing',
#    'フェザー',
#    'ジャケットコーデ',
#    '送料無料',
#    'ブラックコーデ',
#    'ホワイト',
#    'gu',
#    'ユニクロコーデ',
#    'TDE7',
#    'NEWSアニバーサリーグッズ',
#    'BookPromotion',
#    'AuthorPromotion',
#    'Trumpisyourpresident',
#    'BoycottSesameStreet',
#    'glorify',
#    'MidTermsMatter',
#    'AntiCopScumBag',
#    'RealHeroes',
#    'PerpInCityHall',
#    'Megayacht',
#    'KavanaughAc',
#    'MyPeople',
#    'BuyTheBlock',
#    'DUBIA',
#    'tunic',
#    'kurta',
#    'SOCIAL',
#    'QuantumLeap',
#    'DeanStockwell',
#    'kabibeshell',
#    'BrutalTruth',
#    'futurax',
#    'votetoken',
#    'votecoin',
#    'newson',
#    'GloriaAllred',
#    'JudyWoodruff',
#    'ArgentinaSinEstadoDeDerecho',
#    'exposeStrzokandPage',
#    'バス旅',
#    '太川陽介',
#    '蛭子',
#    '人気番組',
#    'バス旅Z',
#    'AKB',
#    '乃木坂',
#    'contributive',
#    'Idiotic',
#    'BlueUnite',
#    'FlipCongress',
#    'tweetstorm',
#    'DamnRightThatsMyPresident',
#    'trumpruinseverything',
#    'alexnajalas',
#    'colombianas01',
#    'AllWillBeRevealed',
#    'PresidentialFact',
#    'SorosCollusion',
#    'IndiansInUSA',
#    'CrazyTrain',
#    'devildogs',
#    'leathernecks',
#    'eatcrayons',
#    'crayons',
#    'readytoeat',
#    'mre',
#    'cre',
#    'スピジャニ',
#    'showmeyourfisa',
#    'establishment',
#    'PUPPET',
#    'STOOGE',
#    'RespectOthers',
#    '4SimpleWords',
#    'TheBlueWave',
#    'MultiplyYourVote',
#    'grussell903',
#    'livefeeds',
#    'adultstars',
#    'اليوم_وين_بتروحون',
#    'Crumbling',
#    'Evolve',
#    'tezos',
#    'SKWAWKBOX',
#    'CorruptCongress',
#    'PDK',
#    'Shamsadeen_Hassan',
#    'best_candidate',
#    'sillywomen',
#    'SaveNetNeutrality',
#    'Redmi6A',
#    'SEP16',
#    'ProgressDem',
#    'warstories',
#    'warmemorial',
#    'lehmarket',
#    'lehsightseeing',
#    'lehdiaries',
#    '小説TRIPPER',
#    'prayerworks',
#    'bds',
#    'AcrossTheGlobe',
#    'ZeroTolerants',
#    'f2b',
#    'respecc',
#    'PatriotsvsEagles',
#    'ecuadorianbeauty',
#    'PieceOfShitPutin',
#    'Tatamotors',
#    'CrookedKillary',
#    'JusticeForAmerica',
#    'Ambode',
#    '3DChess',
#    '4DChess',
#    'CantMakeThisUp',
#    'CNNCaughtLyingAgain',
#    'RapistBillClinton',
#    'करंट',
#    'युवक',
#    'Qproofs',
#    'genders',
#    'friendsforlife',
#    'betofakemexican',
#    'sneakysneaky',
#    'fightharder',
#    'Agenda2030',
#    'GaneshGupta',
#    'CameroUN',
#    'PaulBiya',
#    'JimmyMorales',
#    'livingwithPI',
#    'GOBLUE',
#    'EndangeredSpecies',
#    'AirPower',
#    'theRedstorm',
#    'NOKO',
#    'realestatedevelopment',
#    'Skype',
#    'blogauroradecinemaindica',
#    'elenãopassará',
#    'elenão',
#    'forabostonaro',
#    'VoteEarlyVoteOften',
#    'ONALASKA',
#    'bezos',
#    'Buzzz_zz_zzz_zz_z_zzz_zz',
#    'STORMYDANIELSBOOK',
#    'AtheistApologetics',
#    'ObamasKGB',
#    'afterworkmiles',
#    'beachcities',
#    'KamalToeHarris',
#    'CompassRose',
#    'Giftforher',
#    'AmeriCANS',
#    'GreenDay',
#    'BillieJoe',
#    'VotingAvenue',
#    'SchoolhouseRock',
#    'AmericanBadass',
#    'CaliforniansForTrump',
#    'AntiRepublican',
#    'WinningTeam',
#    'KickRocks',
#    'Nigata',
#    'FindDezaHome',
#    'RepublicansSuck',
#    'FutureMajority',
#    'MarcusSakey',
#    '17Q',
#    'TrumpWhitehouse',
#    'kattwilliams',
#    'VentTeaTalkPanel',
#    'standwithKavanaugh',
#    'allforbenefit',
#    'oversoon',
#    'copihue',
#    'concepcion',
#    'senderismo',
#    'cerrocaracol',
#    'FACESITTING',
#    'Clips4Sale',
#    'Corptocracy',
#    'ScamArtist',
#    '45bestPOTUSever',
#    'peta',
#    'duisdontmatter',
#    'protectwhatyoulove',
#    'ProGunRights',
#    'KavaNOMeansNO',
#    'StopKavanaUGH',
#    'Commitment',
#    'SocialSecuity',
#    'Repulicans',
#    'Trumpmemes',
#    'COTUS',
#    'GoToSleep',
#    'CantResistThis',
#    'FuckDeepState',
#    'CourtMartial',
#    'TDSisreal',
#    'lockman',
#    'pilots',
#    'VolcanicAsh',
#    'WorldAirways',
#    'HealthcareBills',
#    'RaoAnwar',
#    'sites',
#    'NominateABetterCandidate',
#    'iliketrump',
#    'Punishment',
#    'सीबीआई',
#    'विजयमाल्या',
#    '230fifth',
#    'empirestatebuilding',
#    'dailyNews',
#    'EPWEngage',
#    'MoneyFlow',
#    'LauraIngrahm',
#    'Twittersgate',
#    'Nieuws',
#    'transfernews',
#    'trans7',
#    'sissyslut',
#    'oufits',
#    'tranny',
#    'trannyporn',
#    'protectourfreedom',
#    '1位おめでとう',
#    '台灣的安全就靠模仿演員了',
#    'RadFem',
#    'teeshirtdesign',
#    'donthashtag',
#    'beentheredonethat',
#    'MeekFree',
#    'Tirupati',
#    'TeluguDesamParty',
#    'tirupati',
#    'Predators',
#    'NewPlace',
#    'participationtrophy',
#    'RussianAsset',
#    'behumble',
#    'gsp',
#    'ReleaseSessions',
#    'TruthIsPower',
#    'Hussein',
#    'BriberyPayment',
#    'Ecologia',
#    'Sustentabilidad',
#    'DroppingGame',
#    'Supercomputing',
#    'Mellanox',
#    'MaritalIntimacy',
#    'HELLONEARTH',
#    'SummonKerryIranMeetingDocuments',
#    'AlexVirgo',
#    'GravesCreek',
#    'rainbowfishing',
#    'tablemanners',
#    'FreeTheChildren',
#    'FuckCapitalism',
#    'Nobel',
#    'Tourettes',
#    'justundoit',
#    'psyco',
#    'psycology',
#    'selfvalue',
#    'phototherapy',
#    'monies',
#    'rent_to_buy',
#    'shared_ownership',
#    'affordable_rent',
#    'BaldMountainFire',
#    'polecreekfire',
#    'spreading',
#    'silly',
#    'oakleysunglasses',
#    'scarface',
#    'Unbranded',
#    'FORCEOFNATURE',
#    'PHENOMENON',
#    'Tatmadaw',
#    'LIB',
#    'Truckee',
#    'serbian',
#    'ртсвести',
#    'TheBestPeople',
#    'ChildPredators',
#    'ChildMolestors',
#    'TWAFLIGHT800',
#    'ALPHABETAGENCIES',
#    'Abbott',
#    'SchoolDistricts',
#    'Tinderholt',
#    'Decision18',
#    'Cracked',
#    'MontrealRiver',
#    'newyorkgiants',
#    'LIV',
#    'liljoeceo',
#    'mossberg',
#    'BuzzinGreat',
#    'Domestic',
#    'half',
#    'allfoherrbenefit',
#    'masternodes',
#    'BestDayEver',
#    'DCMSHRIRAM',
#    'spselva',
#    'Freakshow',
#    'JessieHelms',
#    'BETTER',
#    'Protests',
#    'UKtrumpvisit',
#    'digitalKids',
#    'IBelieveYou',
#    'africanmagic',
#    'belly',
#    'elationships',
#    'CryBaby',
#    'PartyOfWhiteMen',
#    'PartyOfSexualAssault',
#    'NoRefuge',
#    'HumanTraffickers',
#    'womenfashion',
#    'granite',
#    'composer',
#    'slogans',
#    'PersistenceTrumpsResistance',
#    'SupremeCourtNominee',
#    'Respect大分',
#    'dreamcrazy',
#    'BLACKGOLD',
#    'royality',
#    'blackprints',
#    'Propagandist',
#    'Fahrenheit11_9',
#    'FreeStuff',
#    'SuckMeBeautiful',
#    'redgun',
#    'HandmaidsTale',
#    'democracyvalues',
#    'ReleasetheRecords',
#    'Kamloops',
#    'WELOVE',
#    'CapitaLand',
#    'Millenials',
#    'ReleaseSenateHushFundList',
#    'пожар',
#    'bastogne',
#    'hispanic',
#    'BillPalmer',
#    'Mutual',
#    'Funds',
#    'Fundraising',
#    'workhorse',
#    'teamplayer',
#    'SlaveGrip',
#    'DemocratPlantation',
#    'SlaveNoMore',
#    'trueGrassrootsDemocracy',
#    'AirAssaults',
#    'ICallBS',
#    'WHMustReqFBI',
#    'GOPSHAMRUSH',
#    'FBIReqReasonable',
#    'VAWA4ALL',
#    'weDeserveBetter',
#    'OrangeBaboon',
#    'RememberKateandMollie',
#    'AzureDevOps',
#    'azuresource',
#    'BuckelUp',
#    'dailycurrentaffairs',
#    'dailynewspaper',
#    'wowvideos',
#    'wowvideoscurrentaffairs',
#    'PhineasAndFerb',
#    'milomurphyslaw',
#    'WakeUpInTheSky',
#    'Lastfm',
#    'CultureNight',
#    'rockfellercenter',
#    'gebuilding',
#    'comcastbuilding',
#    's1804',
#    'hr676',
#    'astral',
#    'wentworth',
#    'HumanRightsViolations',
#    'Abduction',
#    'sumedang',
#    'pordajabar',
#    'jailHillary',
#    'Clintoncrimefamily',
#    'Mantra',
#    'foxconn',
#    'PakistanoccupiedKashmir',
#    'Hillaryforprison',
#    'GirlsFrontline',
#    'ForgottenWeapons',
#    'DLC',
#    'FundIt',
#    'SawItComing',
#    'copy',
#    'twitterqrcode',
#    'Protein',
#    'PrinceGeorge',
#    'NoPaylosi',
#    'janzour',
#    'Genocidal',
#    'Escalating',
#    'lowlife',
#    'sethanthony',
#    'roughneck',
#    'countryartist',
#    'FUCKPENCE',
#    'IMPEACHPENCE',
#    'Iseeit',
#    'FuckGOPTraitors',
#    'FuckMcConnell',
#    'FuckRyan',
#    'FuckLindseyGraham',
#    'FuckAllTrumps',
#    'underwaterphotography',
#    'josecuervo',
#    'tequilla',
#    'happyjuice',
#    'heavyhitter',
#    'kush',
#    'ShiftySchiff',
#    'mmmx',
#    'blackhawk',
#    'Sikorsky',
#    'UH60',
#    'desfile16sep',
#    'avgeeks',
#    'goodyontif',
#    'olympicmountains',
#    'bettergetyouame',
#    'starmark',
#    'clonakilty',
#    'directionalist',
#    'abolishdepartmentofeducation',
#    'sangramsingh',
#    'TeamRapert',
#    'Frugal',
#    'ToughTimes',
#    'JamieMasada',
#    'UtilityHacks',
#    'noafd',
#    'deai',
#    'ramadanfasting',
#    'fitdj',
#    'plena',
#    'lookdodia',
#    'Trump202',
#    'NavyAdmiral',
#    'Toro',
#    'ApeEscape',
#    'BobbyScott',
#    'socailist',
#    'HawaiianAirlines',
#    'MushroomStamp',
#    'dismissal',
#    'ಆನ್\u200cಲೈನ್',
#    'ಮೊಬೈಲ್',
#    'JonathonPie',
#    'Departure',
#    'TheWheel',
#    'peculiartv',
#    'Veryexciting',
#    'Pyongyangsummit',
#    'LoonyLibs',
#    'Militarization',
#    'Sankei',
#    'deposeobama',
#    '최유정',
#    'IDOLCHALLENGE',
#    'FightXenophobia',
#    'FightRacism',
#    'WeHappyFew',
#    'Skyrim',
#    'BeyondBruma',
#    'unthinkable',
#    'Slogan',
#    'congresso',
#    'MassimoSugarelli',
#    'congressoPD',
#    'deliberate',
#    'actions',
#    'enourmous',
#    'titties',
#    'RIPMGK',
#    'liferuined',
#    'illegalimmigration',
#    'nomorelies',
#    'livery',
#    'americanairlines',
#    'bud',
#    'spot',
#    'spotter',
#    'spotting',
#    'Untouchable',
#    'Hoggwash',
#    'qadarmehnatki',
#    'GaneshUtsav',
#    'wizardofoz',
#    'WritersLife',
#    'NaNoWriMo',
#    'WritingTip',
#    'BookMarketing',
#    'WritingPrompt',
#    'LitChat',
#    'storystarter',
#    'Insulin4All',
#    'peoplefirst',
#    'T1D',
#    'Heathcare',
#    'artgalleries',
#    'comment4comment',
#    'Denali',
#    'MilitaryAppreciationDay',
#    'StopTweeting',
#    'PrayForPeace',
#    'FilipinoNurse',
#    'DiversityMatters',
#    'ER',
#    'GreysAnatomy',
#    'wrongfrom',
#    'start',
#    'fallenangels',
#    'bootyluvs',
#    'republicanparty',
#    'corporatism',
#    'DRAININGtheSWAMP',
#    'YettiPubes',
#    'BrownLegacy',
#    'canucks',
#    'solarpanel',
#    'destruction',
#    'bigoil',
#    'already',
#    'PositiveMind',
#    'RadicalSelfLove',
#    'PeaceOfMind',
#    'MarioSeries',
#    '너잖아',
#    'GIA',
#    'VoteBlueForAmerica',
#    'themeparks',
#    'rollercoasters',
#    'BluesHistory',
#    '2018Glorious',
#    'EnjoyingTheMovie',
#    'Bolsonaro1ºturno',
#    'WillfulStupidity',
#    'Rockies',
#    'Works',
#    'FoodNews',
#    'fbads',
#    '2018GeneralElection',
#    'moment44',
#    'originalsongs',
#    'AmbiNingVayassaytho',
#    'Sept27',
#    'RebelStar',
#    'Ambreesh',
#    'AmbiNingVayasaitho',
#    'ANV',
#    'Bu',
#    'EmbraceTheSuck',
#    'ThrowTheBastardsOut',
#    'rig',
#    'wethepeoplehavethepower',
#    'Bloom',
#    'Gardens',
#    'ElectionTO',
#    'TheCircus',
#    'Categories',
#    'pops',
#    'DougJones',
#    'DougJones4Senate',
#    'TimeForAChange',
#    'missitalia2018',
#    'VoteBETO',
#    'immunologhi',
#    'ingegneri',
#    'allenatori',
#    'StopTheCensorship',
#    'ConservativesArePatriots',
#    'LiberalsAreSocialistCommunists',
#    'DRovell',
#    'DJR',
#    'DJRx',
#    'NawaeWaqt',
#    'publicviews',
#    '2k19pm',
#    'CongressSankalpYatra',
#    'lahorediaries',
#    'Itllbealrightonthenight',
#    'ClimateCultBS',
#    'realTCUstatetrainOH',
#    'bwahaha',
#    'TrumpCup',
#    'hwnt',
#    'hwntrgv',
#    '今日のおやつ',
#    'ぬれせんべい',
#    'ぬれいか天',
#    'lyingted',
#    '小学生の鼻歌',
#    'HappyBDayPMModi',
#    'PMHouse',
#    'VensonPestSolutions',
#    'Machines',
#    'VeteransBridge',
#    'TimeToInvestigate',
#    'ManicAssholeGriftingAmerica',
#    'redstain',
#    'DimitriVegas',
#    'XGGL',
#    'wegohard',
#    'Minions',
#    'Dive',
#    'Divers',
#    'Palace',
#    'Wilfried',
#    'Zaha',
#    'kneepain',
#    'deutsch',
#    'Jakarta',
#    'bekasi',
#    'kantor',
#    'pilkada',
#    'PRIAN',
#    'Llorona',
#    'laredo',
#    'nld',
#    'nuevolaredo',
#    'leon',
#    'JoyReid',
#    'MaddowBlog',
#    'videoclips',
#    'coloradomodel',
#    'cmgirl',
#    'JatengGayeng',
#    'KIMJONGUN',
#    'CA21',
#    'BAC',
#    'Boğaz',
#    'Bosphorus',
#    'strait',
#    'CryptoFever',
#    'DemocraciesDieInDarkness',
#    'ProAbortion',
#    'wfoa',
#    'mobilkonsep',
#    'individual',
#    'ConfirmKavanughNow',
#    'googlereviews',
#    'customerexperiences',
#    'usecasesverticals',
#    'Importaufschläge',
#    'Zoll',
#    'ÉtatsUnis',
#    'ybraptvnews',
#    'thanksASNC',
#    'LockedUp',
#    'WhiteFace',
#    'livro',
#    'ler',
#    'PrayerForAmerica',
#    'GodBlessedPresidentTrump',
#    'AreWeNuts',
#    'calgary',
#    'Canadadiaries',
#    'greatfriends',
#    'oldfriends',
#    'bonding',
#    'ShareItForward',
#    'LikeIfYouAgree',
#    'marketingdigital',
#    'Stozk',
#    'CattoorLivestock',
#    'roundups',
#    'WILDHORSE',
#    'Zee',
#    'zeeamericas',
#    'polcan',
#    'pallagrellonero',
#    'Volturno',
#    'Chaplin',
#    'Civil_NGO',
#    '修造',
#    'something',
#    'wait',
#    'berightback',
#    'jaycharrisma',
#    'boneinfilet',
#    'rareplus',
#    'saldo',
#    '석산',
#    'Integracion',
#    'ClimateGeoEngineeringChemtrails',
#    'Seinäjoki',
#    'Vaasa',
#    'Hyvinkää',
#    'seksiä',
#    'DreamzGKFraud',
#    'Constitutionನಮ್ಮDharma',
#    'RainMakers',
#    'nfltrade',
#    'TumblringThroughTwitterville',
#    'RiotOnRiotsThoughtsOnKyuss',
#    'ThatIsAll',
#    'BerlinGermany',
#    'TaintedSheriffDavidClarke',
#    'wench',
#    'TexasVotes',
#    'TexasElections',
#    'sniperrifle',
#    'LiberalHypocricy',
#    'trifecta_unlimited',
#    'arizonaforest',
#    'safarilandholster',
#    'thankgod',
#    'THANKGOD',
#    '45NeverMyPrez',
#    'wassenaar',
#    'tgtalk',
#    'plays',
#    'EventNews',
#    'brutalist',
#    'landmarks',
#    'theatres',
#    'shailyretails',
#    'growthhackiing',
#    'github',
#    'amigos',
#    'nopotus',
#    'Manichino',
#    '13settembre',
#    'rc68',
#    'thisiscnn',
#    'fotodeldía',
#    'martes',
#    'rosas',
#    'QAnonPosts',
#    'NEPAL',
#    'MylesJackWasntDown',
#    'ifyoureapatsfan',
#    'destroys',
#    'MyNAmeISREEK',
#    'LoserDonald',
#    'GodBlessWlilieNelson',
#    'NoWarInSyria',
#    'cavanaugh',
#    'MILeg',
#    'Architectural',
#    'Drawing',
#    'Rendering',
#    'Cad',
#    'Interior',
#    'PDF',
#    'AutoCAD',
#    'Drawings',
#    'Conversion',
#    'Outsourcing',
#    'drafting',
#    'Bolts',
#    'weld',
#    'MIAG',
#    'Seaworld',
#    'FailedGOP45',
#    'Disaster45',
#    'OTHER',
#    'EYEWITTNESS',
#    'NEED',
#    'KNOW',
#    'BOOKWORM',
#    'VoteJohnCoxforGovernor',
#    'Endorsed',
#    'IMSpartacus',
#    'さんま御殿',
#    'Credo',
#    'relaxing',
#    'graciasmadre',
#    'Goeb',
#    'GoogleCEO',
#    'bokepbarat',
#    'Inspirations',
#    'Mud',
#    'Squares',
#    'Vans',
#    'minorenni',
#    'westlakepark',
#    'downtownseattle',
#    'gunban',
#    'Bernie2016',
#    'CHicago',
#    'I94',
#    'BabyBeMyBaby',
#    '6November2018',
#    'BlueWedding',
#    'equityineducation',
#    'PaulMooney',
#    'cutyoudown',
#    'opiates',
#    'landofconfusion',
#    'イナズマロックフェス',
#    'playmobil',
#    'flowersofinstagram',
#    'redandorange',
#    'これなに',
#    'ThanksMichelle',
#    'Азербайджан',
#    'jasad',
#    'jasadutuh',
#    'jasadutuhciamis',
#    'jenazah',
#    'chineseinafrica',
#    'chinesezambia',
#    'zambiaafrica',
#    'neocolonialism',
#    'Furguson',
#    'WalkAwayFromCommunists',
#    'whistleblower',
#    'DominicWyKanak',
#    'ritornoalboscodeicentoacri',
#    'shinlim',
#    'agtvote',
#    'CAMEROON',
#    'loseCruz',
#    'devote52weeks',
#    'christianblogger',
#    'christianmom',
#    'christiangirl',
#    'makeyourbed',
#    'admiralmcraven',
#    'LOSS',
#    'LOVEisLOVE',
#    'LiveLetLIve',
#    'Clima',
#    'piccolenews',
#    'SauravRTiberewaal',
#    'facilitator',
#    'AccessConsciousness',
#    'SCROLLING',
#    'ENJOY',
#    'CONTENT',
#    'PROVIDERS',
#    'GUEST',
#    'LEARN',
#    'Silhouette',
#    'GoldColored',
#    'OrangeColor',
#    'Close',
#    'NoRockBottom',
#    'helenamontana',
#    'swim',
#    'ISPR',
#    'Quetta',
#    'letmetalktothem',
#    'PHUCKINGassholes',
#    'allfakeeverything',
#    'smileforthejury',
#    'fill',
#    'hastags',
#    'annoy',
#    'RPAcourse',
#    'iKeenAcademy',
#    'Pasadena',
#    'donacion',
#    'تبرع',
#    'attijariwafabank',
#    'PaxEx',
#    'SpeakTruth',
#    'StartSomewhere',
#    'Hurrican',
#    'HumanRightsDefenders',
#    'NowThisNews',
#    'boxoffice',
#    'returning',
#    'ideeplyappreciateyou',
#    ...]),
#  (2,
#   ['Follow4Follow',
#    'SigoATodos',
#    'BancoDeSeguidores',
#    'FollowSeguro',
#    'takipedenitakipederim',
#    'InstantFollow',
#    'outside',
#    'PlasticSurgery',
#    'indianarmy',
#    'indiansoldiers',
#    'martyrs',
#    'Fascinating',
#    'frightening',
#    'officials',
#    'SOSVenezuela',
#    'PrayforVenezuela',
#    'liveit',
#    'tellit',
#    'takeit',
#    'WIPrimary',
#    'WisconsinPrimary',
#    'ChainOfCommand',
#    'YouTuber',
#    'abortionismurder',
#    'russiagate',
#    'lgstylo4',
#    'ThePeoplesVote',
#    'TheGeorgeSorosVote',
#    'TheBureaucratsVote',
#    'TheElitesVote',
#    'GayPride',
#    'NoNukes',
#    'gentle',
#    'civilization',
#    'Luxurious',
#    'Ajmer',
#    'SVEEP',
#    'RuthbaderGinsberg',
#    'portal',
#    'multiplayer',
#    'GrowthMindset',
#    'Puola',
#    'sotilastukikohta',
#    'photojournalism',
#    'ExpedienteRojas',
#    'LisaBloom',
#    'Reasonable',
#    'Request',
#    'BureauOfInvestigation',
#    '千葉県',
#    'IndiaVsPakistan',
#    'yesthisisthereallife',
#    'ProudBoys',
#    'Qc2018',
#    'Occulte',
#    'Esoterisme',
#    'spiritisme',
#    'Caturday',
#    'quickmoney',
#    'csgofast',
#    'InvestigateFeinstein',
#    'txhsvb',
#    'nisdedchat',
#    'EducationMatters',
#    'Bareback',
#    'Twink',
#    'BigDick',
#    'CollegeGuys',
#    'AnalSex',
#    'specialelection',
#    'TXSD19',
#    'rickrolled',
#    'StopTheLies',
#    'mttbr',
#    'UofL',
#    'Rinos',
#    'WHILL',
#    '乗り物',
#    '未来',
#    'TheAwakening',
#    'bestshotseries',
#    'Tanmin',
#    'Euros',
#    'ViktorOrban',
#    'FrontNational',
#    'EVs',
#    'michaeljackson',
#    'militarylife',
#    'militarywife',
#    'BradParscale',
#    'Memorial',
#    'EnriquePitbullTour',
#    'PitbullEnriqueTour',
#    'tantrum',
#    'MAGATs',
#    'thisisus',
#    'quartadetremurasdv',
#    'masterchefbr',
#    'jeno',
#    'everybodyin',
#    'Die',
#    'Governor_Jerry_Brown',
#    'TimeToFight',
#    'failingNYTimes',
#    'FakenewsCNN',
#    '280characters',
#    'lib',
#    'Supermarkets',
#    'Verified',
#    'barelylegal',
#    'teendreams',
#    'USDistrictJudge',
#    'WorldTradeCenter',
#    'halal',
#    'मतदान',
#    'VOTEINKAVANAUGH',
#    'Census',
#    'ARTKNB',
#    'AntebellumSlave',
#    'halloffame',
#    'WestBank',
#    'stopextinction',
#    'MakeoverMonday',
#    'SapphireSeptember',
#    'MyNonFictionAddiction',
#    'JaneFonda',
#    'Immunotherapy',
#    'MedicalErrors',
#    'BreastCancer',
#    'Hillaryclinton',
#    'madampresident',
#    'madeinfrance',
#    'TrumpvilleTrains',
#    'reallife',
#    'Contacts',
#    'Beverages',
#    'دوستی',
#    'آمریکا',
#    'billisapphire',
#    'redhat',
#    'armywife',
#    'NewAdult',
#    'periscope',
#    'Singularity',
#    'Singularty',
#    'AirForceBirthday',
#    'CatherineBlaseyFord',
#    'publicservants',
#    '大切な友達',
#    '唯一無二の仲間',
#    'DOJCorruption',
#    'GaryStewart',
#    'GeorgiaGuideStones',
#    'NASALIES',
#    'Depopulation',
#    'Buzzin',
#    'MUSHROOMDICK',
#    'acknowledgment',
#    'spin',
#    'Bell',
#    'CrookInChief',
#    'Wellbeing',
#    'solorayaterkini',
#    'whitenationalist',
#    'Tyrant',
#    'Bengals',
#    'EcoLike',
#    'travelwriting',
#    'bookshelf',
#    'HoustonTX',
#    'polmtl',
#    'LCOT',
#    's281',
#    'rollingeyes',
#    'bybehavior',
#    'complicatedmood',
#    'allformybetterlife',
#    'ジャニPON',
#    'onepiece',
#    'janitoivola',
#    'FirstLady',
#    'TrumpTheBestPresidentEver',
#    'BuyIn',
#    'ZOMBIE',
#    'draft',
#    'TOAD',
#    'WhatAreYouHiding',
#    'ILLEGALS',
#    'BrutalDeathGrind',
#    'lilfestyle',
#    'rooftop',
#    'Merck',
#    'biosafety',
#    'Extra',
#    'agt',
#    'KATESLAW',
#    'Renegade',
#    'relatable',
#    'QTNA',
#    'UTK',
#    'SocialListening',
#    'valores',
#    'wildfire',
#    'なちゃんの妄想',
#    'weekendvibes',
#    'BORDER',
#    'FactoryFarms',
#    'Could',
#    '生きろBillboard1位おめでとう',
#    'EnoughUsEnough',
#    '防災',
#    'kodomo',
#    'uganda',
#    'va07',
#    '511tactical',
#    'breasts',
#    'OUE',
#    'Stake',
#    'Bowsprit',
#    'NoDealsforTraitors',
#    'americastrong',
#    'timecrisis',
#    'Meme',
#    'queleer',
#    'canadians',
#    'смерть',
#    'tideischanging',
#    'newdogintown',
#    'Buenos',
#    'Behinderung',
#    'Inklusion',
#    'Hilfe',
#    'HaitianTwitter',
#    'tiromancino',
#    'charges',
#    'crossover',
#    'sometimes',
#    'PrinceWilliam',
#    'StrongEurope',
#    'SkySoldiers',
#    'Airborne',
#    'NOHOMELESSCITIZEN',
#    'WomenSupportingWomen',
#    'nikes',
#    'FUCKGOP',
#    'CoreeduNord',
#    'FuckPence',
#    'LiberalismIsCommunism',
#    'Announced',
#    'RottingLove',
#    'OfficialSelection',
#    'SacramentoHorror',
#    'fam',
#    'Flags',
#    'icloudunlock',
#    'RoyalHeirEnt',
#    'cork',
#    'EUisOVER',
#    'BDS4EVER',
#    'Conway',
#    'Wakanda',
#    'blasphemy',
#    'codtopplays',
#    'blackops4blackout',
#    'blackops4blackoutbeta',
#    'codcreator',
#    'AnthonyWeiner',
#    'LeaderoftheFreeWorld',
#    'botanicalgarden',
#    'taipei',
#    'tent',
#    'Salvia',
#    'DumbDems',
#    'EndCorruption',
#    'KeepEmEducated',
#    'nationalgeographic',
#    'TheeDisruptor',
#    'RUMORS',
#    'hungary',
#    'DemocratPlaybook',
#    'dorothy',
#    'wan',
#    'టెక్నాలజీ',
#    'మొబైల్స్',
#    'శాంసంగ్',
#    'signatures',
#    '요고바라',
#    'wkys',
#    'washdc',
#    'congressionalblackcaucus',
#    'cbc2018',
#    'NEWS1位おめでとう',
#    'KUの日記',
#    '2IDTKD',
#    'determined',
#    'Encouragement',
#    'Male',
#    'SeniorPost',
#    'NEWSROOM',
#    'newsroomdiary',
#    'HushFund',
#    'Rise_Up',
#    '若狭',
#    'WhereIsBillSmith',
#    'NASCARPlayoffs',
#    '4TheCup',
#    'disneyworld',
#    'BeautifulBastard',
#    'CentralBanks',
#    'NoTED',
#    'gitmo',
#    'congressopd',
#    'Alex',
#    'EBAY',
#    'oldies',
#    'DenisNorden',
#    'Troglodyte',
#    'PresidentialNomination',
#    'BoycottMSM',
#    'Paryushan',
#    'MondayMotivaton',
#    'ECity',
#    'Launches',
#    'Industrialautomationacademy',
#    'Unemployment',
#    'printing',
#    'ElSalvador',
#    'estudio',
#    'JoshGertein',
#    'AriMelber',
#    'PleaDeal',
#    'Designed',
#    'theology',
#    'FakePresidentTrump',
#    'HonorNote',
#    'HonorNote10',
#    'madhyagujarat',
#    'popupshop',
#    'junk',
#    'hiphopartist',
#    'healthandwellness',
#    'tangerang',
#    'kampus',
#    'ner',
#    '下北沢',
#    'ghanamusic',
#    'TheREALPresident',
#    'İstanbul',
#    'テニミュ',
#    'headline',
#    'livpsg',
#    'muellerProbe',
#    'EyesEverywhere',
#    'ARW',
#    'Dutch',
#    'SinglePayerNow',
#    'HR676',
#    'S104',
#    'M4A',
#    'DoUrResearch',
#    'profoundthinking',
#    'beautifulcuisines',
#    'bauhaus',
#    'makeithappen',
#    'MONOS',
#    'HELPREDUGEESININDONESIA',
#    'USGov',
#    'SheWon',
#    'steak',
#    'DarknessIntoLight',
#    'Streetart',
#    '日本の司法レベル',
#    'mi6',
#    'interpol',
#    'CUBERS',
#    '昭島系アイドル',
#    '春斗',
#    'ElectionJudge',
#    'travelerlife',
#    'solidWaste',
#    'NDS2',
#    'Speakers',
#    'DontMessWithTX',
#    'OpenHouseLondon',
#    'html5',
#    'wired25',
#    'YehHaiMohabbatein',
#    'YRKKH',
#    'virtuesignal',
#    'jquery',
#    'opioids',
#    'MIGov',
#    'BERNIE2020',
#    'newvapes',
#    'fyi',
#    'wedeliver',
#    'Nordstream2',
#    'UPCM',
#    'YogiCabinet',
#    'Paddy',
#    '1minsingle',
#    'Drafting',
#    'Tekla',
#    'Fabrication',
#    'drawings',
#    'Firm',
#    'BienEtreAnimal',
#    'valeurs',
#    'Tamilnadu',
#    'DanPatrick',
#    'SportsBar',
#    'Humiliating',
#    'WITCH',
#    'I696',
#    'QueenShania',
#    'ILoveForeverShania',
#    'ShaniaNOWTour',
#    'ShaniaNOW',
#    'ComfortWomen',
#    'sexslaves',
#    'Laos',
#    'SenBiden',
#    'jfkjralive',
#    'viaje',
#    'NonMuslim',
#    'prezident',
#    'президент',
#    'ilhamaliyev',
#    'ilhamlaireli',
#    'FEDENALGAS',
#    'Cockroaches',
#    'Mekong',
#    'christianlife',
#    'AIDS',
#    'HEART',
#    'URBAN',
#    'CONFIRM',
#    'colangels',
#    'meetyourangelhere',
#    'startuplife',
#    '小山C',
#    'preservation',
#    'Bluewavecoming',
#    'doubt',
#    'HAPPY',
#    'YEAR',
#    'fisherspasepen',
#    'backpacker',
#    'onset',
#    'makeupartist',
#    'lobbyist',
#    'e40',
#    'trumpdoodletuesday',
#    'PlanPauvrete',
#    'PlanSante',
#    'BiasedMedia',
#    'pemilu2019',
#    'setindex',
#    'endmetoo',
#    'AmericaIsTrumpedUp',
#    'MaliciousLiberalLeft',
#    'PoeticJustice',
#    'BidenObama2020',
#    '3d',
#    'DestroytheDeepState',
#    'PutinsBitch',
#    'zionists',
#    'typewriter',
#    'pisalnistroj',
#    'rdeč',
#    'naprava',
#    'prenosnik',
#    'RedOctober',
#    'SiempreEnLaNoticia',
#    'ivlp2018',
#    'IVLP',
#    'CBN',
#    'lagosstate',
#    'Scandinavia',
#    'NorthernEurope',
#    'pastor',
#    'dayinrockhistory',
#    'thisdayinrock',
#    'extraincome',
#    'tiktok',
#    'broken',
#    'she',
#    'too',
#    'klm',
#    'ShotOnAndroid',
#    'TuesdayTho',
#    'WomeninFilm',
#    'FOREX',
#    'Zurcaroh',
#    'カモンベイビーアメリカ',
#    'Messages',
#    'sms',
#    'spam',
#    'czusa',
#    'Posso',
#    'aborted',
#    'Gurugram',
#    'DregsArise',
#    'TrumpDregs',
#    'TrumpDregsOfSociety',
#    'TrumpDregsRising',
#    'JerseyCity',
#    'Paterson',
#    'musique',
#    '18Sep',
#    'emailsignature',
#    'clickable',
#    'gmail',
#    'outlook',
#    'gsuite',
#    'hotmail',
#    'webmail',
#    'signaturegig',
#    'CARR',
#    'Mashrek',
#    'RESUMEN',
#    'GoblinKing',
#    'repTourArlington',
#    'BlillClinton',
#    'screenwriting',
#    'margaritarobles',
#    'cocktails',
#    'ThisBitch',
#    'energie',
#    'Fender',
#    'Stratocaster',
#    'AffiliateMarketing',
#    'GOPWar222',
#    'TheGlobalResistance',
#    'WashingtonExaminer',
#    'GOPWar223',
#    'Avalanche_The_Architect',
#    'Why_Pree',
#    'GetPaid',
#    'wants',
#    '100k',
#    'Parseltongue',
#    'Aktien',
#    'volar',
#    'GarethEvans',
#    'tatbilb',
#    'JAIL',
#    'Lyrics',
#    'mercoledì',
#    'RupertMurdoch',
#    'WomenInMedicine',
#    'ClintonCrimeFoundation',
#    'About',
#    'iPhoneXs',
#    'NPA',
#    'PopularVote',
#    'mangrove',
#    'GreggJarrett',
#    'MakeTheWorldGreatAgain',
#    'LokSabhaElection2019',
#    'timelapse',
#    'LPSstrong',
#    'NorthBranchWhiteRiver',
#    'vs',
#    'TEDCRUZ',
#    'LEGAL',
#    'MEXICAN',
#    'EtsyTeamUNITY',
#    'etsyclub',
#    'folliow4followback',
#    'greenlife',
#    'structural',
#    'napoli',
#    'Forbes',
#    'got',
#    'timesofindia',
#    'SarvisCoveCreek',
#    'FOLLOWTHEMONEY',
#    'voteno',
#    'Role',
#    'powerhung',
#    'Yates',
#    'BothemShemJean',
#    'Orfini',
#    'neoliberal',
#    '高浜',
#    'academy',
#    'ejercito',
#    'PROGRESSIVE',
#    'GoAwayHillary',
#    'pale',
#    'MalcolmX',
#    '1953ChryslerHemi',
#    'Terrible',
#    'TrumpLiesEverytimeHeSpeaks',
#    'co',
#    'studentjournalists',
#    'features',
#    'ignorancia',
#    'inteligencia',
#    'ACTNOW',
#    'EB5',
#    'EB5Visa',
#    'FordTrump',
#    'MixedReality',
#    '旅',
#    '旅行',
#    'GANGPARADE',
#    'BOYSANDMEN',
#    'LordKrishna',
#    'ger',
#    'LiveNews',
#    'Sacrifices',
#    'BestRobot',
#    'ParentChild',
#    'rideordie',
#    'MWDTSA',
#    'MWD',
#    'KimJonghyun',
#    'WeStandWithAssad',
#    'FDI',
#    'エンタの神様',
#    'ダンサー',
#    '振り付け',
#    '芋洗坂係長',
#    'thankfulness',
#    'डोनाल्डट्रंप',
#    'पोर्न',
#    'स्टॉर्मीडेनियल्स',
#    're',
#    'trumpbabes2020',
#    'guaba',
#    'cuztomz',
#    '自衛隊',
#    'selfemployed',
#    'babyboomers',
#    'tabanca',
#    'browning',
#    'Answer',
#    'VoteCollinsOut',
#    'bebee',
#    'Eugene',
#    'shakespeare',
#    'dollars',
#    'OpDeSanitize',
#    'cavuto',
#    'FearNot',
#    'SEATseekingName',
#    'SexualAssualt',
#    'blueprint',
#    'Nasirabad',
#    'Republicants',
#    'fieldtech',
#    'SL',
#    'JustLikeYou',
#    'priyankachopra',
#    'Ludwigsburg',
#    'ICFA',
#    'JusticeForBo',
#    'Capitol',
#    'Prinsjesdag',
#    'benz',
#    'ENTERPRISES',
#    'ENTERTAINMENT',
#    'CHOICE',
#    'elderabuse',
#    'trumpster',
#    'TYRANNY',
#    'Namaste',
#    'Wentworth',
#    'leolist',
#    'vipfavours',
#    'preferred411',
#    'backpage',
#    'nuska',
#    'bhagve',
#    'ARPEGESTORY',
#    'backdrop',
#    'Pickup',
#    'EURUSD',
#    'TPS',
#    'burgundy',
#    'curvy',
#    'CONSTITUTIONAL',
#    'igersusa',
#    '絵',
#    'rahulgandhi',
#    'powerproject',
#    'loksbhaelection',
#    'IBelieveKavanaugh',
#    'farmlife',
#    'prepaidplans',
#    'టెలికాం',
#    'OpenFuture',
#    'endorsement',
#    'Acoustic',
#    'Tarraco',
#    'VerseOfTheDay',
#    'StayHumble',
#    'virtue',
#    'Fallen',
#    'Risen',
#    'featurecorner',
#    'VoteOutTheGOP',
#    'sisepudo',
#    'duncan',
#    'westbrook',
#    'offtheglass',
#    'dwade',
#    'Nba',
#    'greeting',
#    'invitation',
#    'Ch7HD',
#    'shares',
#    'PSU',
#    'VOTEDEMSOUT',
#    'RESISTEVIL',
#    'SeethingFrog',
#    'frankfurt',
#    'Robes',
#    'Pretty',
#    'PeoplesMonday',
#    'hollywoodwalkoffame',
#    'Angers',
#    'Barbaric_Terrorist_mullahs',
#    'drifter',
#    'WorstPotusEver',
#    'TrumpWorstDealMakerEver',
#    'GOPConspiracy',
#    'GOPFraud',
#    'ProtectRosenstein',
#    'amplifier',
#    'Jimi',
#    'الايمان',
#    'الامريكي',
#    'رجال_الله',
#    'ezexpressway',
#    'lovespells',
#    'workathome',
#    'VoteThenToast',
#    'EnVivo',
#    'uscars',
#    'ClearAndPresentDanger',
#    'gocanelo',
#    'High',
#    'acl',
#    'GoodMorningWorld',
#    'topoftherock',
#    'Piano',
#    'contro',
#    'attacchi',
#    'RTしたひと全員フォローする',
#    '대만',
#    'Carpet',
#    'Zinsen',
#    'Sparer',
#    'vikings',
#    'LittlePineCreek',
#    'CricketMeriJaan',
#    'NewIndia',
#    'Tump',
#    'GoodMorningEveryone',
#    'ItWasAVeryFunnyAndAmazingBirthdayIEnjoyAlso',
#    'ThankYouForTheVideo',
#    'Lovedit',
#    'бульвар',
#    'TrudeauForTreason',
#    'Bucharest',
#    'incidente',
#    'MainMaikeChaliJaungi',
#    'YehUnDinoKiBaatHai',
#    'resistbot',
#    'brett_kavanaugh',
#    'MenToo',
#    'MenAreHumanToo',
#    'menaretrash',
#    'Çin',
#    'mockingbirdMedia',
#    'kpk',
#    'KNIL',
#    'veteranen',
#    'ambonezen',
#    'justasking',
#    'poor',
#    'catsinam18',
#    'clone',
#    'thisdayinhistory',
#    'cnnchaosnewsnetwork',
#    'zionnationalpark',
#    'MissItalia2018',
#    'amputoitu',
#    'tasaarvo',
#    'withoutlimits',
#    'llifewithoutlimits',
#    'ゼロ一獲千金ゲーム大好き',
#    'ゼロ一獲千金ゲームありがとう',
#    'SkyFam',
#    'BirdClan',
#    'Tkunda',
#    'Execs',
#    'mariokartmushroomdick',
#    'Maheshbabu',
#    'biblia',
#    'changethenarrative',
#    'declassifyfisa',
#    'pp',
#    'BOBBY',
#    'JIWON',
#    '김지원',
#    '바비',
#    'SECOND',
#    'SOLO',
#    'MTWGA',
#    'REAGAN',
#    'Wrecked',
#    'MarioKartPenis',
#    'REALTOR',
#    'September18',
#    'Dollars',
#    'Humility',
#    'Stronger',
#    'Kern',
#    'SPÖ',
#    'trumptweets',
#    'sensual',
#    'అమ్మాయిలు',
#    'BaaghiTV',
#    'Baudet',
#    'PuertoRican',
#    'MoefiHighSchool',
#    'Mabalstad',
#    'Rustenburg',
#    'satanism',
#    'PJLFraude',
#    'Lactalis',
#    'familiesbelongtogether',
#    'LogicFTW',
#    'GameTheory',
#    'Stablecoin',
#    'geminiusd',
#    'ترمب',
#    'Xero',
#    'blind',
#    'AmericanCitizen',
#    'Support45',
#    'ObamaSucks',
#    'METAL',
#    'kiki',
#    'keke',
#    'inmyfeelings',
#    'VENEZUELA',
#    'IranSacntions',
#    '若おかみは小学生',
#    'furnituredesign',
#    'balmain',
#    'ImranKhanPrimeMinister',
#    'PakistanZindabad',
#    'SA',
#    'JointStatement',
#    'электрогитара',
#    'アンモニア',
#    '車',
#    'AboutThatWall',
#    'Eigo',
#    'Eikaiwa',
#    'JFKNewYork',
#    'ELECTED',
#    'LAR',
#    'RedVote',
#    'doublestandard',
#    'TomMacArthur',
#    'citylights',
#    'feel',
#    'ever',
#    'HazmatWasCalled',
#    'SettingTheAgenda',
#    'kartarpursahib',
#    'RussianRestaurant',
#    'Podkova',
#    'leapinthepast',
#    'cartadaparati',
#    'volgomilano',
#    'SDV',
#    'NuclearWeapons',
#    'geopolitics',
#    'BenGamel',
#    'HeartofALion',
#    'Tur',
#    'truthinmusic',
#    'ganja',
#    'Airindia',
#    'Henderson4Heisman',
#    'お譲り',
#    'AmericanHero',
#    'Lexmark',
#    'printer',
#    'NotRight',
#    'FurtherNetwork',
#    'Hermosillo',
#    'xalfollow',
#    'Indeed',
#    'AUDUSD',
#    'ゴーちゃん',
#    'capable',
#    'FollowMe',
#    'lesestoff',
#    'DumpCruz',
#    'NawazShareef',
#    'dharmshala',
#    'Contractors',
#    'innerwork',
#    'healingworkshop',
#    'meherbaba',
#    'LatinosforTrump',
#    'FESX',
#    'FDAX',
#    'GC',
#    '6E',
#    'manchester',
#    'pesticides',
#    'SHOP',
#    'Fastandfurious',
#    'VernonHills',
#    'renewal',
#    'ImmigrantChildren',
#    'undergroundhiphop',
#    'undergroundrap',
#    'bonesquad',
#    'bonesquaddynasty',
#    'UserExperienceDesign',
#    'channel4news',
#    'CEFAN',
#    'Erde',
#    'Scheibe',
#    'Impfen',
#    'Homöopathie',
#    'GüzelKızlarTwitarttirComda',
#    'GDL',
#    'shinee',
#    'sw2013',
#    'sw2012',
#    'ftisland',
#    'galaxyprint',
#    'pincollection',
#    'cosmic',
#    'pastelgoth',
#    'Extract',
#    'reklame',
#    'rebels',
#    'hopes',
#    'Realitytherapy',
#    'TV9Kannada',
#    'LaurenceFishburne',
#    'Steal',
#    'IVotedForYou',
#    'IBelieveInYou',
#    'ITrustYou',
#    'IWillVoteForYouIn2020',
#    'louisck',
#    'Tr',
#    'GarthBrooks',
#    'townhall',
#    'bert',
#    'Unmasked',
#    'Viswasam',
#    'தல',
#    'விஸ்வாசம்',
#    'GovernoDelCambiamento',
#    'CivilizationVI',
#    'georgebushsr',
#    'indictments',
#    'arethafranklin',
#    'internationalstudent',
#    'thestrip',
#    'Öl',
#    'Baghdad',
#    'T4US',
#    'Qdrop',
#    'Centre',
#    'pojokpitu',
#    'making',
#    'witchcraft',
#    'TESS',
#    'PathologicalLiar',
#    'ジャニーズJr',
#    'insideraz',
#    'ketchup',
#    'LIBERALISMISCONFUSION',
#    'ENOUGHLIBERALSENOUGH',
#    'Morena',
#    'dirtbag',
#    'ARMEDCITIZEN',
#    'goodjob',
#    'امریکا',
#    'NintendoSwitchOnline',
#    'FairGame',
#    'insmedia',
#    'Legalizeit',
#    'CodeRed',
#    'dronevideo',
#    ...]),
#  (3,
#   ['airliner',
#    'DCNative',
#    'TheREALCollusion',
#    'RSA',
#    'publiclands',
#    'sacrifices',
#    'GOPisComplicit',
#    'cringe',
#    'FeaturedBig',
#    'broadband',
#    'EXECUTE',
#    'FinancialFreedom',
#    'surgery',
#    'Kraken',
#    'Radicalism',
#    'KimJungUn',
#    'November8th',
#    'Cosby',
#    '慶ちゃんが大好き',
#    'votevets',
#    'aclu',
#    'godbless',
#    'hypocritical',
#    'immoral',
#    'bigots',
#    'ゲーム',
#    'konami',
#    'コナミ',
#    'kauppasota',
#    'Rainmakersunite',
#    'DUPAMP',
#    'Radical',
#    'Yetipubes',
#    'crack',
#    'Oath',
#    'IDontBelieveHer',
#    'MadHatters',
#    'Southend',
#    'DemocratsGoingCrazy',
#    'theResistance',
#    'crimefiction',
#    'SLR',
#    'blog_jp',
#    'fc2',
#    'YouthSafety',
#    'spoilme',
#    'Priorities',
#    'Bringdownthehouse',
#    'Dooo',
#    'SgtHeiligUSMC',
#    'CD入荷情報',
#    'ThankyouAmericans',
#    'muslims',
#    'PVV',
#    'naftawatch',
#    'LetsGetAfterIt',
#    '35mm',
#    'oval',
#    'TrumpCult',
#    'soldiersinrevolt',
#    'vietnamwar',
#    'truthmatters',
#    'Neoliberalism',
#    'BuildTheWave',
#    'Downtown',
#    'Skyline',
#    '選挙に行こう',
#    '参院選',
#    'InsultToRealVictims',
#    'homestay',
#    'brokenheart',
#    'MAGAWarriors',
#    'HPE',
#    'ProLiant',
#    'AzureStack',
#    'MiniXDA',
#    'OPPO',
#    'BrettKavanaughConformation',
#    'Hope4Fairness',
#    'Store',
#    'Stores',
#    'Owners',
#    'RelubliCONS',
#    'Yelp',
#    'devilsdaughters',
#    'h1bvisa',
#    'YOMKIPPUR',
#    'Abuse',
#    'fresnostatedc',
#    'Beno',
#    'DEMSRDONE',
#    'audirs6',
#    'rs6',
#    'sportcar',
#    'sportscar',
#    'matteblack',
#    'Chess',
#    'creatives',
#    'ComradeTrump',
#    'Cher',
#    'virgo',
#    'Pricing',
#    'Beverage',
#    'Determined',
#    'ObstructJustice',
#    'KarenMcDougal',
#    'PakvsInd',
#    'Buzzzzzzzz____Swat',
#    'trumpconcentrationcamps',
#    'Confirmation',
#    'TelephoneAVeteranTuesday',
#    'TelephoneAVetTuesday',
#    'iSBU',
#    'TAVT',
#    'elenunca',
#    'porter',
#    'AmericanRevolution',
#    'TrayvonMartinStory',
#    'Vega411',
#    'Welcome_to_Iran_Tasavof_Empire',
#    'इंदौर',
#    'playlist',
#    'AyeSupportTheUsoDoe',
#    'PeaceInKorea',
#    'RemoveHR392',
#    'trekking',
#    'FeelsGood',
#    'wage',
#    'offer',
#    'breakingNews',
#    'TreasonousBastard',
#    'flockbn',
#    'Daniels',
#    'HeSaidThat',
#    'govote',
#    'PVAC',
#    'NigelFarage',
#    '賭博覇王伝零',
#    'fkmt',
#    'impressions',
#    'neveragainmovement',
#    'weareCBA',
#    'StoptheBias',
#    'train',
#    'Ministry',
#    'TheStormIsComing',
#    'LivePodcast',
#    'rainbowtrout',
#    'affirmations',
#    'indapendent',
#    'AmericanDream',
#    '少クラP',
#    'dallascowboys',
#    'nippon',
#    'dnc2018',
#    'MKGA',
#    'shooter',
#    'three',
#    'goa',
#    'hughhefner',
#    'playboy',
#    'ladygirl',
#    'vigor',
#    'playboybunnies',
#    'candles',
#    'Oxfam',
#    'MX',
#    'packagingdesign',
#    'HispanicforTrump',
#    'ResistTheResistance',
#    'Las',
#    'Aires',
#    'piscis',
#    'プレイパス',
#    'boot',
#    'iamstillwithher',
#    'NoVoterFraud',
#    'NoCaliforniaDemocrats',
#    'NoSanctuaryCities',
#    'NoSafeSpaces',
#    '緊急地震速報',
#    'NEWS速',
#    'Defund',
#    'CDNpoli',
#    'cheeky',
#    'spunk',
#    'Issues',
#    'DemsWork4USA',
#    'Discredit',
#    'HusBeard',
#    'WeAreThePeople',
#    'TrumpTreasonInPlainSight',
#    'blackops4',
#    'blackout',
#    'OPMAYFLOWER2018',
#    'PutridInPink',
#    'h',
#    'whore',
#    'backpack',
#    '真相传媒',
#    '魔鬼在統治著我們的世界',
#    '共產主義',
#    '共產邪靈',
#    '社會主義',
#    '全球化',
#    '政治正確',
#    '真相',
#    '真相傳媒',
#    'UnhingedProgressives',
#    'Okinawa',
#    'cena',
#    'Mafia',
#    'elephant',
#    'boeing',
#    'Ganesh',
#    'GanpatiBappaMorya',
#    'rekt',
#    '비주얼가이드',
#    '엑스포츠뉴스',
#    'likeforfollow',
#    'DeathPenalty',
#    'trumpadministration',
#    'x22',
#    'frankwuco',
#    'Enlightenment',
#    'foggy',
#    'shareholders',
#    '森本慎太郎',
#    'PoliticalCorrectness',
#    'estinzione',
#    'sinistra',
#    'TOpoli',
#    'MissItalia',
#    'NewsPaper',
#    'ThanksGOP',
#    'PuntoCentralLuzon',
#    'golfbag',
#    'setagayabase',
#    'Vijayawada',
#    'INDVSHK',
#    'Eritrean',
#    'RioBravo',
#    'rnb',
#    'tamaulipas',
#    'PrabowoSandi',
#    'CA25',
#    'xlm',
#    'トラジャ',
#    'ゲリラ豪雨',
#    'ミュージカル風',
#    'ユメノトビラ',
#    'Isreal',
#    'customerservice',
#    'Export',
#    'MakeAmericaSafeAgain',
#    'JOHNJAMES',
#    'OnlyTheRealest',
#    'NANA',
#    'Carter',
#    'everyday',
#    'set',
#    'DoSomething',
#    'reaction',
#    'OILPAINTING',
#    'HOLOGRAPHIC',
#    'wasting',
#    'DonaldDuck',
#    'thejamericantraveler',
#    'travelers',
#    'GoogleCardboard',
#    'MrRecovery',
#    'shtf',
#    'SilsilaBadalteRishtonKa',
#    'Leftism',
#    'Nahles',
#    'ดวงใจในไฟหนาว',
#    'WAŻNE',
#    'buildings',
#    'hangem',
#    'ASKTHEQ',
#    'YogiAdityanath',
#    'uplatestnews',
#    '2D',
#    'detailing',
#    'KrisWuFirstAlbum',
#    'Anitters',
#    'abortionIsMurder',
#    'M4BL',
#    'Insegnacicomesivola',
#    'I75',
#    'Airports',
#    'KingPower',
#    'RelationshipRedFlags',
#    'OpISIS',
#    'alcinema',
#    'DarkToLIGHT',
#    'Mypresident',
#    'azpresident',
#    'Azərbaycan',
#    'PPM',
#    'negative',
#    'liveleak',
#    'patrol',
#    'SOUL',
#    'LuckyCat',
#    'ListenTo',
#    'RoevWade',
#    'Trumpshroom',
#    'GetTheRedOut',
#    'ashokanews',
#    'can',
#    'Catolicos',
#    'socal',
#    'JPFO',
#    'gadets',
#    'AnneHathaway',
#    'goverment',
#    'Troublemakers',
#    'Mistress',
#    'Pregnant',
#    'fallen',
#    'G20Summit',
#    'VOTEREDORWERDEAD',
#    'ninjabot',
#    'MeTooLynchings',
#    'WeWontStop',
#    'RatShitFBI',
#    'Gestapo',
#    'SUPPORTATX',
#    'Banger',
#    'DJSLASHA999',
#    'drunk',
#    'SenBobCorker',
#    'credible',
#    'Anniversaire',
#    'Periodismo',
#    'diploma',
#    '정국이는_9월의_첫번째_기적',
#    'coachrieken',
#    'burbankca',
#    'debtfree',
#    'UseCasesVerticals',
#    'война',
#    'Attitude',
#    'teamFiji',
#    'ShowUp',
#    'reach',
#    'TSG',
#    'SSO',
#    'declassification',
#    'CourtneyHadwin',
#    'BabulSupriyo',
#    'MAGAVOTE',
#    'TrumpKnew',
#    'MarbledCrayfish',
#    'HillaryRottenClinton',
#    'Newark',
#    'socialists',
#    'Identity',
#    'flyfisherman',
#    'truthisviral',
#    'crystal',
#    'Brian',
#    'Futurología',
#    'brilliant',
#    'marchforourlives',
#    'brew',
#    'IVANKA',
#    'NetworkMarketing',
#    'Violence',
#    'BarackHussein',
#    'Sweet',
#    'iphonesia',
#    'travellingwithkids',
#    'qt',
#    'iPhones',
#    'Biya',
#    'tRumpResign',
#    'ComieIsMyHomie',
#    'Alumni',
#    'Guangzhou',
#    'InternationalDayofDemocracy',
#    'Natural',
#    'Cuomo',
#    'typography',
#    'texasrangers',
#    'clueless',
#    'CB4G',
#    'Palplus',
#    'MadeinChina',
#    'paragon',
#    'fatal',
#    'fakeNews',
#    'FORD',
#    'holland',
#    'falseflag',
#    'girlfriend',
#    'PatriotDay',
#    'dm',
#    'sportsnews',
#    'railroad',
#    '勝山',
#    'Vertrieb',
#    'JL',
#    'JFL',
#    'JNL',
#    'JL999',
#    'Julius',
#    'JuliusLeineweber',
#    'Leineweber',
#    'Lancia',
#    'Stratos',
#    'rallye',
#    'serial',
#    'BestFriends',
#    'ReleaseTheDocumentsNow',
#    'DeepTech',
#    'z',
#    'Foreign',
#    'Investor',
#    'TechnologyNews',
#    'afternoon',
#    'policing',
#    '虹のコンキスタドール',
#    'kills',
#    'ProphetMuhammad',
#    'Siblings',
#    'Couples',
#    'RT_America',
#    'rational',
#    'TrendingNews',
#    'Section377',
#    'yum',
#    'MAGATrash',
#    'Mangkhut',
#    'HK',
#    'ruger',
#    'colt',
#    'Localgov',
#    'scenes',
#    'CivilEngineering',
#    'UAE_In_Yemen',
#    'โน่ณิ',
#    'paidleave',
#    'postpaid',
#    'lanzamientosny',
#    'Salisbury',
#    'queens',
#    'insect',
#    'standintheway',
#    'packing',
#    'PranaEnergieTherapyie',
#    'SpiritualJewelry',
#    'Bentley',
#    'Arnage',
#    'Oneness',
#    'catholicchurch',
#    'priests',
#    'LK',
#    '留学',
#    'Antifascist',
#    'hyderabad',
#    'JusticeForBothamJean',
#    'asbestos',
#    'suit',
#    'ZA',
#    'mystock',
#    'ThankYouForYourService',
#    'strengths',
#    'use',
#    'NS',
#    'MamnoonHussain',
#    'teachings',
#    'GRAY',
#    'WilburRoss',
#    'karlyletomms',
#    'VOTEGOP',
#    'BarakObama',
#    'Bluzelle',
#    'BestActressInADrama',
#    'Sprinkles',
#    'StandWithBrett',
#    'DN',
#    'lamp',
#    'StanfordUniversity',
#    'ASKtheQ',
#    'echinocereusonline',
#    'echinocereus',
#    'WeStandStrong',
#    'TheKingLives',
#    'WeWin',
#    'JesusRules',
#    'NoWeapon',
#    'ourGodreigns',
#    'MarioKartMushroom',
#    'spiritualawakening',
#    'lifeculture',
#    'NewEarth',
#    'michaelbrown',
#    'board',
#    'celebration',
#    'tank',
#    'Edition',
#    'comfy',
#    'tourlife',
#    'Liberalsaredangerous',
#    'EmoPop',
#    'PRESIDENT_TRUMP',
#    'riders',
#    'LindsayGraham',
#    'drift',
#    'terrariumtv',
#    'hamburg',
#    'illegals',
#    'shortstories',
#    'MarkJudgeTestify',
#    'Cumberland',
#    'gapyear',
#    'childhoodtrauma',
#    'youarestrong',
#    '台灣',
#    'Kozinski',
#    'miui',
#    'miui10',
#    'rollout',
#    'side',
#    'RafaleDeal',
#    'PrivateSchools',
#    'Fee',
#    'fighter',
#    'kickboxing',
#    'Urbana',
#    'bling',
#    'Mussolini',
#    'pout',
#    'LovingYouLovingOnMe',
#    '友達になりませんか',
#    'MARINESagainstTrump',
#    'VeryFakeNews',
#    'automata',
#    'Humout',
#    'ICT',
#    'Forum',
#    'BETOFORTEXAS',
#    'kpopvote',
#    'girlgroup',
#    'kpopgirl',
#    'Ceewai',
#    'Femdom',
#    'threeway',
#    'fuckus',
#    'threesome',
#    'bisexual',
#    'hottie',
#    'cocktribute',
#    'bigroom',
#    'TARIFFS',
#    'Noise',
#    'AlexandreBenalla',
#    'Trump2018',
#    'IshqSubhanAllah',
#    'espresso',
#    'florist',
#    'MensRights',
#    'TeenyWeeny',
#    'COMPLICIT',
#    'KFC',
#    'hi',
#    'GodSpeed',
#    'VictimShaming',
#    'Omniturm',
#    'ThingsTrumpSay',
#    'IAmTrump',
#    'IWin',
#    'MarriottAmericas',
#    'GOPGrowAPair',
#    'Pussy',
#    'ProudDreg',
#    'Darien',
#    'astrologia',
#    'Ads',
#    'Path',
#    'toaddick',
#    'DemoRATS',
#    'livefree',
#    'verdad',
#    'plannedparenthood',
#    'ALBUM',
#    'WEATHER',
#    'youcandoit',
#    'theory',
#    'ETHL',
#    'ETHLIMITED',
#    'artistsofinstagram',
#    'artisfun',
#    'twitterart',
#    'deathvalley',
#    'explosion',
#    'Österreich',
#    'Says',
#    'Guadalupe',
#    'Watergate',
#    'TrumpTerror',
#    'MichaelFlynn',
#    'Album',
#    'BaijayantPanda',
#    'KennyArmano',
#    'mushrooms',
#    'PTS',
#    'smallbusinesses',
#    'broadcasting',
#    'Scholarship',
#    'Croatian',
#    'Definition',
#    'bestfriend',
#    'thea',
#    'işdünyası',
#    'DFL',
#    'beyounique',
#    'su',
#    'lingerie',
#    'speakthetruth',
#    'bgm',
#    'Virgin',
#    'milan',
#    'Bussnines',
#    'hotnews',
#    'networkmarket',
#    'Sanctimonious',
#    'peacemaker',
#    'ternana',
#    'ALLLIVESMATTER',
#    'jesuslovesyou',
#    'TransformingDemocracy',
#    'Landlords',
#    'Realtors',
#    'Dinner',
#    'DemocratsSUCK',
#    'Complain',
#    'Blame',
#    'TechnologyTimes',
#    'igdayly',
#    'Remittance',
#    'Cashaa',
#    'CAS',
#    'Retirement',
#    'GST',
#    'saint',
#    'MOGOP',
#    'SixTONES',
#    'pedophiles',
#    'birdsofinstagram',
#    'Alt',
#    'SI',
#    'bees',
#    'JustDidIt',
#    'KS02',
#    'Pubs',
#    'nofap',
#    'pins',
#    'wicca',
#    'wiccan',
#    'WeAreFull',
#    'WeWelcomeYouLEGALLY',
#    'CERN',
#    'tapalkuda',
#    'madura',
#    'conditions',
#    'Base',
#    'Seat',
#    'Tonight',
#    'Anniversary',
#    'controversy',
#    'uswahl20',
#    'Atlas',
#    'AxisBank',
#    'Shares',
#    'Civilians',
#    'bewegung',
#    'Wahrheit',
#    'mistress',
#    'pokemongo',
#    'Raccoon',
#    'azerbaijan',
#    'spaceforce',
#    'ISRO',
#    'newpost',
#    'Recipients',
#    'padman',
#    'educational',
#    'CrimeSeries',
#    'Vitusspeakz',
#    'Righter',
#    '20years',
#    'veuvecliquot',
#    'champagnecake',
#    'TheGuardian',
#    '写真シェアGO',
#    '松井玲奈',
#    'brexitshambles',
#    'Taekwondo',
#    'DET',
#    'SOROS',
#    'фото',
#    'mexicans',
#    'offset',
#    'Redpill',
#    'CPO',
#    'britisharmy',
#    'PresidentialPenis',
#    'Ishqbaaz',
#    'ILLUMINATI',
#    'tarotvisa',
#    'THFC',
#    'internetofthings',
#    'WTC',
#    'KaranSinghGrover',
#    'urbanart',
#    '赤黒チェック',
#    '仲良しDAPUMP',
#    'salem',
#    'Investments',
#    'IIoT',
#    'brands',
#    'AKARI',
#    'Lion',
#    'セクガルと繋がりたい',
#    'AkusSchool',
#    'Childdevelopment',
#    'ReligiousEdu',
#    'step',
#    'biography',
#    'shine',
#    'rocks',
#    'nationalpark',
#    'igersthailand',
#    'thailand_ig',
#    'insta_thailand',
#    'thailand_allshots',
#    'amazingthailand',
#    'bangkokstuff',
#    'Levante',
#    'vent',
#    'MehdiHasan',
#    'Videos',
#    'onlinemarketing',
#    'bagels',
#    'MaltaBlockchainSummit',
#    'BOOTH62',
#    'QB',
#    'NCC',
#    'GOSPEL',
#    'MopsBuckets',
#    'DominiqueStraussKahn',
#    'USTeatre',
#    'USLibelLaws',
#    'brooklynbridge',
#    'アメリカンダイナー',
#    'BusinessOwner',
#    'StAustellVoice',
#    'StAustell',
#    'Briton',
#    'Dinmark',
#    'SouthSudan',
#    'ilSinonimo',
#    'AAP',
#    'Blended',
#    'libspill',
#    'mosques',
#    'tirane',
#    'mencek',
#    'Heinz',
#    'happen',
#    'Which',
#    'Mayonnaise',
#    'Insitu',
#    'UAVreports',
#    'PMImranKhan',
#    'Epic',
#    'XOXO',
#    'CNNisFakeNews',
#    'enscred',
#    'colourpop',
#    'LEADERSHIP',
#    'del',
#    'panam',
#    'parisnord',
#    'MakeNigeriaGreat',
#    'MNG',
#    'EllaDraper',
#    'Hampstead',
#    'scredconnexion',
#    'ForeignTrade',
#    'PIA',
#    'AirHostess',
#    'Escaped',
#    'Wave',
#    'PARANORMAL',
#    'louisiana',
#    'PIL',
#    'Billions',
#    'bookiekiller',
#    'Cuff',
#    'Tryon',
#    'storms',
#    'sevenandcounting',
#    'おともだちください',
#    'アニメ好きと繋がりたい',
#    'cryptomeme',
#    'cryptocurrencymeme',
#    'catalunya',
#    'murdoch',
#    'Vijayakranthi',
#    'northamerica',
#    'DXInformation',
#    'plaid',
#    'TodayInChina',
#    'Code',
#    'Begin',
#    'OneOnOne',
#    'IGNORANCE',
#    'BlackHops',
#    'Work4Bobs',
#    'nepal',
#    'siderablockchain',
#    'CBDnews',
#    'acrylics',
#    'Petrol',
#    'CHANGE',
#    'Bless',
#    'EstateAgent',
#    'AMG',
#    'VP',
#    'makemoneynow',
#    'affiliates',
#    'Remodeling',
#    'Covington',
#    'Luthern',
#    'SFV',
#    'SameSex',
#    'ObamaFraud',
#    'TeamMorse',
#    'thailandnews',
#    'Китай',
#    'inkedcovergirl',
#    'tired',
#    'Salons',
#    'НАТО',
#    'Dumptrump',
#    'redroses',
#    'qanon8chan',
#    'confident',
#    'PLEASE',
#    'invendita',
#    'enventa',
#    'للبيع',
#    'ITALY',
#    'GERMANY',
#    'SWEDEN',
#    'StockMarkets',
#    'Pocahontas',
#    'usagirlss',
#    'lovingithere',
#    'feelslikehome',
#    'tannedgirl',
#    'SCJ',
# ...
#    'MuMuMama',
#    'Progressive',
#    'Norfolk']),
#  (156, ['right', 'UnitedStates', 'science']),
#  (157, ['TX', 'niagarafalls', 'Police', 'eu', 'Chinese']),
#  (158, ['Science', 'markets', 'usarmy', 'Fascism', 'pcexpander', 'graphic']),
#  (159, ['Poll', 'Macron', 'uk']),
#  (160, ['giveaway', 'deepstate', 'Gaza', 'Qanon8chan', 'Ravens', 'ots']),
#  (161, ['twitter', 'Flowers']),
#  (162, ['education', 'SanFrancisco', 'FakeNewsMedia']),
#  (163, ['Bernie', 'Forex', 'entrepreneur', 'people', 'Android']),
#  (164,
#   ['LiberalismIsAMentalDisease',
#    'Islam',
#    'gunsense',
#    'WitchHunt',
#    'WalkAwayFromDemocrats2018',
#    'Iowa',
#    'Cuba',
#    'DregOfSociety']),
#  (165, ['MintToBe', '慶ちゃん頑張れ', 'общество']),
#  (166,
#   ['London', 'war', 'trending', 'JudgeKavanaugh', 'BruselasNosPillaDePaso']),
#  (167, ['Sales', 'chicago', 'Minnesota', 'Winner']),
#  (168, ['sky', 'KavanaughForSCOTUS', 'Palestinian', 'ข่าววันนี้', 'Jack']),
#  (169, ['allnews24', 'NEWSファンと繋がりたい', 'MarineOne']),
#  (171, ['democrat', 'vintage']),
#  (172,
#   ['HiillaryWon',
#    'Google',
#    'atheistrollcall',
#    'atheistpics',
#    'Marketing',
#    'Thala',
#    'trumptrain',
#    'Hounews']),
#  (173,
#   ['希望～yell～',
#    'Benghazi',
#    'beautiful',
#    'KimJongUn',
#    'Patriarchy',
#    'TrumpTweetTruck']),
#  (174, ['ClintonFoundation', '慶ちゃんに愛届け隊', 'Deplorables', 'BoycottNetflix']),
#  (175, ['HumanRights']),
#  (176, ['economy', 'BlueTsunami2018', 'china', 'Fiverr']),
#  (177, ['InternetBillOfRights']),
#  (178, ['deal']),
#  (179,
#   ['LiberalismIsAMentalDisorder',
#    'Follow',
#    'wisdom',
#    'stillyes',
#    'ScotRef',
#    'EXO']),
#  (180, ['FollowTheWhiteRabbit', 'Right', 'democrats', 'gun', 'greenparty']),
#  (181, ['KSA', 'わーーーージャニオタさんと繋がるお時間がまいりましたいっぱい繋がりましょ', 'p2', 'Libdems']),
#  (182,
#   ['Gossip',
#    'artist',
#    'quotes',
#    'market',
#    'OpenSelection',
#    'MOG',
#    'Retweetforawareness']),
#  (183, ['中国', 'PuertoRico']),
#  (184, ['GoLive', 'EggDrp', 'JESUS', '手越くん']),
#  (185, ['WordPress', 'ISIS']),
#  (186, ['Wisconsin', 'TrumpLies', 'readmisionya', 'indyref2']),
#  (187, ['humor', 'books', 'TrumpsArmy', 'today']),
#  (188, ['health', 'MAGA2020']),
#  (189, ['TRUMP2020', 'Anime', 'cdnpoli', 'lockherup', 'DFS']),
#  (190, ['NastyWomen']),
#  (191, ['kavanaugh', 'PanicInDC', 'BackTheBlue', 'MustVote2018', 'AF1']),
#  (192, ['YeastInfestedPussySuits', 'NYC']),
#  (193, ['connectsindonesia']),
#  (194, ['ChristinaBlaseyFord']),
#  (195, ['USarmy', 'reuters', 'Hiking']),
#  (196, ['inspiration', 'Pedogate']),
#  (197,
#   ['NYT', 'Gist', 'Georgia', 'ObamaGate', 'BrettKavanuagh', 'ComfortInn']),
#  (198, ['startup', 'Washington', 'Palestinians', 'USBiz']),
#  (199,
#   ['trump2020',
#    'CCOT',
#    'realDonaldTrump',
#    'DianaMarySharpton',
#    'Asia',
#    'Libertarian',
#    'Restart']),
#  (200, ['ImstillwithHer', 'PAD', 'sports', 'TrumpTrain2020', 'NEvsDET']),
#  (201, ['NewJersey', 'Fashion', 'めざましテレビ', 'MakeNoMistake', 'MAGASwaGGa']),
#  (202, ['DemForce', 'AnitaHill', 'it', 'plaidcymru', 'snp']),
#  (204, ['IndianArmy', 'チャンカパーナ', 'success', 'Wales']),
#  (205, ['blacklivesmatter', 'Dallas']),
#  (206, ['pjnet', 'AIRPOWER', 'media', 'hiphop', 'Startup']),
#  (207, ['maternity']),
#  (208, ['Maine']),
#  (209, ['Women', 'Clinton', 'AirForceOne']),
#  (210, ['Bible', 'Sessions', 'finance', 'atheist', 'RESPECT', 'Nachrichten']),
#  (211, ['AI', 'ElectricVehicle', 'Australia', 'atheism', 'Kavanagh']),
#  (212, ['ゼロエピソードZERO']),
#  (213, ['MAGA2018', 'Dagga']),
#  (214, ['follow', '2a']),
#  (215, ['blog', 'pray', 'rt', 'forex']),
#  (216,
#   ['Peace',
#    'TrustThePlan',
#    'AFBDay',
#    'YudhAbhyas2018',
#    'fishing',
#    'pedogate']),
#  (217,
#   ['tRump',
#    'Mexico',
#    'gaming',
#    'fakenews',
#    'Indies',
#    'PremioLiterario',
#    'Oferta']),
#  (218, ['SmellGists', 'eBooks']),
#  (219, ['ThankYou', 'BTS']),
#  (220, ['Ford', 'honor', 'KeepAmericaGreat', 'Gaming']),
#  (221, ['FISADeclassification']),
#  (222, ['political', 'beauty', 'Nowplaying', 'Killary']),
#  (223, ['Markets', 'donaldtrump', 'history', 'Scotland']),
#  (224, ['VoteGOP']),
#  (225,
#   ['BetoForTexas', 'UAE', 'PrayForOurLeaders', 'PrayForUSA', 'aboluowang']),
#  (226, ['Feinstein', 'Christian', 'PrayForPotus']),
#  (229, ['Africa', 'Sunrise', 'Fight']),
#  (230, ['SuperSaiyan', 'コヤシゲ']),
#  (232, ['Houston', 'OBAMA', 'ZIP']),
#  (233, ['Religion', 'etsy', 'speakerryan', 'Technology']),
#  (234, ['Owens', 'ConfirmJudgeKavanaugh', 'peace', 'tony4wi', 'scottwalker']),
#  (236, ['liberals', 'BetoforTX']),
#  (237, ['novasocialnews']),
#  (238, ['SouthAfrica']),
#  (239, ['Amazon', 'MarioKart', 'apple', 'Democratic']),
#  (240, ['trading', 'History', '2ADefenders']),
#  (241, ['ドリフェス2018円盤化希望', 'Education', 'England']),
#  (242, ['GA']),
#  (243,
#   ['PlannedParenthood',
#    'ImWithHer',
#    'VoteBlueToSaveAmerica',
#    'ChooseCruz',
#    'abortion']),
#  (244, ['DianeFeinstein']),
#  (245, ['ConfirmJudgeKavanaughNow', 'FTrump']),
#  (246, ['election', 'Sunset', 'Benalla']),
#  (248, ['TRUMPTRAIN', 'Finance']),
#  (249, ['DemocratsHateAmerica', 'MEGA', 'AMAZON']),
#  (250, ['investing', 'share']),
#  (251, ['stocks', 'TheRainMakers']),
#  (253, ['guncontrol', 'NEWSニッポン']),
#  (254, ['PATRIOTS', 'tedcruz', 'PastorAndrew']),
#  (255, ['TakeAKnee', 'DrFord', 'JOBS']),
#  (256, ['fucktrump', 'MerrickGarland', '慶ちゃん']),
#  (257, ['metoo', 'Liberty', 'Germany']),
#  (259, ['BigOlFamily', 'free', 'Opinion']),
#  (260, ['Photography', 'BigTimeRadio', 'teropongsenayan']),
#  (261, ['AskTheQ', 'TedCruz']),
#  (262, ['USFA', 'BlackTwitter', 'ハロウィン音楽祭', 'FlipItBlue', 'GodsArmy']),
#  (264, ['Detroit']),
#  (265, ['味の素スタジアム円盤化希望', 'IFB', 'JESUSLIVES']),
#  (266, ['auspol']),
#  (267, ['AlternativeFacts']),
#  (268,
#   ['India',
#    'France',
#    'IllegalAliens',
#    'quote',
#    'MuellerInvestigation',
#    'Midterms',
#    'Usa']),
#  (269, ['cascade', 'Tennessee']),
#  (271, ['Blockchain', 'nature']),
#  (272, ['Eagles', 'Deplorable']),
#  (273, ['photography', 'FoxAndFriends']),
#  (275, ['Corruption']),
#  (276, ['PrescientInfo', 'Beto']),
#  (277, ['Maddow']),
#  (280, ['Twitter', 'ドリフェス', 'SupremeCourt', '1A']),
#  (282, ['갓세븐', 'feathers']),
#  (283, ['Europe', '慶ちゃん応援隊']),
#  (284, ['DeepStateExposed', '嵐', 'conservative']),
#  (285, ['WalkAwayFromDemocrats', 'SpecialElectionWin', 'SenateSeat']),
#  (286, ['Impeach45', 'obama']),
#  (287, ['RedWaveRising2018', 'EU', 'veteran', 'blockchaintechnology']),
#  (290, ['bbjinsight', 'NBC', 'motivation']),
#  (292, ['Jesus', 'NorthKorea', 'テゴマスのらじお']),
#  (293, ['NotMyPresident', 'FL']),
#  (295, ['Iranian']),
#  (297, ['NeverTrump']),
#  (298, ['Relaxing', 'Walking', 'Hikes']),
#  (299, ['FISAgate', 'World']),
#  (300, ['BlueTsunami']),
#  (301, ['women', 'ICYMI', 'Manafort', 'WorstPresidentEver']),
#  (303, ['Austin']),
#  (304, ['money']),
#  (306, ['Ohio', 'Yemen']),
#  (307, ['ReadmisionYa']),
#  (308, ['FoxNews', 'NEWS速報JAPAN']),
#  (310, ['liberty']),
#  (311, ['cnn']),
#  (317, ['Turkey']),
#  (319, ['EEUU', 'Istandul']),
#  (320, ['JeffSessions']),
#  (321, ['ゼロ一獲千金ゲームエピソードZERO']),
#  (322, ['Poland', 'RESIST', 'instagram']),
#  (324, ['Collins', 'BlueWaveIsComing']),
#  (325, ['canada']),
#  (326, ['Duda', 'Senate', 'Pakistan']),
#  (327, ['Conservative', 'LJMAGA']),
#  (331, ['IT']),
#  (333, ['希望yell']),
#  (334, ['leadership', 'NP', 'NC']),
#  (335, ['winning']),
#  (336, ['Japan']),
#  (337, ['TalkLikeAPirateDay']),
#  (339, ['ProjectVeritas']),
#  (340, ['大野智', 'Fact']),
#  (341, ['Potus']),
#  (343, ['KAG2018', 'ABC', 'MSNBC', 'Healthcare']),
#  (345, ['パーナさんと繋がりたい', '中國']),
#  (347, ['KeepTexasRed']),
#  (348, ['BlueWaveComing2018']),
#  (349,
#   ['WhiteHouse', 'TheMoreYouKnow', 'TeaParty', 'faith', 'PedoGate', 'TUR']),
#  (352, ['SpyGate']),
#  (358, ['POTUS45']),
#  (360, ['Music', 'Relax']),
#  (366, ['LiberalLogic']),
#  (367, ['NY']),
#  (369, ['TXSen', 'prolife']),
#  (370, ['LockHerUp', 'breaking', 'notícia']),
#  (371, ['NorthCarolina', 'Spain']),
#  (374, ['TuesdayThoughts']),
#  (375, ['Maga']),
#  (376, ['deals']),
#  (384, ['LaUnionEsNuestraFuerza']),
#  (387, ['ゼロ一獲千金ゲーム続編希望']),
#  (391, ['1u']),
#  (392, ['Followback']),
#  (397, ['God']),
#  (398, ['PTSD']),
#  (400, ['president', 'AMERICA', 'DeepStateCorruption']),
#  (402, ['nowplaying', 'RoyMoore']),
#  (404, ['Life']),
#  (405, ['android', 'haberler']),
#  (407, ['VoteRed2018', 'Mueller']),
#  (408, ['慶ちゃん大好き']),
#  (409, ['Polish']),
#  (411, ['TEXAS', 'エンドレスサマー']),
#  (415, ['DeclassifyFISA', '小山キャスター復帰希望']),
#  (420, ['video', 'notizie', 'haber']),
#  (421, ['Noshowicus']),
#  (424, ['MorningJoe']),
#  (425, ['RNC']),
#  (428, ['Labour']),
#  (430, ['WelcomeTiffanyYoungtoThailand', 'TiffanyYoungFanMeetingTourBKK']),
#  (431, ['Election']),
#  (432, ['KavanaughConfirmation', 'ザ少年倶楽部プレミアム', 'Tech']),
#  (433, ['Pilecki']),
#  (434, ['Saudi']),
#  (435, ['RedNationRising', 'world']),
#  (439, ['Putin']),
#  (440, ['cryptocurrency']),
#  (442, ['官骗']),
#  (445, ['gop']),
#  (449, ['TrendingNow']),
#  (450, ['Jobs', 'PJNET', 'TrumpMan']),
#  (452, ['NEWSで妄想']),
#  (453, ['NEWSでお絵かき']),
#  (454, ['Photo']),
#  (455, ['liberal']),
#  (457, ['Treason']),
#  (458, ['BreakingNews']),
#  (461, ['crypto']),
#  (464, ['technology', 'Country']),
#  (467, ['拡散希望']),
#  (468, ['shoponline']),
#  (470, ['生きろ1位おめでとう']),
#  (471, ['Venezuela']),
#  (473, ['TheStorm']),
#  (474, ['Job']),
#  (477, ['QProofs']),
#  (478, ['希望～Yell〜']),
#  (479, ['EPCOTIA円盤化希望']),
#  (480, ['泛亚']),
#  (485, ['Business']),
#  (487, ['walkawayfromwalkaway', 'bigjujumedia']),
#  (488, ['Retweet']),
#  (492, ['PresidentTrump']),
#  (493, ['DumpTrump', 'Americans']),
#  (494, ['LockThemAllUp']),
#  (496, ['laugh']),
#  (499, ['lmao']),
#  (500, ['FortTrump', 'hilarious']),
#  (505, ['country']),
#  (506, ['WalkAwayDemocrats2018']),
#  (508, ['Chicago']),
#  (510, ['VoteDemsOut']),
#  (511, ['MSM']),
#  (512, ['Love']),
#  (518, ['america']),
#  (519, ['Florence']),
#  (523, ['Bitcoin']),
#  (524, ['tips']),
#  (526, ['NiUnSuicidioMasEnFFCCSEyFAS']),
#  (528, ['YesWeCan']),
#  (531, ['QuoteOfTheDay', 'Dobbs']),
#  (534, ['WINNING']),
#  (535, ['life', 'Crypto']),
#  (537, ['Army']),
#  (540, ['art']),
#  (542, ['reatilsales']),
#  (544, ['VOTERED2018']),
#  (545, ['Gratitude']),
#  (546, ['QPosts', 'ccot']),
#  (548, ['CoreaDelNorte']),
#  (556, ['DerogacionLey08_2006']),
#  (557, ['VoteThemOut', 'blockchain']),
#  (560, ['TRUTH']),
#  (563, ['Congress']),
#  (566, ['Liberal', 'BoozAllen']),
#  (567, ['lol']),
#  (570, ['kag']),
#  (575, ['ニュース']),
#  (576, ['Winning']),
#  (581, ['government']),
#  (586, ['Dems']),
#  (587, ['новости', 'MakeAmericaGreatAgain']),
#  (588, ['Iran']),
#  (591, ['EreEncubierto']),
#  (592, ['NFL']),
#  (596, ['Breaking']),
#  (597, ['TornadoTrump', 'music']),
#  (600, ['wwg1wga']),
#  (601, ['WednesdayMotivation']),
#  (604, ['FOLLOW']),
#  (609, ['sales', 'Constitution']),
#  (617, ['religion']),
#  (618, ['bluewave']),
#  (619, ['RedWave2018', 'Spartacus']),
#  (623, ['Hollywood']),
#  (629, ['DNC']),
#  (630, ['SD19']),
#  (635, ['work', 'Canada']),
#  (637, ['criminal']),
#  (640, ['Veteran', 'ReleaseTheDocs']),
#  (641, ['45SinDespidos']),
#  (644, ['QANON', 'walkaway']),
#  (646, ['Patriot']),
#  (647, ['conservatives']),
#  (651, ['DearProfessorFord']),
#  (653, ['resist']),
#  (655, ['RESISTANCE']),
#  (657, ['President']),
#  (658, ['Israel']),
#  (663, ['Russia']),
#  (667, ['bitcoin']),
#  (668, ['DrainTheDeepState']),
#  (671, ['feedly']),
#  (672, ['Liberals', 'NEWS担と繋がりたい']),
#  (673, ['TrumpRussia']),
#  (676, ['Trending']),
#  (681, ['FBR']),
#  (695, ['PromisesKept']),
#  (703, ['Brexit']),
#  (714, ['funny']),
#  (715, ['Syria']),
#  (719, ['WWI', 'cross']),
#  (722, ['Weather']),
#  (728, ['texas']),
#  (730, ['guns']),
#  (731, ['Antifa']),
#  (733, ['ShareJourney', 'ImpeachTrump']),
#  (735, ['StopKavanaugh', 'RedWave']),
#  (744, ['ChristineFord']),
#  (748, ['1W1Lツ']),
#  (756, ['strawberry', 'patriots']),
#  (764, ['jobs']),
#  (766, ['CatsOfTwitter']),
#  (774, ['RED']),
#  (775, ['FISA']),
#  (776, ['fitness']),
#  (782, ['CrookedHillary']),
#  (788, ['democracy']),
#  (794, ['ConfirmKavanaughNow']),
#  (795, ['marketing']),
#  (797, ['DerogacionLey08']),
#  (800, ['TraitorTrump']),
#  (802, ['UK']),
#  (805, ['TCOT']),
#  (809, ['WakeUpAmerica', 'Tripletalaq']),
#  (826, ['KAG2020']),
#  (828, ['Conservatives']),
#  (830, ['StormyDaniels']),
#  (831, ['GITMO']),
#  (834, ['tech']),
#  (836, ['FuckTrump']),
#  (837, ['NEWSRING']),
#  (840, ['Red']),
#  (856, ['TeamJohnJames']),
#  (858, ['BREAKING']),
#  (868, ['RedWaveRising']),
#  (869, ['Q', 'resistance']),
#  (878, ['military']),
#  (888, ['Nature']),
#  (891, ['breakingnews']),
#  (905, ['Walkaway', 'veterans']),
#  (923, ['travel']),
#  (926, ['WinBlue']),
#  (931, ['fashion']),
#  (942, ['Justice']),
#  (945, ['ProLife']),
#  (952, ['MAGAveteran']),
#  (969, ['BlueWave2018']),
#  (985, ['love']),
#  (992, ['DAPUMP']),
#  (993, ['CNN']),
#  (999, ['California']),
#  (1014, ['freedom']),
#  (1016, ['NosotrosLosSoldados']),
#  (1019, ['Republicans']),
#  (1041, ['Florida']),
#  (1045, ['Bring']),
#  (1049, ['NEWS15thAnniversary']),
#  (1056, ['gratitude']),
#  (1080, ['KEIICHIRO']),
#  (1083, ['BlackLivesMatter']),
#  (1095, ['USArmy']),
#  (1111, ['VoteBlue']),
#  (1115, ['Midterms2018']),
#  (1136, ['RT']),
#  (1145, ['KちゃんNEWS']),
#  (1149, ['希望〜Yell〜']),
#  (1155, ['Election2018']),
#  (1159, ['Cascade']),
#  (1164, ['Military', 'TheResistance']),
#  (1168, ['Government']),
#  (1195, ['Hillary']),
#  (1207, ['ดาราเดลี่']),
#  (1217, ['qanon']),
#  (1225, ['potus']),
#  (1227, ['business']),
#  (1228, ['GreatAwakening']),
#  (1232, ['KeithEllison']),
#  (1233, ['DOJ']),
#  (1248, ['VoteRedToSaveAmerica']),
#  (1267, ['Democracy']),
#  (1271, ['中山優馬']),
#  (1277, ['Travel']),
#  (1291, ['daradaily', 'ジャニーズWEST']),
#  (1295, ['キンプリ']),
#  (1349, ['HurricaneFlorence']),
#  (1398, ['Politics']),
#  (1409, ['US']),
#  (1424, ['TRUMP']),
#  (1428, ['WWE']),
#  (1436, ['NEWSに恋して']),
#  (1451, ['増田貴久']),
#  (1479, ['American']),
#  (1482, ['HeySayJUMP']),
#  (1493, ['Indiana']),
#  (1499, ['Maryland']),
#  (1517, ['GodBlessAmerica']),
#  (1523, ['VoteRed']),
#  (1528, ['Obama']),
#  (1546, ['Hiring']),
#  (1552, ['夜よ踊れ']),
#  (1568, ['Missouri']),
#  (1581, ['China']),
#  (1598, ['DeepState']),
#  (1630, ['hiring']),
#  (1640, ['MeToo']),
#  (1646, ['TheGreatAwakening']),
#  (1668, ['vote']),
#  (1673, ['CareerArc']),
#  (1686, ['BuildTheWall']),
#  (1708, ['VOTE']),
#  (1712, ['NRA']),
#  (1726, ['手越祐也']),
#  (1741, ['cbc']),
#  (1765, ['BrettKavanaugh']),
#  (1767, ['Trump2020']),
#  (1838, ['FBRparty']),
#  (1939, ['Freedom']),
#  (1968, ['tbs_news']),
#  (1976, ['tbs', 'WeThePeople']),
#  (2001, ['NewYork']),
#  (2059, ['DonaldTrump']),
#  (2069, ['tcot']),
#  (2071, ['japan']),
#  (2111, ['politics']),
#  (2159, ['PatriotsUnited']),
#  (2215, ['HillaryClinton']),
#  (2226, ['FBI']),
#  (2236, ['Veterans']),
#  (2253, ['Truth']),
#  (2314, ['BringBacktheSummer']),
#  (2319, ['小山慶一郎']),
#  (2342, ['Republican']),
#  (2384, ['usa']),
#  (2446, ['QArmy']),
#  (2481, ['加藤シゲアキ']),
#  (2529, ['AmericaFirst']),
#  (2530, ['ChristineBlaseyFord']),
#  (2535, ['希望～Yell～']),
#  (2592, ['45sindespidos']),
#  (2608, ['SCOTUS']),
#  (2631, ['Qanon']),
#  (2650, ['Democrats']),
#  (2663, ['TrumpTrain']),
#  (2680, ['Respect']),
#  (2782, ['FakeNews']),
#  (2783, ['ElectoralCollege']),
#  (2813, ['job']),
#  (2898, ['AAUSA']),
#  (2925, ['Louisiana']),
#  (2930, ['trump']),
#  (2933, ['np']),
#  (2943, ['NowPlaying']),
#  (3007, ['Mazie']),
#  (3014, ['Sexist']),
#  (3015, ['Hirono']),
#  (3046, ['DigitalSoldiers']),
#  (3051, ['Senator']),
#  (3059, ['Virginia']),
#  (3062, ['PresentYou']),
#  (3087, ['Lullaby']),
#  (3102, ['MAGAbots']),
#  (3117, ['2A']),
#  (3144, ['GoodTRUMPsEvil']),
#  (3152, ['FISAGate']),
#  (3158, ['GOT7']),
#  (3169, ['OPMAYFLOWER']),
#  (3206, ['Pennsylvania']),
#  (3284, ['Resist']),
#  (3306, ['ConfirmKavanaugh']),
#  (3362, ['America']),
#  (3369, ['WednesdayWisdom']),
#  (3429, ['QAlert']),
#  (3477, ['respect']),
#  (3518, ['Resistance']),
#  (3683, ['red']),
#  (3711, ['FollowBackResistance']),
#  (3773, ['MeTooHucksters']),
#  (3787, ['PatriotsFight']),
#  (4002, ['FBRParty']),
#  (4033, ['choreography']),
#  (4075, ['truth', 'エンドレス・サマー']),
#  (4084, ['StrayKids']),
#  (4130, ['maga']),
#  (4417, ['BlueWave']),
#  (4578, ['BLUE']),
#  (4664, ['WalkAway']),
#  (4981, ['Democrat']),
#  (5026, ['DrainTheSwamp']),
#  (5099, ['Patriots']),
#  (5296, ['Strawberry']),
#  (5691, ['Vote']),
#  (5787, ['ゼロ一獲千金ゲーム']),
#  (6133, ['KAG']),
#  (7338, ['LVE']),
#  (8794, ['Texas']),
#  (8834, ['WWG1WGA']),
#  (8962, ['GOP']),
#  (10609, ['QAnon']),
#  (11632, ['Kavanaugh']),
#  (12404, ['USA']),
#  (12867, ['News']),
#  (16536, ['BackfireTrump']),
#  (20586, ['POTUS']),
#  (24008, ['生きろ']),
#  (26561, ['Trump']),
#  (26809, ['news']),
#  (32020, ['NEWS']),
#  (62512, ['MAGA'])]

# %%
hashtag_lst = []
with open('political_hashtags_2018.txt', 'r') as f:
    for line in f:
        hashtag_lst.append(line[1:-1].lower())
    f.close()

# %%
hashtag_lst
# Out:
# ['makeamericagreatagain',
#  'dumptrump',
#  'nevertrump',
#  'donaldtrumpthemovie',
#  'trumpsacrifices',
#  'donaldtrumpwantstobanghisdaughter',
#  'trumpyourcat',
#  'trumpsajoke',
#  'makedonalddrumpfagain',
#  'lovetrumpshate',
#  'boycotttrump',
#  'trumptrain',
#  'whentrumpiselected',
#  'antitrump',
#  'trump666',
#  'battrump',
#  'saferthanatrumprally',
#  'trumpsopoor',
#  'famousmelaniatrumpquotes',
#  'trumpolympics',
#  'faketrumpintelligencebriefing',
#  'weakdonald',
#  'sociopathinchief',
#  'trumpdebateexcuses',
#  'dumbdonald',
#  'traitortrump',
#  'maga',
#  'trumptrain',
#  'mikepence',
#  'teaparty',
#  'donaldjtrump',
#  'donaldtrump',
#  'defenddonald',
#  'trump',
#  'secondamendment',
#  '2ndamendment',
#  '2a',
#  'defendthesecond',
#  'onenationundergod',
#  'righttobeararms',
#  'donttreadonme',
#  'red',
#  'rightwing',
#  'right',
#  'conservatives',
#  'prolife',
#  'progod',
#  'progun',
#  'gunrights',
#  'donaldtrump',
#  'latinosfortrump',
#  'gaysfortrump',
#  'votetrump',
#  'freemilo',
#  'alllivesmatter',
#  'buildthewall',
#  'hillaryclinton',
#  'obama',
#  'guncontrol',
#  'berniebros',
#  'blacklivesmatter',
#  'hillaryclinton',
#  'hillary',
#  'imwithher',
#  'wakeupamerica',
#  'amerikkka',
#  'feelthebern',
#  'berniesanders',
#  'bernie',
#  'berniesanders2016',
#  'billandhillary',
#  'voteyourconscience',
#  '3percent',
#  'makedonalddrumpfagain',
#  'fascism',
#  'fucktrump',
#  'dumptrump',
#  'nevertrump',
#  'drumpf',
#  'trumptrainwreck',
#  'libtards',
#  'liberallogic',
#  'toosavagefordemocrats',
#  'crookedhillary',
#  'clintonfoundation',
#  'payforplay',
#  'conservative',
#  'libertarian',
#  'republican',
#  'democrat',
#  'gop',
#  'liberals',
#  'liberal',
#  'constitution',
#  'american',
#  'merica',
#  'nationalism',
#  'politics',
#  'america',
#  'gun',
#  'president',
#  'capitalism',
#  'military',
#  'guns',
#  'americafirst',
#  'usa',
#  'freedom',
#  'liberty',
#  'government',
#  'election',
#  'news',
#  'godblessamerica',
#  'supportthetroops',
#  'firearms',
#  'country',
#  'patriotic',
#  'usarmy',
#  'political',
#  'patriotism',
#  'libertyordeath',
#  'vote',
#  '2016the',
#  'veterans_us',
#  'veterans',
#  'usveterans',
#  'veteransusa',
#  'supportveterans',
#  'patriots',
#  'gratitude',
#  'honorvets',
#  'thankvets',
#  'supportourtroops',
#  'remembereveryonedeployed',
#  'usflag',
#  'truth',
#  'religion',
#  'americanaf',
#  'veteran',
#  'respect',
#  'honor',
#  'patriot',
#  'presidentialelection',
#  'ushistory',
#  'americanhistory',
#  'pledgeofallegiance',
#  'president',
#  'potus',
#  'election',
#  'godblessamerica',
#  'americanpride',
#  'nra',
#  'murica',
#  'military',
#  'rand2020',
#  'american',
#  'texas',
#  'democracy',
#  'votelocal',
#  'voteorlando',
#  'resistance',
#  'bluewave']

# %% [markdown]
# Get popular hashtags that don't show up in our list of hashtags.

# %%
hashtags_not_in_lst = []
for _,hashtags in top_hashtags_and_counts:
    for hashtag in hashtags:
        if hashtag.lower() not in hashtag_lst:
            hashtags_not_in_lst.append(hashtag)

# %%
hashtag_lst
# Out:
# ['makeamericagreatagain',
#  'dumptrump',
#  'nevertrump',
#  'donaldtrumpthemovie',
#  'trumpsacrifices',
#  'donaldtrumpwantstobanghisdaughter',
#  'trumpyourcat',
#  'trumpsajoke',
#  'makedonalddrumpfagain',
#  'lovetrumpshate',
#  'boycotttrump',
#  'trumptrain',
#  'whentrumpiselected',
#  'antitrump',
#  'trump666',
#  'battrump',
#  'saferthanatrumprally',
#  'trumpsopoor',
#  'famousmelaniatrumpquotes',
#  'trumpolympics',
#  'faketrumpintelligencebriefing',
#  'weakdonald',
#  'sociopathinchief',
#  'trumpdebateexcuses',
#  'dumbdonald',
#  'traitortrump',
#  'maga',
#  'trumptrain',
#  'mikepence',
#  'teaparty',
#  'donaldjtrump',
#  'donaldtrump',
#  'defenddonald',
#  'trump',
#  'secondamendment',
#  '2ndamendment',
#  '2a',
#  'defendthesecond',
#  'onenationundergod',
#  'righttobeararms',
#  'donttreadonme',
#  'red',
#  'rightwing',
#  'right',
#  'conservatives',
#  'prolife',
#  'progod',
#  'progun',
#  'gunrights',
#  'donaldtrump',
#  'latinosfortrump',
#  'gaysfortrump',
#  'votetrump',
#  'freemilo',
#  'alllivesmatter',
#  'buildthewall',
#  'hillaryclinton',
#  'obama',
#  'guncontrol',
#  'berniebros',
#  'blacklivesmatter',
#  'hillaryclinton',
#  'hillary',
#  'imwithher',
#  'wakeupamerica',
#  'amerikkka',
#  'feelthebern',
#  'berniesanders',
#  'bernie',
#  'berniesanders2016',
#  'billandhillary',
#  'voteyourconscience',
#  '3percent',
#  'makedonalddrumpfagain',
#  'fascism',
#  'fucktrump',
#  'dumptrump',
#  'nevertrump',
#  'drumpf',
#  'trumptrainwreck',
#  'libtards',
#  'liberallogic',
#  'toosavagefordemocrats',
#  'crookedhillary',
#  'clintonfoundation',
#  'payforplay',
#  'conservative',
#  'libertarian',
#  'republican',
#  'democrat',
#  'gop',
#  'liberals',
#  'liberal',
#  'constitution',
#  'american',
#  'merica',
#  'nationalism',
#  'politics',
#  'america',
#  'gun',
#  'president',
#  'capitalism',
#  'military',
#  'guns',
#  'americafirst',
#  'usa',
#  'freedom',
#  'liberty',
#  'government',
#  'election',
#  'news',
#  'godblessamerica',
#  'supportthetroops',
#  'firearms',
#  'country',
#  'patriotic',
#  'usarmy',
#  'political',
#  'patriotism',
#  'libertyordeath',
#  'vote',
#  '2016the',
#  'veterans_us',
#  'veterans',
#  'usveterans',
#  'veteransusa',
#  'supportveterans',
#  'patriots',
#  'gratitude',
#  'honorvets',
#  'thankvets',
#  'supportourtroops',
#  'remembereveryonedeployed',
#  'usflag',
#  'truth',
#  'religion',
#  'americanaf',
#  'veteran',
#  'respect',
#  'honor',
#  'patriot',
#  'presidentialelection',
#  'ushistory',
#  'americanhistory',
#  'pledgeofallegiance',
#  'president',
#  'potus',
#  'election',
#  'godblessamerica',
#  'americanpride',
#  'nra',
#  'murica',
#  'military',
#  'rand2020',
#  'american',
#  'texas',
#  'democracy',
#  'votelocal',
#  'voteorlando',
#  'resistance',
#  'bluewave']

# %%
hashtags_not_in_lst
# Out:
# ['TradeTarrifs',
#  'Replay',
#  'edlandscapes',
#  'itswhatsontheoutsidethatcounts',
#  'mudgee',
#  'abattoir',
#  'OvenStoveCleaners',
#  'MuéveteEnMéxico',
#  'militaryhalloffame',
#  'bcbravehearts',
#  'protector',
#  '150Billion',
#  'BankOfRussia',
#  'Blacklist',
#  'IMPEACHTRUMPNOW',
#  'IncompetentPOTUS',
#  'factoryfarming',
#  'BlogPost',
#  'NunesIsATraitor',
#  'NunesIsALeaker',
#  'VoteJanzforCongress',
#  'TheDocumentsAreComing',
#  'IGI',
#  'steeldossier',
#  'ironicmemes',
#  'UseYourHead',
#  'guargopaldas',
#  'goFast',
#  'Walkawayfromdemocrats2018',
#  'itsokwhenitsaconservative',
#  'DIDDLERSDOWN',
#  'MakeaDifference',
#  'STEPSocal',
#  'CrisisOfCharacter',
#  'Beto4Veterans',
#  'drugskill',
#  'SomeDrugsArentCool',
#  'NoSelfRespect',
#  'chevelle',
#  'liveatthenorva',
#  'Creepy',
#  'DemonratsAreSorosPaidPuppets',
#  'OTC',
#  'wusses',
#  'betamales',
#  'TearsDown',
#  'TRAMPTRAIN',
#  'TRUMPSTAIN',
#  'CaitlynJenner',
#  'VotoLatino',
#  'Nuthatch',
#  'species',
#  'AajKeSamachar',
#  'unethical',
#  'atlas',
#  'スチーム',
#  'valve',
#  'Kiina',
#  'Euroopan',
#  'Lumber',
#  'libby',
#  'triggerwarning',
#  'liberalbull',
#  'SteamingPileOfTrump',
#  'DonaldHump',
#  '袖ヶ浦公園',
#  '袖ヶ浦',
#  '季節のお花',
#  'lycoris',
#  'Chiba',
#  'sodegaura',
#  'partcolor',
#  'indvhk',
#  'votebank',
#  'RightToKnow',
#  'FacesOfRacism',
#  'apes',
#  'JesseWilliams',
#  'copslivesmatter',
#  'stopallracism',
#  'dontbearacist',
#  'enoughisenough',
#  'streetphotographicnyc',
#  'marcelopratesphotojournalist',
#  'houstantexans',
#  'OakPoint',
#  'VoteBlueToSaveAmericaDemocracy',
#  'BatshitCrazy',
#  'DrinkMe',
#  'footsteps',
#  'TheRojasFile',
#  'SaferJoburg',
#  'makeSAsafe',
#  'Ekse',
#  'BuyaMthetho',
#  'Spanking',
#  'DumDon',
#  'Blam',
#  'toffee',
#  'toffees',
#  'DavidAxelrod',
#  'Krauthammer',
#  'SepticTankCleaning',
#  'BoyBye',
#  'StopTheDemocraticDeception',
#  'WalkAwayMovementGrowing',
#  'byebyefelicia',
#  'fo_exchange',
#  'entropy',
#  'GopHatesDemocracy',
#  'FakePoll',
#  'ChildSafety',
#  'CrimePrevention',
#  'VisiblePolicing',
#  'フェザー',
#  'ジャケットコーデ',
#  '送料無料',
#  'ブラックコーデ',
#  'ホワイト',
#  'gu',
#  'ユニクロコーデ',
#  'TDE7',
#  'NEWSアニバーサリーグッズ',
#  'BookPromotion',
#  'AuthorPromotion',
#  'Trumpisyourpresident',
#  'BoycottSesameStreet',
#  'glorify',
#  'MidTermsMatter',
#  'AntiCopScumBag',
#  'RealHeroes',
#  'PerpInCityHall',
#  'Megayacht',
#  'KavanaughAc',
#  'MyPeople',
#  'BuyTheBlock',
#  'DUBIA',
#  'tunic',
#  'kurta',
#  'SOCIAL',
#  'QuantumLeap',
#  'DeanStockwell',
#  'kabibeshell',
#  'BrutalTruth',
#  'futurax',
#  'votetoken',
#  'votecoin',
#  'newson',
#  'GloriaAllred',
#  'JudyWoodruff',
#  'ArgentinaSinEstadoDeDerecho',
#  'exposeStrzokandPage',
#  'バス旅',
#  '太川陽介',
#  '蛭子',
#  '人気番組',
#  'バス旅Z',
#  'AKB',
#  '乃木坂',
#  'contributive',
#  'Idiotic',
#  'BlueUnite',
#  'FlipCongress',
#  'tweetstorm',
#  'DamnRightThatsMyPresident',
#  'trumpruinseverything',
#  'alexnajalas',
#  'colombianas01',
#  'AllWillBeRevealed',
#  'PresidentialFact',
#  'SorosCollusion',
#  'IndiansInUSA',
#  'CrazyTrain',
#  'devildogs',
#  'leathernecks',
#  'eatcrayons',
#  'crayons',
#  'readytoeat',
#  'mre',
#  'cre',
#  'スピジャニ',
#  'showmeyourfisa',
#  'establishment',
#  'PUPPET',
#  'STOOGE',
#  'RespectOthers',
#  '4SimpleWords',
#  'TheBlueWave',
#  'MultiplyYourVote',
#  'grussell903',
#  'livefeeds',
#  'adultstars',
#  'اليوم_وين_بتروحون',
#  'Crumbling',
#  'Evolve',
#  'tezos',
#  'SKWAWKBOX',
#  'CorruptCongress',
#  'PDK',
#  'Shamsadeen_Hassan',
#  'best_candidate',
#  'sillywomen',
#  'SaveNetNeutrality',
#  'Redmi6A',
#  'SEP16',
#  'ProgressDem',
#  'warstories',
#  'warmemorial',
#  'lehmarket',
#  'lehsightseeing',
#  'lehdiaries',
#  '小説TRIPPER',
#  'prayerworks',
#  'bds',
#  'AcrossTheGlobe',
#  'ZeroTolerants',
#  'f2b',
#  'respecc',
#  'PatriotsvsEagles',
#  'ecuadorianbeauty',
#  'PieceOfShitPutin',
#  'Tatamotors',
#  'CrookedKillary',
#  'JusticeForAmerica',
#  'Ambode',
#  '3DChess',
#  '4DChess',
#  'CantMakeThisUp',
#  'CNNCaughtLyingAgain',
#  'RapistBillClinton',
#  'करंट',
#  'युवक',
#  'Qproofs',
#  'genders',
#  'friendsforlife',
#  'betofakemexican',
#  'sneakysneaky',
#  'fightharder',
#  'Agenda2030',
#  'GaneshGupta',
#  'CameroUN',
#  'PaulBiya',
#  'JimmyMorales',
#  'livingwithPI',
#  'GOBLUE',
#  'EndangeredSpecies',
#  'AirPower',
#  'theRedstorm',
#  'NOKO',
#  'realestatedevelopment',
#  'Skype',
#  'blogauroradecinemaindica',
#  'elenãopassará',
#  'elenão',
#  'forabostonaro',
#  'VoteEarlyVoteOften',
#  'ONALASKA',
#  'bezos',
#  'Buzzz_zz_zzz_zz_z_zzz_zz',
#  'STORMYDANIELSBOOK',
#  'AtheistApologetics',
#  'ObamasKGB',
#  'afterworkmiles',
#  'beachcities',
#  'KamalToeHarris',
#  'CompassRose',
#  'Giftforher',
#  'AmeriCANS',
#  'GreenDay',
#  'BillieJoe',
#  'VotingAvenue',
#  'SchoolhouseRock',
#  'AmericanBadass',
#  'CaliforniansForTrump',
#  'AntiRepublican',
#  'WinningTeam',
#  'KickRocks',
#  'Nigata',
#  'FindDezaHome',
#  'RepublicansSuck',
#  'FutureMajority',
#  'MarcusSakey',
#  '17Q',
#  'TrumpWhitehouse',
#  'kattwilliams',
#  'VentTeaTalkPanel',
#  'standwithKavanaugh',
#  'allforbenefit',
#  'oversoon',
#  'copihue',
#  'concepcion',
#  'senderismo',
#  'cerrocaracol',
#  'FACESITTING',
#  'Clips4Sale',
#  'Corptocracy',
#  'ScamArtist',
#  '45bestPOTUSever',
#  'peta',
#  'duisdontmatter',
#  'protectwhatyoulove',
#  'ProGunRights',
#  'KavaNOMeansNO',
#  'StopKavanaUGH',
#  'Commitment',
#  'SocialSecuity',
#  'Repulicans',
#  'Trumpmemes',
#  'COTUS',
#  'GoToSleep',
#  'CantResistThis',
#  'FuckDeepState',
#  'CourtMartial',
#  'TDSisreal',
#  'lockman',
#  'pilots',
#  'VolcanicAsh',
#  'WorldAirways',
#  'HealthcareBills',
#  'RaoAnwar',
#  'sites',
#  'NominateABetterCandidate',
#  'iliketrump',
#  'Punishment',
#  'सीबीआई',
#  'विजयमाल्या',
#  '230fifth',
#  'empirestatebuilding',
#  'dailyNews',
#  'EPWEngage',
#  'MoneyFlow',
#  'LauraIngrahm',
#  'Twittersgate',
#  'Nieuws',
#  'transfernews',
#  'trans7',
#  'sissyslut',
#  'oufits',
#  'tranny',
#  'trannyporn',
#  'protectourfreedom',
#  '1位おめでとう',
#  '台灣的安全就靠模仿演員了',
#  'RadFem',
#  'teeshirtdesign',
#  'donthashtag',
#  'beentheredonethat',
#  'MeekFree',
#  'Tirupati',
#  'TeluguDesamParty',
#  'tirupati',
#  'Predators',
#  'NewPlace',
#  'participationtrophy',
#  'RussianAsset',
#  'behumble',
#  'gsp',
#  'ReleaseSessions',
#  'TruthIsPower',
#  'Hussein',
#  'BriberyPayment',
#  'Ecologia',
#  'Sustentabilidad',
#  'DroppingGame',
#  'Supercomputing',
#  'Mellanox',
#  'MaritalIntimacy',
#  'HELLONEARTH',
#  'SummonKerryIranMeetingDocuments',
#  'AlexVirgo',
#  'GravesCreek',
#  'rainbowfishing',
#  'tablemanners',
#  'FreeTheChildren',
#  'FuckCapitalism',
#  'Nobel',
#  'Tourettes',
#  'justundoit',
#  'psyco',
#  'psycology',
#  'selfvalue',
#  'phototherapy',
#  'monies',
#  'rent_to_buy',
#  'shared_ownership',
#  'affordable_rent',
#  'BaldMountainFire',
#  'polecreekfire',
#  'spreading',
#  'silly',
#  'oakleysunglasses',
#  'scarface',
#  'Unbranded',
#  'FORCEOFNATURE',
#  'PHENOMENON',
#  'Tatmadaw',
#  'LIB',
#  'Truckee',
#  'serbian',
#  'ртсвести',
#  'TheBestPeople',
#  'ChildPredators',
#  'ChildMolestors',
#  'TWAFLIGHT800',
#  'ALPHABETAGENCIES',
#  'Abbott',
#  'SchoolDistricts',
#  'Tinderholt',
#  'Decision18',
#  'Cracked',
#  'MontrealRiver',
#  'newyorkgiants',
#  'LIV',
#  'liljoeceo',
#  'mossberg',
#  'BuzzinGreat',
#  'Domestic',
#  'half',
#  'allfoherrbenefit',
#  'masternodes',
#  'BestDayEver',
#  'DCMSHRIRAM',
#  'spselva',
#  'Freakshow',
#  'JessieHelms',
#  'BETTER',
#  'Protests',
#  'UKtrumpvisit',
#  'digitalKids',
#  'IBelieveYou',
#  'africanmagic',
#  'belly',
#  'elationships',
#  'CryBaby',
#  'PartyOfWhiteMen',
#  'PartyOfSexualAssault',
#  'NoRefuge',
#  'HumanTraffickers',
#  'womenfashion',
#  'granite',
#  'composer',
#  'slogans',
#  'PersistenceTrumpsResistance',
#  'SupremeCourtNominee',
#  'Respect大分',
#  'dreamcrazy',
#  'BLACKGOLD',
#  'royality',
#  'blackprints',
#  'Propagandist',
#  'Fahrenheit11_9',
#  'FreeStuff',
#  'SuckMeBeautiful',
#  'redgun',
#  'HandmaidsTale',
#  'democracyvalues',
#  'ReleasetheRecords',
#  'Kamloops',
#  'WELOVE',
#  'CapitaLand',
#  'Millenials',
#  'ReleaseSenateHushFundList',
#  'пожар',
#  'bastogne',
#  'hispanic',
#  'BillPalmer',
#  'Mutual',
#  'Funds',
#  'Fundraising',
#  'workhorse',
#  'teamplayer',
#  'SlaveGrip',
#  'DemocratPlantation',
#  'SlaveNoMore',
#  'trueGrassrootsDemocracy',
#  'AirAssaults',
#  'ICallBS',
#  'WHMustReqFBI',
#  'GOPSHAMRUSH',
#  'FBIReqReasonable',
#  'VAWA4ALL',
#  'weDeserveBetter',
#  'OrangeBaboon',
#  'RememberKateandMollie',
#  'AzureDevOps',
#  'azuresource',
#  'BuckelUp',
#  'dailycurrentaffairs',
#  'dailynewspaper',
#  'wowvideos',
#  'wowvideoscurrentaffairs',
#  'PhineasAndFerb',
#  'milomurphyslaw',
#  'WakeUpInTheSky',
#  'Lastfm',
#  'CultureNight',
#  'rockfellercenter',
#  'gebuilding',
#  'comcastbuilding',
#  's1804',
#  'hr676',
#  'astral',
#  'wentworth',
#  'HumanRightsViolations',
#  'Abduction',
#  'sumedang',
#  'pordajabar',
#  'jailHillary',
#  'Clintoncrimefamily',
#  'Mantra',
#  'foxconn',
#  'PakistanoccupiedKashmir',
#  'Hillaryforprison',
#  'GirlsFrontline',
#  'ForgottenWeapons',
#  'DLC',
#  'FundIt',
#  'SawItComing',
#  'copy',
#  'twitterqrcode',
#  'Protein',
#  'PrinceGeorge',
#  'NoPaylosi',
#  'janzour',
#  'Genocidal',
#  'Escalating',
#  'lowlife',
#  'sethanthony',
#  'roughneck',
#  'countryartist',
#  'FUCKPENCE',
#  'IMPEACHPENCE',
#  'Iseeit',
#  'FuckGOPTraitors',
#  'FuckMcConnell',
#  'FuckRyan',
#  'FuckLindseyGraham',
#  'FuckAllTrumps',
#  'underwaterphotography',
#  'josecuervo',
#  'tequilla',
#  'happyjuice',
#  'heavyhitter',
#  'kush',
#  'ShiftySchiff',
#  'mmmx',
#  'blackhawk',
#  'Sikorsky',
#  'UH60',
#  'desfile16sep',
#  'avgeeks',
#  'goodyontif',
#  'olympicmountains',
#  'bettergetyouame',
#  'starmark',
#  'clonakilty',
#  'directionalist',
#  'abolishdepartmentofeducation',
#  'sangramsingh',
#  'TeamRapert',
#  'Frugal',
#  'ToughTimes',
#  'JamieMasada',
#  'UtilityHacks',
#  'noafd',
#  'deai',
#  'ramadanfasting',
#  'fitdj',
#  'plena',
#  'lookdodia',
#  'Trump202',
#  'NavyAdmiral',
#  'Toro',
#  'ApeEscape',
#  'BobbyScott',
#  'socailist',
#  'HawaiianAirlines',
#  'MushroomStamp',
#  'dismissal',
#  'ಆನ್\u200cಲೈನ್',
#  'ಮೊಬೈಲ್',
#  'JonathonPie',
#  'Departure',
#  'TheWheel',
#  'peculiartv',
#  'Veryexciting',
#  'Pyongyangsummit',
#  'LoonyLibs',
#  'Militarization',
#  'Sankei',
#  'deposeobama',
#  '최유정',
#  'IDOLCHALLENGE',
#  'FightXenophobia',
#  'FightRacism',
#  'WeHappyFew',
#  'Skyrim',
#  'BeyondBruma',
#  'unthinkable',
#  'Slogan',
#  'congresso',
#  'MassimoSugarelli',
#  'congressoPD',
#  'deliberate',
#  'actions',
#  'enourmous',
#  'titties',
#  'RIPMGK',
#  'liferuined',
#  'illegalimmigration',
#  'nomorelies',
#  'livery',
#  'americanairlines',
#  'bud',
#  'spot',
#  'spotter',
#  'spotting',
#  'Untouchable',
#  'Hoggwash',
#  'qadarmehnatki',
#  'GaneshUtsav',
#  'wizardofoz',
#  'WritersLife',
#  'NaNoWriMo',
#  'WritingTip',
#  'BookMarketing',
#  'WritingPrompt',
#  'LitChat',
#  'storystarter',
#  'Insulin4All',
#  'peoplefirst',
#  'T1D',
#  'Heathcare',
#  'artgalleries',
#  'comment4comment',
#  'Denali',
#  'MilitaryAppreciationDay',
#  'StopTweeting',
#  'PrayForPeace',
#  'FilipinoNurse',
#  'DiversityMatters',
#  'ER',
#  'GreysAnatomy',
#  'wrongfrom',
#  'start',
#  'fallenangels',
#  'bootyluvs',
#  'republicanparty',
#  'corporatism',
#  'DRAININGtheSWAMP',
#  'YettiPubes',
#  'BrownLegacy',
#  'canucks',
#  'solarpanel',
#  'destruction',
#  'bigoil',
#  'already',
#  'PositiveMind',
#  'RadicalSelfLove',
#  'PeaceOfMind',
#  'MarioSeries',
#  '너잖아',
#  'GIA',
#  'VoteBlueForAmerica',
#  'themeparks',
#  'rollercoasters',
#  'BluesHistory',
#  '2018Glorious',
#  'EnjoyingTheMovie',
#  'Bolsonaro1ºturno',
#  'WillfulStupidity',
#  'Rockies',
#  'Works',
#  'FoodNews',
#  'fbads',
#  '2018GeneralElection',
#  'moment44',
#  'originalsongs',
#  'AmbiNingVayassaytho',
#  'Sept27',
#  'RebelStar',
#  'Ambreesh',
#  'AmbiNingVayasaitho',
#  'ANV',
#  'Bu',
#  'EmbraceTheSuck',
#  'ThrowTheBastardsOut',
#  'rig',
#  'wethepeoplehavethepower',
#  'Bloom',
#  'Gardens',
#  'ElectionTO',
#  'TheCircus',
#  'Categories',
#  'pops',
#  'DougJones',
#  'DougJones4Senate',
#  'TimeForAChange',
#  'missitalia2018',
#  'VoteBETO',
#  'immunologhi',
#  'ingegneri',
#  'allenatori',
#  'StopTheCensorship',
#  'ConservativesArePatriots',
#  'LiberalsAreSocialistCommunists',
#  'DRovell',
#  'DJR',
#  'DJRx',
#  'NawaeWaqt',
#  'publicviews',
#  '2k19pm',
#  'CongressSankalpYatra',
#  'lahorediaries',
#  'Itllbealrightonthenight',
#  'ClimateCultBS',
#  'realTCUstatetrainOH',
#  'bwahaha',
#  'TrumpCup',
#  'hwnt',
#  'hwntrgv',
#  '今日のおやつ',
#  'ぬれせんべい',
#  'ぬれいか天',
#  'lyingted',
#  '小学生の鼻歌',
#  'HappyBDayPMModi',
#  'PMHouse',
#  'VensonPestSolutions',
#  'Machines',
#  'VeteransBridge',
#  'TimeToInvestigate',
#  'ManicAssholeGriftingAmerica',
#  'redstain',
#  'DimitriVegas',
#  'XGGL',
#  'wegohard',
#  'Minions',
#  'Dive',
#  'Divers',
#  'Palace',
#  'Wilfried',
#  'Zaha',
#  'kneepain',
#  'deutsch',
#  'Jakarta',
#  'bekasi',
#  'kantor',
#  'pilkada',
#  'PRIAN',
#  'Llorona',
#  'laredo',
#  'nld',
#  'nuevolaredo',
#  'leon',
#  'JoyReid',
#  'MaddowBlog',
#  'videoclips',
#  'coloradomodel',
#  'cmgirl',
#  'JatengGayeng',
#  'KIMJONGUN',
#  'CA21',
#  'BAC',
#  'Boğaz',
#  'Bosphorus',
#  'strait',
#  'CryptoFever',
#  'DemocraciesDieInDarkness',
#  'ProAbortion',
#  'wfoa',
#  'mobilkonsep',
#  'individual',
#  'ConfirmKavanughNow',
#  'googlereviews',
#  'customerexperiences',
#  'usecasesverticals',
#  'Importaufschläge',
#  'Zoll',
#  'ÉtatsUnis',
#  'ybraptvnews',
#  'thanksASNC',
#  'LockedUp',
#  'WhiteFace',
#  'livro',
#  'ler',
#  'PrayerForAmerica',
#  'GodBlessedPresidentTrump',
#  'AreWeNuts',
#  'calgary',
#  'Canadadiaries',
#  'greatfriends',
#  'oldfriends',
#  'bonding',
#  'ShareItForward',
#  'LikeIfYouAgree',
#  'marketingdigital',
#  'Stozk',
#  'CattoorLivestock',
#  'roundups',
#  'WILDHORSE',
#  'Zee',
#  'zeeamericas',
#  'polcan',
#  'pallagrellonero',
#  'Volturno',
#  'Chaplin',
#  'Civil_NGO',
#  '修造',
#  'something',
#  'wait',
#  'berightback',
#  'jaycharrisma',
#  'boneinfilet',
#  'rareplus',
#  'saldo',
#  '석산',
#  'Integracion',
#  'ClimateGeoEngineeringChemtrails',
#  'Seinäjoki',
#  'Vaasa',
#  'Hyvinkää',
#  'seksiä',
#  'DreamzGKFraud',
#  'Constitutionನಮ್ಮDharma',
#  'RainMakers',
#  'nfltrade',
#  'TumblringThroughTwitterville',
#  'RiotOnRiotsThoughtsOnKyuss',
#  'ThatIsAll',
#  'BerlinGermany',
#  'TaintedSheriffDavidClarke',
#  'wench',
#  'TexasVotes',
#  'TexasElections',
#  'sniperrifle',
#  'LiberalHypocricy',
#  'trifecta_unlimited',
#  'arizonaforest',
#  'safarilandholster',
#  'thankgod',
#  'THANKGOD',
#  '45NeverMyPrez',
#  'wassenaar',
#  'tgtalk',
#  'plays',
#  'EventNews',
#  'brutalist',
#  'landmarks',
#  'theatres',
#  'shailyretails',
#  'growthhackiing',
#  'github',
#  'amigos',
#  'nopotus',
#  'Manichino',
#  '13settembre',
#  'rc68',
#  'thisiscnn',
#  'fotodeldía',
#  'martes',
#  'rosas',
#  'QAnonPosts',
#  'NEPAL',
#  'MylesJackWasntDown',
#  'ifyoureapatsfan',
#  'destroys',
#  'MyNAmeISREEK',
#  'LoserDonald',
#  'GodBlessWlilieNelson',
#  'NoWarInSyria',
#  'cavanaugh',
#  'MILeg',
#  'Architectural',
#  'Drawing',
#  'Rendering',
#  'Cad',
#  'Interior',
#  'PDF',
#  'AutoCAD',
#  'Drawings',
#  'Conversion',
#  'Outsourcing',
#  'drafting',
#  'Bolts',
#  'weld',
#  'MIAG',
#  'Seaworld',
#  'FailedGOP45',
#  'Disaster45',
#  'OTHER',
#  'EYEWITTNESS',
#  'NEED',
#  'KNOW',
#  'BOOKWORM',
#  'VoteJohnCoxforGovernor',
#  'Endorsed',
#  'IMSpartacus',
#  'さんま御殿',
#  'Credo',
#  'relaxing',
#  'graciasmadre',
#  'Goeb',
#  'GoogleCEO',
#  'bokepbarat',
#  'Inspirations',
#  'Mud',
#  'Squares',
#  'Vans',
#  'minorenni',
#  'westlakepark',
#  'downtownseattle',
#  'gunban',
#  'Bernie2016',
#  'CHicago',
#  'I94',
#  'BabyBeMyBaby',
#  '6November2018',
#  'BlueWedding',
#  'equityineducation',
#  'PaulMooney',
#  'cutyoudown',
#  'opiates',
#  'landofconfusion',
#  'イナズマロックフェス',
#  'playmobil',
#  'flowersofinstagram',
#  'redandorange',
#  'これなに',
#  'ThanksMichelle',
#  'Азербайджан',
#  'jasad',
#  'jasadutuh',
#  'jasadutuhciamis',
#  'jenazah',
#  'chineseinafrica',
#  'chinesezambia',
#  'zambiaafrica',
#  'neocolonialism',
#  'Furguson',
#  'WalkAwayFromCommunists',
#  'whistleblower',
#  'DominicWyKanak',
#  'ritornoalboscodeicentoacri',
#  'shinlim',
#  'agtvote',
#  'CAMEROON',
#  'loseCruz',
#  'devote52weeks',
#  'christianblogger',
#  'christianmom',
#  'christiangirl',
#  'makeyourbed',
#  'admiralmcraven',
#  'LOSS',
#  'LOVEisLOVE',
#  'LiveLetLIve',
#  'Clima',
#  'piccolenews',
#  'SauravRTiberewaal',
#  'facilitator',
#  'AccessConsciousness',
#  'SCROLLING',
#  'ENJOY',
#  'CONTENT',
#  'PROVIDERS',
#  'GUEST',
#  'LEARN',
#  'Silhouette',
#  'GoldColored',
#  'OrangeColor',
#  'Close',
#  'NoRockBottom',
#  'helenamontana',
#  'swim',
#  'ISPR',
#  'Quetta',
#  'letmetalktothem',
#  'PHUCKINGassholes',
#  'allfakeeverything',
#  'smileforthejury',
#  'fill',
#  'hastags',
#  'annoy',
#  'RPAcourse',
#  'iKeenAcademy',
#  'Pasadena',
#  'donacion',
#  'تبرع',
#  'attijariwafabank',
#  'PaxEx',
#  'SpeakTruth',
#  'StartSomewhere',
#  'Hurrican',
#  'HumanRightsDefenders',
#  'NowThisNews',
#  'boxoffice',
#  'returning',
#  'ideeplyappreciateyou',
#  'trueopinion',
#  ...]

# %%
hashtags_not_in_lst.reverse()

# %%
hashtags_not_in_lst
# Out:
# ['生きろ',
#  'BackfireTrump',
#  'Kavanaugh',
#  'QAnon',
#  'WWG1WGA',
#  'LVE',
#  'KAG',
#  'ゼロ一獲千金ゲーム',
#  'Strawberry',
#  'DrainTheSwamp',
#  'WalkAway',
#  'BLUE',
#  'StrayKids',
#  'エンドレス・サマー',
#  'choreography',
#  'FBRParty',
#  'PatriotsFight',
#  'MeTooHucksters',
#  'FollowBackResistance',
#  'QAlert',
#  'WednesdayWisdom',
#  'ConfirmKavanaugh',
#  'Resist',
#  'Pennsylvania',
#  'OPMAYFLOWER',
#  'GOT7',
#  'FISAGate',
#  'GoodTRUMPsEvil',
#  'MAGAbots',
#  'Lullaby',
#  'PresentYou',
#  'Virginia',
#  'Senator',
#  'DigitalSoldiers',
#  'Hirono',
#  'Sexist',
#  'Mazie',
#  'NowPlaying',
#  'np',
#  'Louisiana',
#  'AAUSA',
#  'job',
#  'ElectoralCollege',
#  'FakeNews',
#  'Democrats',
#  'Qanon',
#  'SCOTUS',
#  '45sindespidos',
#  '希望～Yell～',
#  'ChristineBlaseyFord',
#  '加藤シゲアキ',
#  'QArmy',
#  '小山慶一郎',
#  'BringBacktheSummer',
#  'FBI',
#  'PatriotsUnited',
#  'japan',
#  'tcot',
#  'NewYork',
#  'WeThePeople',
#  'tbs',
#  'tbs_news',
#  'FBRparty',
#  'Trump2020',
#  'BrettKavanaugh',
#  'cbc',
#  '手越祐也',
#  'CareerArc',
#  'TheGreatAwakening',
#  'MeToo',
#  'hiring',
#  'DeepState',
#  'China',
#  'Missouri',
#  '夜よ踊れ',
#  'Hiring',
#  'VoteRed',
#  'Maryland',
#  'Indiana',
#  'HeySayJUMP',
#  '増田貴久',
#  'NEWSに恋して',
#  'WWE',
#  'US',
#  'HurricaneFlorence',
#  'キンプリ',
#  'ジャニーズWEST',
#  'daradaily',
#  'Travel',
#  '中山優馬',
#  'VoteRedToSaveAmerica',
#  'DOJ',
#  'KeithEllison',
#  'GreatAwakening',
#  'business',
#  'qanon',
#  'ดาราเดลี่',
#  'TheResistance',
#  'Cascade',
#  'Election2018',
#  '希望〜Yell〜',
#  'KちゃんNEWS',
#  'RT',
#  'Midterms2018',
#  'VoteBlue',
#  'KEIICHIRO',
#  'NEWS15thAnniversary',
#  'Bring',
#  'Florida',
#  'Republicans',
#  'NosotrosLosSoldados',
#  'California',
#  'CNN',
#  'DAPUMP',
#  'love',
#  'BlueWave2018',
#  'MAGAveteran',
#  'Justice',
#  'fashion',
#  'WinBlue',
#  'travel',
#  'Walkaway',
#  'breakingnews',
#  'Nature',
#  'Q',
#  'RedWaveRising',
#  'BREAKING',
#  'TeamJohnJames',
#  'NEWSRING',
#  'tech',
#  'GITMO',
#  'StormyDaniels',
#  'KAG2020',
#  'Tripletalaq',
#  'TCOT',
#  'UK',
#  'DerogacionLey08',
#  'marketing',
#  'ConfirmKavanaughNow',
#  'fitness',
#  'FISA',
#  'CatsOfTwitter',
#  'jobs',
#  'strawberry',
#  '1W1Lツ',
#  'ChristineFord',
#  'RedWave',
#  'StopKavanaugh',
#  'ImpeachTrump',
#  'ShareJourney',
#  'Antifa',
#  'Weather',
#  'cross',
#  'WWI',
#  'Syria',
#  'funny',
#  'Brexit',
#  'PromisesKept',
#  'FBR',
#  'Trending',
#  'TrumpRussia',
#  'NEWS担と繋がりたい',
#  'feedly',
#  'DrainTheDeepState',
#  'bitcoin',
#  'Russia',
#  'Israel',
#  'resist',
#  'DearProfessorFord',
#  'walkaway',
#  'QANON',
#  '45SinDespidos',
#  'ReleaseTheDocs',
#  'criminal',
#  'Canada',
#  'work',
#  'SD19',
#  'DNC',
#  'Hollywood',
#  'Spartacus',
#  'RedWave2018',
#  'sales',
#  'FOLLOW',
#  'WednesdayMotivation',
#  'wwg1wga',
#  'music',
#  'TornadoTrump',
#  'Breaking',
#  'NFL',
#  'EreEncubierto',
#  'Iran',
#  'новости',
#  'Dems',
#  'Winning',
#  'ニュース',
#  'kag',
#  'lol',
#  'BoozAllen',
#  'Congress',
#  'blockchain',
#  'VoteThemOut',
#  'DerogacionLey08_2006',
#  'CoreaDelNorte',
#  'ccot',
#  'QPosts',
#  'VOTERED2018',
#  'reatilsales',
#  'art',
#  'Army',
#  'Crypto',
#  'life',
#  'WINNING',
#  'Dobbs',
#  'QuoteOfTheDay',
#  'YesWeCan',
#  'NiUnSuicidioMasEnFFCCSEyFAS',
#  'tips',
#  'Bitcoin',
#  'Florence',
#  'Love',
#  'MSM',
#  'VoteDemsOut',
#  'Chicago',
#  'WalkAwayDemocrats2018',
#  'hilarious',
#  'FortTrump',
#  'lmao',
#  'laugh',
#  'LockThemAllUp',
#  'Americans',
#  'PresidentTrump',
#  'Retweet',
#  'bigjujumedia',
#  'walkawayfromwalkaway',
#  'Business',
#  '泛亚',
#  'EPCOTIA円盤化希望',
#  '希望～Yell〜',
#  'QProofs',
#  'Job',
#  'TheStorm',
#  'Venezuela',
#  '生きろ1位おめでとう',
#  'shoponline',
#  '拡散希望',
#  'technology',
#  'crypto',
#  'BreakingNews',
#  'Treason',
#  'Photo',
#  'NEWSでお絵かき',
#  'NEWSで妄想',
#  'TrumpMan',
#  'PJNET',
#  'Jobs',
#  'TrendingNow',
#  '官骗',
#  'cryptocurrency',
#  'Putin',
#  'world',
#  'RedNationRising',
#  'Saudi',
#  'Pilecki',
#  'Tech',
#  'ザ少年倶楽部プレミアム',
#  'KavanaughConfirmation',
#  'TiffanyYoungFanMeetingTourBKK',
#  'WelcomeTiffanyYoungtoThailand',
#  'Labour',
#  'RNC',
#  'MorningJoe',
#  'Noshowicus',
#  'haber',
#  'notizie',
#  'video',
#  '小山キャスター復帰希望',
#  'DeclassifyFISA',
#  'エンドレスサマー',
#  'Polish',
#  '慶ちゃん大好き',
#  'Mueller',
#  'VoteRed2018',
#  'haberler',
#  'android',
#  'Life',
#  'RoyMoore',
#  'nowplaying',
#  'DeepStateCorruption',
#  'PTSD',
#  'God',
#  'Followback',
#  '1u',
#  'ゼロ一獲千金ゲーム続編希望',
#  'LaUnionEsNuestraFuerza',
#  'deals',
#  'TuesdayThoughts',
#  'Spain',
#  'NorthCarolina',
#  'notícia',
#  'breaking',
#  'LockHerUp',
#  'TXSen',
#  'NY',
#  'Relax',
#  'Music',
#  'POTUS45',
#  'SpyGate',
#  'TUR',
#  'PedoGate',
#  'faith',
#  'TheMoreYouKnow',
#  'WhiteHouse',
#  'BlueWaveComing2018',
#  'KeepTexasRed',
#  '中國',
#  'パーナさんと繋がりたい',
#  'Healthcare',
#  'MSNBC',
#  'ABC',
#  'KAG2018',
#  'Fact',
#  '大野智',
#  'ProjectVeritas',
#  'TalkLikeAPirateDay',
#  'Japan',
#  'winning',
#  'NC',
#  'NP',
#  'leadership',
#  '希望yell',
#  'IT',
#  'LJMAGA',
#  'Pakistan',
#  'Senate',
#  'Duda',
#  'canada',
#  'BlueWaveIsComing',
#  'Collins',
#  'instagram',
#  'RESIST',
#  'Poland',
#  'ゼロ一獲千金ゲームエピソードZERO',
#  'JeffSessions',
#  'Istandul',
#  'EEUU',
#  'Turkey',
#  'cnn',
#  'NEWS速報JAPAN',
#  'FoxNews',
#  'ReadmisionYa',
#  'Yemen',
#  'Ohio',
#  'money',
#  'Austin',
#  'WorstPresidentEver',
#  'Manafort',
#  'ICYMI',
#  'women',
#  'BlueTsunami',
#  'World',
#  'FISAgate',
#  'Hikes',
#  'Walking',
#  'Relaxing',
#  'Iranian',
#  'FL',
#  'NotMyPresident',
#  'テゴマスのらじお',
#  'NorthKorea',
#  'Jesus',
#  'motivation',
#  'NBC',
#  'bbjinsight',
#  'blockchaintechnology',
#  'EU',
#  'RedWaveRising2018',
#  'Impeach45',
#  'SenateSeat',
#  'SpecialElectionWin',
#  'WalkAwayFromDemocrats',
#  '嵐',
#  'DeepStateExposed',
#  '慶ちゃん応援隊',
#  'Europe',
#  'feathers',
#  '갓세븐',
#  '1A',
#  'SupremeCourt',
#  'ドリフェス',
#  'Twitter',
#  'Maddow',
#  'Beto',
#  'PrescientInfo',
#  'Corruption',
#  'FoxAndFriends',
#  'photography',
#  'Deplorable',
#  'Eagles',
#  'nature',
#  'Blockchain',
#  'Tennessee',
#  'cascade',
#  'Midterms',
#  'MuellerInvestigation',
#  'quote',
#  'IllegalAliens',
#  'France',
#  'India',
#  'AlternativeFacts',
#  'auspol',
#  'JESUSLIVES',
#  'IFB',
#  '味の素スタジアム円盤化希望',
#  'Detroit',
#  'GodsArmy',
#  'FlipItBlue',
#  'ハロウィン音楽祭',
#  'BlackTwitter',
#  'USFA',
#  'TedCruz',
#  'AskTheQ',
#  'teropongsenayan',
#  'BigTimeRadio',
#  'Photography',
#  'Opinion',
#  'free',
#  'BigOlFamily',
#  'Germany',
#  'metoo',
#  '慶ちゃん',
#  'MerrickGarland',
#  'JOBS',
#  'DrFord',
#  'TakeAKnee',
#  'PastorAndrew',
#  'tedcruz',
#  'NEWSニッポン',
#  'TheRainMakers',
#  'stocks',
#  'share',
#  'investing',
#  'AMAZON',
#  'MEGA',
#  'DemocratsHateAmerica',
#  'Finance',
#  'Benalla',
#  'Sunset',
#  'FTrump',
#  'ConfirmJudgeKavanaughNow',
#  'DianeFeinstein',
#  'abortion',
#  'ChooseCruz',
#  'VoteBlueToSaveAmerica',
#  'PlannedParenthood',
#  'GA',
#  'England',
#  'Education',
#  'ドリフェス2018円盤化希望',
#  '2ADefenders',
#  'History',
#  'trading',
#  'Democratic',
#  'apple',
#  'MarioKart',
#  'Amazon',
#  'SouthAfrica',
#  'novasocialnews',
#  'BetoforTX',
#  'scottwalker',
#  'tony4wi',
#  'peace',
#  'ConfirmJudgeKavanaugh',
#  'Owens',
#  'Technology',
#  'speakerryan',
#  'etsy',
#  'ZIP',
#  'Houston',
#  'コヤシゲ',
#  'SuperSaiyan',
#  'Fight',
#  'Sunrise',
#  'Africa',
#  'PrayForPotus',
#  'Christian',
#  'Feinstein',
#  'aboluowang',
#  'PrayForUSA',
#  'PrayForOurLeaders',
#  'UAE',
#  'BetoForTexas',
#  'VoteGOP',
#  'Scotland',
#  'history',
#  'Markets',
#  'Killary',
#  'Nowplaying',
#  'beauty',
#  'FISADeclassification',
#  'Gaming',
#  'KeepAmericaGreat',
#  'Ford',
#  'BTS',
#  'ThankYou',
#  'eBooks',
#  'SmellGists',
#  'Oferta',
#  'PremioLiterario',
#  'Indies',
#  'fakenews',
#  'gaming',
#  'Mexico',
#  'pedogate',
#  'fishing',
#  'YudhAbhyas2018',
#  'AFBDay',
#  'TrustThePlan',
#  'Peace',
#  'forex',
#  'rt',
#  'pray',
#  'blog',
#  'follow',
#  'Dagga',
#  'MAGA2018',
#  'ゼロエピソードZERO',
#  'Kavanagh',
#  'atheism',
#  'Australia',
#  'ElectricVehicle',
#  'AI',
#  'Nachrichten',
#  'atheist',
#  'finance',
#  'Sessions',
#  'Bible',
#  'AirForceOne',
#  'Clinton',
#  'Women',
#  'Maine',
#  'maternity',
#  'Startup',
#  'hiphop',
#  'media',
#  'AIRPOWER',
#  'pjnet',
#  'Dallas',
#  'Wales',
#  'success',
#  'チャンカパーナ',
#  'IndianArmy',
#  'snp',
#  'plaidcymru',
#  'it',
#  'AnitaHill',
#  'DemForce',
#  'MAGASwaGGa',
#  'MakeNoMistake',
#  'めざましテレビ',
#  'Fashion',
#  'NewJersey',
#  'NEvsDET',
#  'TrumpTrain2020',
#  'sports',
#  'PAD',
#  'ImstillwithHer',
#  'Restart',
#  'Asia',
#  'DianaMarySharpton',
#  'realDonaldTrump',
#  'CCOT',
#  'trump2020',
#  'USBiz',
#  'Palestinians',
#  'Washington',
#  'startup',
#  'ComfortInn',
#  'BrettKavanuagh',
#  'ObamaGate',
#  'Georgia',
#  'Gist',
#  'NYT',
#  'Pedogate',
#  'inspiration',
#  'Hiking',
#  'reuters',
#  'ChristinaBlaseyFord',
#  'connectsindonesia',
#  'NYC',
#  'YeastInfestedPussySuits',
#  'AF1',
#  'MustVote2018',
#  'BackTheBlue',
#  'PanicInDC',
#  'kavanaugh',
#  'NastyWomen',
#  'DFS',
#  'lockherup',
#  'cdnpoli',
#  'Anime',
#  'TRUMP2020',
#  'MAGA2020',
#  'health',
#  'today',
#  'TrumpsArmy',
#  'books',
#  'humor',
#  'indyref2',
#  'readmisionya',
#  'TrumpLies',
#  'Wisconsin',
#  'ISIS',
#  'WordPress',
#  '手越くん',
#  'JESUS',
#  'EggDrp',
#  'GoLive',
#  'PuertoRico',
#  '中国',
#  'Retweetforawareness',
#  'MOG',
#  'OpenSelection',
#  'market',
#  'quotes',
#  'artist',
#  'Gossip',
#  'Libdems',
#  'p2',
#  'わーーーージャニオタさんと繋がるお時間がまいりましたいっぱい繋がりましょ',
#  'KSA',
#  'greenparty',
#  'democrats',
#  'FollowTheWhiteRabbit',
#  'EXO',
#  'ScotRef',
#  'stillyes',
#  'wisdom',
#  'Follow',
#  'LiberalismIsAMentalDisorder',
#  'deal',
#  'InternetBillOfRights',
#  'Fiverr',
#  'china',
#  'BlueTsunami2018',
#  'economy',
#  'HumanRights',
#  'BoycottNetflix',
#  'Deplorables',
#  '慶ちゃんに愛届け隊',
#  'TrumpTweetTruck',
#  'Patriarchy',
#  'KimJongUn',
#  'beautiful',
#  'Benghazi',
#  '希望～yell～',
#  'Hounews',
#  'Thala',
#  'Marketing',
#  'atheistpics',
#  'atheistrollcall',
#  'Google',
#  'HiillaryWon',
#  'vintage',
#  'MarineOne',
#  'NEWSファンと繋がりたい',
#  'allnews24',
#  'Jack',
#  'ข่าววันนี้',
#  'Palestinian',
#  'KavanaughForSCOTUS',
#  'sky',
#  'Winner',
#  'Minnesota',
#  'chicago',
#  'Sales',
#  'BruselasNosPillaDePaso',
#  'JudgeKavanaugh',
#  'trending',
#  'war',
#  'London',
#  'общество',
#  '慶ちゃん頑張れ',
#  'MintToBe',
#  'DregOfSociety',
#  'Cuba',
#  'Iowa',
#  'WalkAwayFromDemocrats2018',
#  'WitchHunt',
#  'gunsense',
#  'Islam',
#  'LiberalismIsAMentalDisease',
#  'Android',
#  'people',
#  'entrepreneur',
#  'Forex',
#  'FakeNewsMedia',
#  'SanFrancisco',
#  'education',
#  'Flowers',
#  'twitter',
#  'ots',
#  'Ravens',
#  'Qanon8chan',
#  'Gaza',
#  'deepstate',
#  'giveaway',
#  'uk',
#  'Macron',
#  'Poll',
#  'graphic',
#  'pcexpander',
#  'markets',
#  'Science',
#  'Chinese',
#  'eu',
#  'Police',
#  'niagarafalls',
#  'TX',
#  'science',
#  'UnitedStates',
#  'Norfolk',
#  'Progressive',
#  'MuMuMama',
#  'VoteBlue2018',
#  'BillClinton',
#  'SocialMedia',
#  'CA22',
#  'USS',
#  'TrumpWorldPeace',
#  'GreatestThingsAboutThe90s',
#  'WWENXT',
#  'help',
#  'HRC',
#  'Palestine',
#  'Beauty',
#  'происшествие',
#  'FreeSpeech',
#  'Hispanic',
#  'Toad',
#  'refugees',
#  'vacation',
#  'WALKAWAY',
#  'CBS',
#  'food',
#  'anime',
#  'PedoGateNews',
#  'sunset',
#  'godless',
#  'redwave',
#  'NowPIaying',
#  'GoToJail',
#  'PeoplesPresident',
#  'STAY',
#  'Mountains',
#  'Media',
#  'makeup',
#  'FX',
#  'newyork',
#  'ジャニーズ',
#  'DEMS',
#  'Video',
#  'Soros',
#  'film',
#  'Greece',
#  'Cryptocurrency',
#  'CruzCrew',
#  'stockmarket',
#  'cybernews',
#  'blue',
#  'btc',
#  'TriggerBallot',
#  'cannabis',
#  'games',
#  'Facts',
#  'MS13',
#  'Election2016',
#  'nigeria',
#  'QLoungeLive',
#  'terpopuler',
#  'BetoORourke',
#  'Trump2016',
#  'INDvPAK',
#  'Nigeria',
#  'LAPD',
#  'africanstyle',
#  'BLM',
#  'UN',
#  'Arizona',
#  'Repost',
#  'amazon',
#  'lka',
#  'TheTruthCommunity',
#  'southafricanfarmers',
#  'africanprint',
#  'ankarastyles',
#  'africanclothing',
#  'ChildTrafficking',
#  'Clippers',
#  'LASD',
#  'SurenosAryanos',
#  'Day2Day1nSociety',
#  'X3',
#  'rep_hunter',
#  'Medicare',
#  '小山慶一郎大好き',
#  'ConstitutionDay',
#  'sexy',
#  'RETWEET',
#  'Vikings',
#  'Michigan',
#  'Future40',
#  'Latest',
#  'DAICHI',
#  'Flower',
#  'we_are_iranian',
#  'CIA',
#  'KisMyFt2',
#  'DEEPSTATE',
#  'jjs5547',
#  'findom',
#  'TheExtraordinaryJourneyoftheFakir',
#  'BREKING112',
#  'Resisters',
#  'retweet',
#  'REDPASSION',
#  'Idlib',
#  'ゼロ一攫千金ゲーム',
#  'Nike',
#  'RING',
#  'GOPRussia',
#  'USAF',
#  'tariffs',
#  'TWTG1',
#  'tlot',
#  'Ireland',
#  'genocide',
#  'Emirates',
#  'NSUI',
#  'POTUS44',
#  'TrumpCrimeFamily',
#  'samsung',
#  'Beautiful',
#  'ＫちゃんNEWS',
#  'YouTube',
#  'Compassion',
#  'NPR',
#  'REDWAVE',
#  'healthcare',
#  'Physician',
#  'BayAreaSouthAsianFilmFestival',
#  'paranormal',
#  'ChewbacaLeg',
#  'friends',
#  'オリコン',
#  'wednesdaythoughts',
#  'Russian',
#  'NEWYORK',
#  'NeverForget',
#  'truthers',
#  'TrustSessions',
#  'russia',
#  'Facebook',
#  'Vets',
#  'Live',
#  'podcast',
#  'Mステ',
#  'endracism',
#  'lets',
#  'AlexJones',
#  'model',
#  'TickTock',
#  'trendingnews',
#  'DeportThemAll',
#  'Argentina',
#  'Hulu',
#  'Alibaba',
#  'westportkc',
#  'kansascity',
#  'TakeItBack',
#  'Israeli',
#  '新譜',
#  'casino',
#  'Plants',
#  'Cruz',
#  'AndersonCooper',
#  'GoPats',
#  'Maassen',
#  'sd19',
#  'Transportation',
#  'arme',
#  'invest',
#  'grateful',
#  'hot',
#  'online',
#  'Celebrities',
#  'DevilYouLoseAgain',
#  'NowPlaying️',
#  'USMC',
#  'over20なNEWS担繋がろうキャンペーン',
#  'realdonaldtrump',
#  'Cowboys',
#  'Apple',
#  'FLOTUS',
#  'home',
#  'KingandPrince',
#  'Left',
#  'WednesdayMorning',
#  'LaborDay',
#  'mentalhealth',
#  'ICO',
#  'Grassley',
#  'BBC',
#  'LadyD',
#  'Ecuador',
#  'AltLeft',
#  'VetoBeto',
#  'LOCKHERUP',
#  'NEWS15thAniniversary',
#  'SexyZone',
#  'ConfirmBrettKavanaugh',
#  'FullAttackMode',
#  'LIVPSG',
#  '今日のにゅすくん',
#  'WWII',
#  'Ukraine',
#  'SanAntonio',
#  'social',
#  'TheStormIsHere',
#  'ethereum',
#  'TrumpWorld',
#  'MasterChefBR',
#  'Brennan',
#  'TruthHurts',
#  'CloserNation',
#  'SikhGenocide',
#  'Waterfall',
#  'photo',
#  'nonstopnews',
#  'Investment',
#  'AnimalMatters',
#  '藤原さくら',
#  'apologist',
#  'テゴマス',
#  'Socialism',
#  'Jaguars',
#  'DemocratsAreDangerous',
#  'LPS',
#  'fintech',
#  'Falcons',
#  'SlowWalker',
#  'Photos',
#  'StandUp4Brexit',
#  'Newswire',
#  'socialmedia',
#  'telegram',
#  'tariff',
#  'soynadie',
#  'romance',
#  'weather',
#  'Showbiz',
#  'scomo',
#  'DNI',
#  'FEMA',
#  'california',
#  'ElectionDay',
#  'NEWS15周年おめでとう',
#  'SEO',
#  'TrumpDerangementSyndrome',
#  'DrainTheDeepStateSwamp',
#  'Exclusive',
#  'Wethepeople',
#  'REPUBS',
#  'Emmys',
#  'NAFTA',
#  'APEC',
#  'Boston',
#  'рф',
#  'family',
#  'House',
#  'msnbc',
#  'Paparazzi',
#  'VipScandals',
#  'WestWing',
#  '1600Daily',
#  'POTUSSchedule',
#  'realestate',
#  'climatechange',
#  'TV',
#  'book',
#  'AnydayIsGoodDay',
#  'WRWY',
#  'Tcot',
#  'Rosenstein',
#  'sentedcruz',
#  'bonus',
#  'Comedy',
#  'TrumpEconomy',
#  'amazing',
#  'KeepItBlue',
#  'houston',
#  ...]

# %%
f = open('top_1000_hashtags_not_in_political_hashtags_2018_09-19.txt', 'w+')
for hashtag in hashtags_not_in_lst:
    f.write(hashtag + '\n')
f.close()
